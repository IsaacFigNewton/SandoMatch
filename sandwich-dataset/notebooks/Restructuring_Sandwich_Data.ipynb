# %%
import random
import re
import pandas as pd
import json
import requests
from google.colab import files
import ipywidgets as widgets
from IPython.display import display

originating_restaurant = "mr_pickles"

# Create a FileUpload widget that accepts JSON files
uploader = widgets.FileUpload(
    accept='.json',
    multiple=False
)

# Display the uploader widget
display(uploader)

def handle_upload(change):
    # Declare global vars because apparently I can't use ones in the broader scope
    global sandwiches_data, uploaded_filename
    if uploader.value:
        # Get the uploaded file content
        uploaded_file = next(iter(uploader.value.values()))
        uploaded_filename = uploaded_file['metadata']['name']

        # Decode the file content from bytes to a string
        json_str = uploaded_file['content'].decode('utf-8')

        sandwiches_data = json.loads(json_str)
        print(f"Successfully uploaded {uploaded_filename}")

# Observe changes in the uploader widget
uploader.observe(handle_upload, names='value')
# Out:
# FileUpload(value={}, accept='.json', description='Upload')
# Successfully uploaded mr_pickles_menu.json

# %%
print(sandwiches_data)
# Out:
# [{'id': 33687, 'ingredients': ['black pepper', 'onions', 'bread', 'extra-virgin olive oil', 'eggs', 'salt', 'butter'], 'cuisine': None}, {'id': 9720, 'ingredients': ['ground black pepper', 'coarse salt', 'large eggs', 'extra-virgin olive oil', 'unsalted butter', 'lemon', 'bread', 'boneless skinless chicken breasts'], 'cuisine': None}, {'id': 23540, 'ingredients': ['ricotta cheese', 'tomatoes', 'italian seasoning', 'bread', 'provolone cheese', 'mayonaise'], 'cuisine': None}, {'id': 13816, 'ingredients': ['baguette', 'salt', 'medium shrimp', 'tomatoes', 'yellow bell pepper', 'scallions', 'bread', 'dijon mustard', 'creole seasoning', 'romaine lettuce', 'extra-virgin olive oil', 'reduced fat mayonnaise'], 'cuisine': 'cajun_creole'}, {'id': 24965, 'ingredients': ['Spanish olives', 'parsley', 'olive oil', 'bread', 'hard salami'], 'cuisine': 'spanish'}, {'id': 26788, 'ingredients': ['bread', 'sliced turkey', 'mayonaise', 'chipotle chile powder', 'cheddar cheese', 'cooked bacon', 'sprouts'], 'cuisine': 'mexican'}, {'id': 28279, 'ingredients': ['genoa salami', 'sliced ham', 'mortadella', 'mozzarella cheese', 'olives', 'bread', 'provolone cheese'], 'cuisine': 'cajun_creole'}, {'id': 4357, 'ingredients': ['fresh basil', 'sprinkles', 'bread', 'deli ham', 'roasted red peppers', 'crushed red pepper', 'spinach leaves', 'low-fat mayonnaise'], 'cuisine': 'italian'}, {'id': 35077, 'ingredients': ['bread', 'brown mustard', 'shredded mozzarella cheese', 'broccoli florets', 'boneless skinless chicken breast halves'], 'cuisine': 'italian'}, {'id': 50001, 'ingredients': ['sourdough bread', 'corned beef', 'sauerkraut', 'swiss cheese', 'russian dressing'], 'cuisine': 'american'}, {'id': 50002, 'ingredients': ['baguette', 'brie cheese', 'fig jam', 'prosciutto', 'arugula'], 'cuisine': 'french'}, {'id': 50003, 'ingredients': ['whole wheat bread', 'hummus', 'cucumber', 'tomato', 'feta cheese', 'kalamata olives'], 'cuisine': 'mediterranean'}, {'id': 50004, 'ingredients': ['ciabatta', 'pesto', 'mozzarella', 'tomato', 'basil leaves'], 'cuisine': 'italian'}, {'id': 50005, 'ingredients': ['rye bread', 'pastrami', 'swiss cheese', 'sauerkraut', 'thousand island dressing'], 'cuisine': 'american'}, {'id': 50006, 'ingredients': ['pumpernickel bread', 'smoked salmon', 'cream cheese', 'red onion', 'capers', 'dill'], 'cuisine': 'scandinavian'}, {'id': 50007, 'ingredients': ['brioche bun', 'pulled pork', 'bbq sauce', 'coleslaw'], 'cuisine': 'american'}, {'id': 50008, 'ingredients': ['pita bread', 'falafel', 'tahini sauce', 'lettuce', 'tomato', 'cucumber'], 'cuisine': 'middle_eastern'}, {'id': 50009, 'ingredients': ['focaccia', 'grilled vegetables', 'goat cheese', 'balsamic glaze'], 'cuisine': 'italian'}, {'id': 50010, 'ingredients': ['croissant', 'ham', 'gruyere cheese', 'dijon mustard'], 'cuisine': 'french'}, {'id': 50011, 'ingredients': ['tortilla wrap', 'grilled chicken', 'avocado', 'bacon', 'ranch dressing', 'lettuce'], 'cuisine': 'american'}, {'id': 50012, 'ingredients': ['toasted white bread', 'tuna salad', 'cheddar cheese', 'tomato'], 'cuisine': 'american'}, {'id': 50013, 'ingredients': ['pretzel bun', 'bratwurst', 'sauerkraut', 'whole grain mustard'], 'cuisine': 'german'}, {'id': 50014, 'ingredients': ['english muffin', 'egg', 'canadian bacon', 'hollandaise sauce'], 'cuisine': 'american'}, {'id': 50015, 'ingredients': ['naan bread', 'chicken tikka', 'yogurt sauce', 'cucumber', 'red onion'], 'cuisine': 'indian'}, {'id': 50016, 'ingredients': ['baguette', 'roast beef', 'horseradish sauce', 'arugula', 'tomato'], 'cuisine': 'french'}, {'id': 50017, 'ingredients': ['multigrain bread', 'turkey', 'cranberry sauce', 'stuffing', 'mayo'], 'cuisine': 'american'}, {'id': 50018, 'ingredients': ['bao bun', 'pork belly', 'hoisin sauce', 'cucumber', 'scallions'], 'cuisine': 'chinese'}, {'id': 50019, 'ingredients': ['ciabatta', 'grilled eggplant', 'roasted red peppers', 'fresh mozzarella', 'basil pesto'], 'cuisine': 'italian'}, {'id': 50020, 'ingredients': ['whole wheat wrap',  ...

# %% [markdown]
# #Variables

# %%
vegetarian_bases = {"egg", "veggie patty"}
vegan_bases = {"veggie patty"}

# %% [markdown]
# ##Cost, calorie data

# %%
all_ingredients = {
    "breads": {
        "baguette": {"cost": 1.5, "calories": 250},
        "ciabatta": {"cost": 1.8, "calories": 250},
        "pita": {"cost": 1.0, "calories": 200},
        "naan": {"cost": 1.2, "calories": 300},
        "tortilla": {"cost": 0.8, "calories": 150},
        "roll": {"cost": 0.5, "calories": 120},
        "sourdough": {"cost": 2.0, "calories": 220},
        "rye": {"cost": 1.5, "calories": 200},
        "multigrain": {"cost": 1.5, "calories": 220},
        "whole wheat": {"cost": 1.0, "calories": 180},
        "white bread": {"cost": 1.0, "calories": 160},
        "brioche": {"cost": 2.5, "calories": 300},
        "focaccia": {"cost": 2.0, "calories": 250},
        "panini": {"cost": 2.0, "calories": 200},
        "english muffin": {"cost": 0.8, "calories": 150},
        "bagel": {"cost": 1.0, "calories": 250},
        "croissant": {"cost": 1.5, "calories": 280},
        "milk bread": {"cost": 1.8, "calories": 220},
        "flatbread": {"cost": 1.0, "calories": 180},
        "pumpernickel": {"cost": 1.8, "calories": 190},
        "pretzel roll": {"cost": 1.5, "calories": 200},
        "potato bread": {"cost": 1.0, "calories": 180},
        "bolillo": {"cost": 0.6, "calories": 150},
        "torta": {"cost": 0.8, "calories": 180},
        "lavash": {"cost": 1.0, "calories": 160},
        "cornbread": {"cost": 1.5, "calories": 180},
        "chapati": {"cost": 0.5, "calories": 120},
        "paratha": {"cost": 0.8, "calories": 150},
        "wrap": {"cost": 1.0, "calories": 150},
        "bun": {"cost": 0.5, "calories": 120},
        "steamed bun": {"cost": 0.8, "calories": 140}
    },
    "meats": {
        "beef": {"cost": 3.0, "calories": 250},
        "chicken": {"cost": 2.0, "calories": 200},
        "turkey": {"cost": 2.5, "calories": 180},
        "pork": {"cost": 2.5, "calories": 220},
        "ham": {"cost": 2.0, "calories": 150},
        "bacon": {"cost": 1.0, "calories": 50},
        "sausage": {"cost": 1.5, "calories": 180},
        "bratwurst": {"cost": 2.0, "calories": 250},
        "salami": {"cost": 2.0, "calories": 120},
        "prosciutto": {"cost": 2.5, "calories": 70},
        "pepperoni": {"cost": 1.5, "calories": 80},
        "pastrami": {"cost": 2.0, "calories": 120},
        "mortadella": {"cost": 2.0, "calories": 100},
        "lamb": {"cost": 3.5, "calories": 250},
        "duck": {"cost": 4.0, "calories": 350},
        "roast beef": {"cost": 3.0, "calories": 250},
        "veal": {"cost": 3.5, "calories": 200},
        "venison": {"cost": 4.0, "calories": 220},
        "chorizo": {"cost": 2.0, "calories": 100},
        "capicola": {"cost": 2.5, "calories": 90},
        "bresaola": {"cost": 3.0, "calories": 70},
        "pancetta": {"cost": 2.5, "calories": 80},
        "smoked fish": {"cost": 4.0, "calories": 100},
        "tuna": {"cost": 2.0, "calories": 150},
        "shrimp": {"cost": 3.0, "calories": 100},
        "crab": {"cost": 3.5, "calories": 70},
        "lobster": {"cost": 5.0, "calories": 100},
        "meatball": {"cost": 2.0, "calories": 150},
        "pulled pork": {"cost": 2.5, "calories": 200},
        "carnitas": {"cost": 2.5, "calories": 200},
        "corned beef": {"cost": 3.0, "calories": 200},
        "brisket": {"cost": 3.5, "calories": 250},
        "gyro": {"cost": 2.5, "calories": 220},
        "char siu": {"cost": 3.0, "calories": 240},
        "shawarma": {"cost": 2.5, "calories": 220},
        "jerky": {"cost": 1.5, "calories": 70},
        "egg": {"cost": 0.5, "calories": 78},
        "veggie patty": {"cost": 1.5, "calories": 124}
    },
    "cheeses": {
        "cheddar": {"cost": 1.0, "calories": 110},
        "mozzarella": {"cost": 1.0, "calories": 80},
        "swiss": {"cost": 1.2, "calories": 100},
        "provolone": {"cost": 1.0, "calories": 90},
        "brie": {"cost": 1.5, "calories": 95},
        "gorgonzola": {"cost": 1.5, "calories": 100},
        "feta": {"cost": 1.2, "calories": 70},
        "parmesan": {"cost": 1.5, "calories": 110},
        "gouda": {"cost": 1.3, "calories": 100},
        "ricotta": {"cost": 1.0, "calories": 60},
        "blue cheese": {"cost": 1.5, "calories": 100},
        "goat cheese": {"cost": 1.5, "calories": 80},
        "monterey jack": {"cost": 1.0, "calories": 90},
        "cream cheese": {"cost": 0.8, "calories": 50},
        "american cheese": {"cost": 0.7, "calories": 90},
        "colby": {"cost": 1.0, "calories": 95},
        "pepper jack": {"cost": 1.0, "calories": 90},
        "gruyere": {"cost": 1.5, "calories": 110},
        "camembert": {"cost": 1.5, "calories": 95},
        "asiago": {"cost": 1.2, "calories": 110},
        "romano": {"cost": 1.3, "calories": 110},
        "havarti": {"cost": 1.2, "calories": 100},
        "burrata": {"cost": 1.5, "calories": 80},
        "stracciatella": {"cost": 1.5, "calories": 90},
        "queso fresco": {"cost": 1.0, "calories": 60},
        "cotija": {"cost": 1.0, "calories": 80},
        "paneer": {"cost": 1.0, "calories": 100},
        "halloumi": {"cost": 1.5, "calories": 110}
    },
    "vegetables": {
        "lettuce": {"cost": 0.5, "calories": 10},
        "tomato": {"cost": 0.6, "calories": 20},
        "onion": {"cost": 0.4, "calories": 40},
        "pepper": {"cost": 0.7, "calories": 20},
        "spinach": {"cost": 0.5, "calories": 15},
        "cucumber": {"cost": 0.4, "calories": 10},
        "basil": {"cost": 1.0, "calories": 5},
        "sprouts": {"cost": 1.2, "calories": 15},
        "avocado": {"cost": 1.5, "calories": 150},
        "kale": {"cost": 1.0, "calories": 50},
        "zucchini": {"cost": 0.7, "calories": 20},
        "carrot": {"cost": 0.3, "calories": 30},
        "radish": {"cost": 0.4, "calories": 10},
        "celery": {"cost": 0.3, "calories": 5},
        "mushrooms": {"cost": 0.8, "calories": 20},
        "pickle": {"cost": 0.5, "calories": 5},
        "scallion": {"cost": 0.5, "calories": 5},
        "watercress": {"cost": 1.0, "calories": 5},
        "eggplant": {"cost": 1.0, "calories": 20},
        "beet": {"cost": 0.7, "calories": 40},
        "fennel": {"cost": 1.2, "calories": 20},
        "artichoke": {"cost": 1.5, "calories": 60},
        "garlic": {"cost": 0.5, "calories": 5},
        "olive": {"cost": 1.5, "calories": 50},
        "sun-dried tomato": {"cost": 1.5, "calories": 100},
        "kimchi": {"cost": 1.2, "calories": 20},
        "cabbage": {"cost": 0.6, "calories": 25},
        "greens": {"cost": 0.5, "calories": 15},
        "herbs": {"cost": 1.0, "calories": 5}
    },
    "condiments": {
        "mayonnaise": {"cost": 1.0, "calories": 100},
        "mustard": {"cost": 0.5, "calories": 5},
        "oil": {"cost": 0.8, "calories": 120},
        "butter": {"cost": 0.5, "calories": 100},
        "ketchup": {"cost": 0.6, "calories": 20},
        "relish": {"cost": 0.5, "calories": 10},
        "vinegar": {"cost": 0.3, "calories": 0},
        "dressing": {"cost": 1.0, "calories": 80},
        "salsa": {"cost": 0.8, "calories": 15},
        "sauce": {"cost": 0.5, "calories": 50},
        "pesto": {"cost": 1.5, "calories": 80},
        "chimichurri": {"cost": 1.2, "calories": 60},
        "aioli": {"cost": 1.0, "calories": 90},
        "tahini": {"cost": 1.2, "calories": 100},
        "honey": {"cost": 0.7, "calories": 60},
        "horseradish": {"cost": 0.8, "calories": 10},
        "hummus": {"cost": 1.0, "calories": 60},
        "guacamole": {"cost": 1.5, "calories": 50},
        "tartar sauce": {"cost": 1.0, "calories": 80},
        "yogurt sauce": {"cost": 1.0, "calories": 50},
        "dijon": {"cost": 0.6, "calories": 5},
        "marinara": {"cost": 0.8, "calories": 40},
        "glaze": {"cost": 1.2, "calories": 60},
        "chutney": {"cost": 1.0, "calories": 50}
    },
    "spices": {
        "salt": {"cost": 0.1, "calories": 0},
        "black pepper": {"cost": 0.5, "calories": 5},
        "cumin": {"cost": 0.5, "calories": 10},
        "paprika": {"cost": 0.5, "calories": 10},
        "coriander": {"cost": 0.5, "calories": 10},
        "oregano": {"cost": 0.4, "calories": 5},
        "basil": {"cost": 0.5, "calories": 5},
        "thyme": {"cost": 0.5, "calories": 5},
        "rosemary": {"cost": 0.5, "calories": 5},
        "cayenne pepper": {"cost": 0.5, "calories": 5},
        "turmeric": {"cost": 0.6, "calories": 5},
        "parsley": {"cost": 0.5, "calories": 5},
        "dill": {"cost": 0.5, "calories": 5},
        "cinnamon": {"cost": 0.6, "calories": 10},
        "nutmeg": {"cost": 0.5, "calories": 10},
        "allspice": {"cost": 0.6, "calories": 10},
        "cloves": {"cost": 0.6, "calories": 10},
        "cardamom": {"cost": 0.8, "calories": 10},
        "bay leaf": {"cost": 0.4, "calories": 0},
        "saffron": {"cost": 1.5, "calories": 5},
        "sage": {"cost": 0.5, "calories": 5},
        "mustard seed": {"cost": 0.5, "calories": 10},
        "fenugreek": {"cost": 0.6, "calories": 10},
        "anise": {"cost": 0.5, "calories": 5},
        "five-spice": {"cost": 0.6, "calories": 5},
        "powder": {"cost": 0.5, "calories": 5},
        "seasoning": {"cost": 0.6, "calories": 5},
        "za'atar": {"cost": 0.6, "calories": 5},
        "sumac": {"cost": 0.6, "calories": 5}
    }
}

# %%
# Define the set of words to remove
filter_words = {"ground", "chopped", "sliced", "freshly", "fresh"}

# %% [markdown]
# #Important Functions

# %%
def get_ingredient_subtype(ingredient):
    ingredient_tags = ingredient.split(" ")
    ingr_subtype = " ".join(ingredient_tags[:-1])

    print("Ingredient Subtype: '" + ingr_subtype + "'")
    return ingr_subtype

# %%
def add_ingredient_to_entry(entry,
                            ingredient,
                            ingredient_category,
                            exclusion_set1="",
                            exclusion_set2="",
                            exclusion_words=set()):
    for ingred_type in all_ingredients[ingredient_category].keys():
        if ingred_type in ingredient:
            # Build exclusion set
            exclusion_set = exclusion_words
            if exclusion_set1 and exclusion_set2:
                exclusion_set = exclusion_set.union(set(all_ingredients[exclusion_set1].keys()))
                exclusion_set = exclusion_set.union(set(all_ingredients[exclusion_set2].keys()))

            # Check for exclusions
            if not any(ex_word in ingredient for ex_word in exclusion_set):

                if ingred_type not in entry["ingredients"][ingredient_category]:
                    entry["ingredients"][ingredient_category][ingred_type] = []

                entry["ingredients"][ingredient_category][ingred_type].append(ingredient)
                break

# %%
def categorize_ingredients(ingredients_list):
    entry = {
        "ingredients": {
            "breads": dict(),
            "meats": dict(),
            "cheeses": dict(),
            "vegetables": dict(),
            "condiments": dict(),
            "spices": dict()
        },
        "cost": 0,
        "calories": 0,
        "rating": random.randint(1, 5),
        "dietary_tags": [],
        # increment for each new review,
        #   update rating by weighted sum of old and new ratings
        "review_count": 1,
        # store reviews as list of {rating, text} objects or maybe object ref ids?
        "reviews": []
    }

    for ingredient in ingredients_list:
        # Remove filter words
        pattern = r"\b(" + "|".join(map(re.escape, filter_words)) + r")\b"
        ingredient = re.sub(pattern, "", ingredient.lower()).strip()

        # Simple plural handling
        if ingredient.endswith('s'):
            ingredient = ingredient[:-1]

        print(f"Ingredient: '{ingredient}'")

        add_ingredient_to_entry(entry, ingredient, "breads")
        add_ingredient_to_entry(entry, ingredient, "meats")
        add_ingredient_to_entry(entry, ingredient, "cheeses")
        add_ingredient_to_entry(entry, ingredient, "vegetables",
                                exclusion_set1="condiments",
                                exclusion_set2="spices",
                                exclusion_words={"oil", "pepper jack", "pepperoni"})
        add_ingredient_to_entry(entry, ingredient, "condiments")
        add_ingredient_to_entry(entry, ingredient, "spices")

    # Compute cost and calories
    for category in entry["ingredients"]:
        print(f"Category: {category}")
        for ingredient_type in entry["ingredients"][category]:
            print(f"Ingredient Type: {ingredient_type}")
            lookup_key = ingredient_type
            print(f"Ingredient being searched: '{lookup_key}'")

            try:
                ingredient_data = all_ingredients[category][lookup_key]
                print(ingredient_data)

                # Estimate the sandwich's total cost
                entry["cost"] += ingredient_data["cost"]
                # Estimate the sandwich's total calorie count
                entry["calories"] += ingredient_data["calories"]

            except Exception as e:
                print(f"Exception: {e}")
                continue

    # Round the cost and calories to the nearest hundredth
    entry["cost"] = round(entry["cost"], 2)
    entry["calories"] = round(entry["calories"], 2)


    # Add dietary tags based on ingredients
    # If the base is a veggie patty, egg, or vegetable
    sandwich_bases = set(entry["ingredients"]["meats"].keys())
    if (not sandwich_bases.difference(vegan_bases)\
        or not sandwich_bases) and not entry["ingredients"]["cheeses"]:
        entry["dietary_tags"].append("vegan")
    elif not sandwich_bases.difference(vegetarian_bases)\
        or not sandwich_bases:
        entry["dietary_tags"].append("vegetarian")

    print(f"Total Cost: {entry['cost']}")
    print(f"Total Calories: {entry['calories']}")
    print(f"Rating: {entry['rating']}")
    print(entry)
    return entry

# %% [markdown]
# #Main

# %%
# Reformat each sandwich entry
formatted_sandwiches = []
i = 0
for sandwich in sandwiches_data:
    print("Parsing sandwich...")
    print(f"ID: {sandwich['id']}")
    print(f"Cuisine: {sandwich.get('cuisine')}")
    formatted_entry = {
        "id_": i,
        "cuisine": sandwich.get("cuisine"),
        "restaurant": None
    }

    # If it's indicated that the sandwich came from a specific restaurant
    if originating_restaurant:
        print(f"Restaurant: {originating_restaurant}")
        formatted_entry["restaurant"] = originating_restaurant

    # If the sandwich entry comes with a sandwich name
    if sandwich.get("name"):
        print(f"Name: {sandwich['name']}")
        formatted_entry["name"] = sandwich["name"]

    formatted_entry.update(categorize_ingredients(sandwich["ingredients"]))

    # If the sandwich entry comes with a cost, overwrite the estimate
    #   do this after getting the estimate so that future regression models
    #   can be more easily applied to this data
    if sandwich.get("cost"):
        print(f"Cost: {sandwich['cost']}")
        formatted_entry["cost"] = sandwich["cost"]

    formatted_sandwiches.append(formatted_entry)
    print("\n\n\n")

    i += 1

# Convert to a pandas DataFrame and export
output_file = 'restructured_' + uploaded_filename
with open(output_file, 'w') as outfile:
    json.dump(formatted_sandwiches, outfile, indent=4)

# Download the reformatted JSON file
files.download(output_file)
# Out:
# Parsing sandwich...
# ID: 1
# Cuisine: None
# Restaurant: mr_pickles
# Name: The Mr. Pickle
# Ingredient: 'chicken breast'
# Ingredient: 'bacon'
# Ingredient: 'monterey jack'
# Ingredient: 'avocado'
# Ingredient: 'mayonnaise'
# Ingredient: 'mustard'
# Ingredient: 'garlic sauce'
# Ingredient: 'tomato'
# Ingredient: 'onion'
# Ingredient: 'pickle'
# Ingredient: 'pepperoncini'
# Ingredient: 'lettuce'
# Category: breads
# Category: meats
# Ingredient Type: chicken
# Ingredient being searched: 'chicken'
# {'cost': 2.0, 'calories': 200}
# Ingredient Type: bacon
# Ingredient being searched: 'bacon'
# {'cost': 1.0, 'calories': 50}
# Category: cheeses
# Ingredient Type: monterey jack
# Ingredient being searched: 'monterey jack'
# {'cost': 1.0, 'calories': 90}
# Category: vegetables
# Ingredient Type: avocado
# Ingredient being searched: 'avocado'
# {'cost': 1.5, 'calories': 150}
# Ingredient Type: tomato
# Ingredient being searched: 'tomato'
# {'cost': 0.6, 'calories': 20}
# Ingredient Type: onion
# Ingredient being searched: 'onion'
# {'cost': 0.4, 'calories': 40}
# Ingredient Type: pickle
# Ingredient being searched: 'pickle'
# {'cost': 0.5, 'calories': 5}
# Ingredient Type: pepper
# Ingredient being searched: 'pepper'
# {'cost': 0.7, 'calories': 20}
# Ingredient Type: lettuce
# Ingredient being searched: 'lettuce'
# {'cost': 0.5, 'calories': 10}
# Category: condiments
# Ingredient Type: mayonnaise
# Ingredient being searched: 'mayonnaise'
# {'cost': 1.0, 'calories': 100}
# Ingredient Type: mustard
# Ingredient being searched: 'mustard'
# {'cost': 0.5, 'calories': 5}
# Ingredient Type: sauce
# Ingredient being searched: 'sauce'
# {'cost': 0.5, 'calories': 50}
# Category: spices
# Total Cost: 10.2
# Total Calories: 740
# Rating: 4
# {'ingredients': {'breads': {}, 'meats': {'chicken': ['chicken breast'], 'bacon': ['bacon']}, 'cheeses': {'monterey jack': ['monterey jack']}, 'vegetables': {'avocado': ['avocado'], 'tomato': ['tomato'], 'onion': ['onion'], 'pickle': ['pickle'], 'pepper': ['pepperoncini'], 'lettuce': ['lettuce']}, 'condiments': {'mayonnaise': ['mayonnaise'], 'mustard': ['mustard'], 'sauce': ['garlic sauce']}, 'spices': {}}, 'cost': 10.2, 'calories': 740, 'rating': 4, 'dietary_tags': [], 'review_count': 1, 'reviews': []}
# Cost: 14.69
#
#
#
#
# Parsing sandwich...
# ID: 2
# Cuisine: None
# Restaurant: mr_pickles
# Name: G.O.A.T.
# Ingredient: 'hot ham'
# Ingredient: 'capicola'
# Ingredient: 'salami'
# Ingredient: 'pepperoni'
# Ingredient: 'provolone'
# Ingredient: 'red wine vinegar'
# Ingredient: 'tomato'
# Ingredient: 'onion'
# Ingredient: 'pickle'
# Ingredient: 'pepperoncini'
# Ingredient: 'lettuce'
# Category: breads
# Category: meats
# Ingredient Type: ham
# Ingredient being searched: 'ham'
# {'cost': 2.0, 'calories': 150}
# Ingredient Type: capicola
# Ingredient being searched: 'capicola'
# {'cost': 2.5, 'calories': 90}
# Ingredient Type: salami
# Ingredient being searched: 'salami'
# {'cost': 2.0, 'calories': 120}
# Ingredient Type: pepperoni
# Ingredient being searched: 'pepperoni'
# {'cost': 1.5, 'calories': 80}
# Category: cheeses
# Ingredient Type: provolone
# Ingredient being searched: 'provolone'
# {'cost': 1.0, 'calories': 90}
# Category: vegetables
# Ingredient Type: tomato
# Ingredient being searched: 'tomato'
# {'cost': 0.6, 'calories': 20}
# Ingredient Type: onion
# Ingredient being searched: 'onion'
# {'cost': 0.4, 'calories': 40}
# Ingredient Type: pickle
# Ingredient being searched: 'pickle'
# {'cost': 0.5, 'calories': 5}
# Ingredient Type: pepper
# Ingredient being searched: 'pepper'
# {'cost': 0.7, 'calories': 20}
# Ingredient Type: lettuce
# Ingredient being searched: 'lettuce'
# {'cost': 0.5, 'calories': 10}
# Category: condiments
# Ingredient Type: vinegar
# Ingredient being searched: 'vinegar'
# {'cost': 0.3, 'calories': 0}
# Category: spices
# Total Cost: 12.0
# Total Calories: 625
# Rating: 1
# {'ingredients': {'breads': {}, 'meats': {'ham': ['hot ham'], 'capicola': ['capicola'], 'salami': ['salami'], 'pepperoni': ['pepperoni']}, 'cheeses': {'provolone': ['provolone']}, 'vegetables': {'tomato': ['tomato'], 'onion': ['onion'], 'pickle': ['pickle'], 'pepper': ['pepperoncini'], 'lettuce': ['lettuce']}, 'condiments': {'vinegar': ['red wine vinegar']}, 'spices': {}}, 'cost': 12.0, 'calories': 625, 'rating': 1, 'dietary_tags': [], 'review_count': 1, 'reviews': []}
# Cost: 13.99
#
#
#
#
# Parsing sandwich...
# ID: 3
# Cuisine: None
# Restaurant: mr_pickles
# Name: Kickin' Chicken
# Ingredient: 'chicken breast'
# Ingredient: 'pepper jack'
# Ingredient: 'baja sauce'
# Ingredient: 'hot sauce'
# Ingredient: 'mayonnaise'
# Ingredient: 'mustard'
# Ingredient: 'garlic sauce'
# Ingredient: 'tomato'
# Ingredient: 'onion'
# Ingredient: 'pickle'
# Ingredient: 'pepperoncini'
# Ingredient: 'lettuce'
# Category: breads
# Category: meats
# Ingredient Type: chicken
# Ingredient being searched: 'chicken'
# {'cost': 2.0, 'calories': 200}
# Category: cheeses
# Ingredient Type: pepper jack
# Ingredient being searched: 'pepper jack'
# {'cost': 1.0, 'calories': 90}
# Category: vegetables
# Ingredient Type: tomato
# Ingredient being searched: 'tomato'
# {'cost': 0.6, 'calories': 20}
# Ingredient Type: onion
# Ingredient being searched: 'onion'
# {'cost': 0.4, 'calories': 40}
# Ingredient Type: pickle
# Ingredient being searched: 'pickle'
# {'cost': 0.5, 'calories': 5}
# Ingredient Type: pepper
# Ingredient being searched: 'pepper'
# {'cost': 0.7, 'calories': 20}
# Ingredient Type: lettuce
# Ingredient being searched: 'lettuce'
# {'cost': 0.5, 'calories': 10}
# Category: condiments
# Ingredient Type: sauce
# Ingredient being searched: 'sauce'
# {'cost': 0.5, 'calories': 50}
# Ingredient Type: mayonnaise
# Ingredient being searched: 'mayonnaise'
# {'cost': 1.0, 'calories': 100}
# Ingredient Type: mustard
# Ingredient being searched: 'mustard'
# {'cost': 0.5, 'calories': 5}
# Category: spices
# Total Cost: 7.7
# Total Calories: 540
# Rating: 2
# {'ingredients': {'breads': {}, 'meats': {'chicken': ['chicken breast']}, 'cheeses': {'pepper jack': ['pepper jack']}, 'vegetables': {'tomato': ['tomato'], 'onion': ['onion'], 'pickle': ['pickle'], 'pepper': ['pepperoncini'], 'lettuce': ['lettuce']}, 'condiments': {'sauce': ['baja sauce', 'hot sauce', 'garlic sauce'], 'mayonnaise': ['mayonnaise'], 'mustard': ['mustard']}, 'spices': {}}, 'cost': 7.7, 'calories': 540, 'rating': 2, 'dietary_tags': [], 'review_count': 1, 'reviews': []}
# Cost: 14.39
#
#
#
#
# Parsing sandwich...
# ID: 4
# Cuisine: None
# Restaurant: mr_pickles
# Name: Reuben
# Ingredient: 'pastrami'
# Ingredient: 'swis'
# Ingredient: 'sauerkraut'
# Ingredient: 'thousand island'
# Ingredient: 'toasted marble rye'
# Category: breads
# Ingredient Type: rye
# Ingredient being searched: 'rye'
# {'cost': 1.5, 'calories': 200}
# Category: meats
# Ingredient Type: pastrami
# Ingredient being searched: 'pastrami'
# {'cost': 2.0, 'calories': 120}
# Category: cheeses
# Category: vegetables
# Category: condiments
# Category: spices
# Total Cost: 3.5
# Total Calories: 320
# Rating: 4
# {'ingredients': {'breads': {'rye': ['toasted marble rye']}, 'meats': {'pastrami': ['pastrami']}, 'cheeses': {}, 'vegetables': {}, 'condiments': {}, 'spices': {}}, 'cost': 3.5, 'calories': 320, 'rating': 4, 'dietary_tags': [], 'review_count': 1, 'reviews': []}
# Cost: 14.69
#
#
#
#
# Parsing sandwich...
# ID: 5
# Cuisine: None
# Restaurant: mr_pickles
# Name: Mrs. Pickle
# Ingredient: 'turkey breast'
# Ingredient: 'bacon'
# Ingredient: 'monterey jack'
# Ingredient: 'avocado'
# Ingredient: 'mayonnaise'
# Ingredient: 'mustard'
# Ingredient: 'garlic sauce'
# Ingredient: 'tomato'
# Ingredient: 'onion'
# Ingredient: 'pickle'
# Ingredient: 'pepperoncini'
# Ingredient: 'lettuce'
# Category: breads
# Category: meats
# Ingredient Type: turkey
# Ingredient being searched: 'turkey'
# {'cost': 2.5, 'calories': 180}
# Ingredient Type: bacon
# Ingredient being searched: 'bacon'
# {'cost': 1.0, 'calories': 50}
# Category: cheeses
# Ingredient Type: monterey jack
# Ingredient being searched: 'monterey jack'
# {'cost': 1.0, 'calories': 90}
# Category: vegetables
# Ingredient Type: avocado
# Ingredient being searched: 'avocado'
# {'cost': 1.5, 'calories': 150}
# Ingredient Type: tomato
# Ingredient being searched: 'tomato'
# {'cost': 0.6, 'calories': 20}
# Ingredient Type: onion
# Ingredient being searched: 'onion'
# {'cost': 0.4, 'calories': 40}
# Ingredient Type: pickle
# Ingredient being searched: 'pickle'
# {'cost': 0.5, 'calories': 5}
# Ingredient Type: pepper
# Ingredient being searched: 'pepper'
# {'cost': 0.7, 'calories': 20}
# Ingredient Type: lettuce
# Ingredient being searched: 'lettuce'
# {'cost': 0.5, 'calories': 10}
# Category: condiments
# Ingredient Type: mayonnaise
# Ingredient being searched: 'mayonnaise'
# {'cost': 1.0, 'calories': 100}
# Ingredient Type: mustard
# Ingredient being searched: 'mustard'
# {'cost': 0.5, 'calories': 5}
# Ingredient Type: sauce
# Ingredient being searched: 'sauce'
# {'cost': 0.5, 'calories': 50}
# Category: spices
# Total Cost: 10.7
# Total Calories: 720
# Rating: 3
# {'ingredients': {'breads': {}, 'meats': {'turkey': ['turkey breast'], 'bacon': ['bacon']}, 'cheeses': {'monterey jack': ['monterey jack']}, 'vegetables': {'avocado': ['avocado'], 'tomato': ['tomato'], 'onion': ['onion'], 'pickle': ['pickle'], 'pepper': ['pepperoncini'], 'lettuce': ['lettuce']}, 'condiments': {'mayonnaise': ['mayonnaise'], 'mustard': ['mustard'], 'sauce': ['garlic sauce']}, 'spices': {}}, 'cost': 10.7, 'calories': 720, 'rating': 3, 'dietary_tags': [], 'review_count': 1, 'reviews': []}
# Cost: 14.69
#
#
#
#
# Parsing sandwich...
# ID: 6
# Cuisine: None
# Restaurant: mr_pickles
# Name: Hot "T"
# Ingredient: 'turkey breast'
# Ingredient: 'pepper jack'
# Ingredient: 'baja sauce'
# Ingredient: 'cranberry sauce'
# Ingredient: 'mayonnaise'
# Ingredient: 'mustard'
# Ingredient: 'garlic sauce'
# Ingredient: 'tomato'
# Ingredient: 'onion'
# Ingredient: 'pickle'
# Ingredient: 'pepperoncini'
# Ingredient: 'lettuce'
# Category: breads
# Category: meats
# Ingredient Type: turkey
# Ingredient being searched: 'turkey'
# {'cost': 2.5, 'calories': 180}
# Category: cheeses
# Ingredient Type: pepper jack
# Ingredient being searched: 'pepper jack'
# {'cost': 1.0, 'calories': 90}
# Category: vegetables
# Ingredient Type: tomato
# Ingredient being searched: 'tomato'
# {'cost': 0.6, 'calories': 20}
# Ingredient Type: onion
# Ingredient being searched: 'onion'
# {'cost': 0.4, 'calories': 40}
# Ingredient Type: pickle
# Ingredient being searched: 'pickle'
# {'cost': 0.5, 'calories': 5}
# Ingredient Type: pepper
# Ingredient being searched: 'pepper'
# {'cost': 0.7, 'calories': 20}
# Ingredient Type: lettuce
# Ingredient being searched: 'lettuce'
# {'cost': 0.5, 'calories': 10}
# Category: condiments
# Ingredient Type: sauce
# Ingredient being searched: 'sauce'
# {'cost': 0.5, 'calories': 50}
# Ingredient Type: mayonnaise
# Ingredient being searched: 'mayonnaise'
# {'cost': 1.0, 'calories': 100}
# Ingredient Type: mustard
# Ingredient being searched: 'mustard'
# {'cost': 0.5, 'calories': 5}
# Category: spices
# Total Cost: 8.2
# Total Calories: 520
# Rating: 2
# {'ingredients': {'breads': {}, 'meats': {'turkey': ['turkey breast']}, 'cheeses': {'pepper jack': ['pepper jack']}, 'vegetables': {'tomato': ['tomato'], 'onion': ['onion'], 'pickle': ['pickle'], 'pepper': ['pepperoncini'], 'lettuce': ['lettuce']}, 'condiments': {'sauce': ['baja sauce', 'cranberry sauce', 'garlic sauce'], 'mayonnaise': ['mayonnaise'], 'mustard': ['mustard']}, 'spices': {}}, 'cost': 8.2, 'calories': 520, 'rating': 2, 'dietary_tags': [], 'review_count': 1, 'reviews': []}
# Cost: 14.39
#
#
#
#
# Parsing sandwich...
# ID: 7
# Cuisine: None
# Restaurant: mr_pickles
# Name: Rachel
# Ingredient: 'turkey breast'
# Ingredient: 'swis'
# Ingredient: 'sauerkraut'
# Ingredient: 'thousand island'
# Ingredient: 'toasted marble rye'
# Category: breads
# Ingredient Type: rye
# Ingredient being searched: 'rye'
# {'cost': 1.5, 'calories': 200}
# Category: meats
# Ingredient Type: turkey
# Ingredient being searched: 'turkey'
# {'cost': 2.5, 'calories': 180}
# Category: cheeses
# Category: vegetables
# Category: condiments
# Category: spices
# Total Cost: 4.0
# Total Calories: 380
# Rating: 1
# {'ingredients': {'breads': {'rye': ['toasted marble rye']}, 'meats': {'turkey': ['turkey breast']}, 'cheeses': {}, 'vegetables': {}, 'condiments': {}, 'spices': {}}, 'cost': 4.0, 'calories': 380, 'rating': 1, 'dietary_tags': [], 'review_count': 1, 'reviews': []}
# Cost: 14.69
#
#
#
#
# Parsing sandwich...
# ID: 8
# Cuisine: None
# Restaurant: mr_pickles
# Name: CJ's Pastrami
# Ingredient: 'pastrami'
# Ingredient: 'swis'
# Ingredient: 'mustard'
# Ingredient: 'pickle'
# Category: breads
# Category: meats
# Ingredient Type: pastrami
# Ingredient being searched: 'pastrami'
# {'cost': 2.0, 'calories': 120}
# Category: cheeses
# Category: vegetables
# Ingredient Type: pickle
# Ingredient being searched: 'pickle'
# {'cost': 0.5, 'calories': 5}
# Category: condiments
# Ingredient Type: mustard
# Ingredient being searched: 'mustard'
# {'cost': 0.5, 'calories': 5}
# Category: spices
# Total Cost: 3.0
# Total Calories: 130
# Rating: 3
# {'ingredients': {'breads': {}, 'meats': {'pastrami': ['pastrami']}, 'cheeses': {}, 'vegetables': {'pickle': ['pickle']}, 'condiments': {'mustard': ['mustard']}, 'spices': {}}, 'cost': 3.0, 'calories': 130, 'rating': 3, 'dietary_tags': [], 'review_count': 1, 'reviews': []}
# Cost: 14.69
#
#
#
#
# Parsing sandwich...
# ID: 9
# Cuisine: None
# Restaurant: mr_pickles
# Name: Hang Loose
# Ingredient: 'pastrami'
# Ingredient: 'bacon'
# Ingredient: 'cream cheese'
# Ingredient: 'avocado'
# Ingredient: 'mayonnaise'
# Ingredient: 'mustard'
# Ingredient: 'garlic sauce'
# Ingredient: 'tomato'
# Ingredient: 'onion'
# Ingredient: 'pickle'
# Ingredient: 'pepperoncini'
# Ingredient: 'lettuce'
# Category: breads
# Category: meats
# Ingredient Type: pastrami
# Ingredient being searched: 'pastrami'
# {'cost': 2.0, 'calories': 120}
# Ingredient Type: bacon
# Ingredient being searched: 'bacon'
# {'cost': 1.0, 'calories': 50}
# Category: cheeses
# Ingredient Type: cream cheese
# Ingredient being searched: 'cream cheese'
# {'cost': 0.8, 'calories': 50}
# Category: vegetables
# Ingredient Type: avocado
# Ingredient being searched: 'avocado'
# {'cost': 1.5, 'calories': 150}
# Ingredient Type: tomato
# Ingredient being searched: 'tomato'
# {'cost': 0.6, 'calories': 20}
# Ingredient Type: onion
# Ingredient being searched: 'onion'
# {'cost': 0.4, 'calories': 40}
# Ingredient Type: pickle
# Ingredient being searched: 'pickle'
# {'cost': 0.5, 'calories': 5}
# Ingredient Type: pepper
# Ingredient being searched: 'pepper'
# {'cost': 0.7, 'calories': 20}
# Ingredient Type: lettuce
# Ingredient being searched: 'lettuce'
# {'cost': 0.5, 'calories': 10}
# Category: condiments
# Ingredient Type: mayonnaise
# Ingredient being searched: 'mayonnaise'
# {'cost': 1.0, 'calories': 100}
# Ingredient Type: mustard
# Ingredient being searched: 'mustard'
# {'cost': 0.5, 'calories': 5}
# Ingredient Type: sauce
# Ingredient being searched: 'sauce'
# {'cost': 0.5, 'calories': 50}
# Category: spices
# Total Cost: 10.0
# Total Calories: 620
# Rating: 4
# {'ingredients': {'breads': {}, 'meats': {'pastrami': ['pastrami'], 'bacon': ['bacon']}, 'cheeses': {'cream cheese': ['cream cheese']}, 'vegetables': {'avocado': ['avocado'], 'tomato': ['tomato'], 'onion': ['onion'], 'pickle': ['pickle'], 'pepper': ['pepperoncini'], 'lettuce': ['lettuce']}, 'condiments': {'mayonnaise': ['mayonnaise'], 'mustard': ['mustard'], 'sauce': ['garlic sauce']}, 'spices': {}}, 'cost': 10.0, 'calories': 620, 'rating': 4, 'dietary_tags': [], 'review_count': 1, 'reviews': []}
# Cost: 14.99
#
#
#
#
# Parsing sandwich...
# ID: 10
# Cuisine: None
# Restaurant: mr_pickles
# Name: BBQ Melt
# Ingredient: 'chicken breast'
# Ingredient: 'cheddar'
# Ingredient: 'bbq sauce'
# Ingredient: 'mayonnaise'
# Ingredient: 'mustard'
# Ingredient: 'garlic sauce'
# Ingredient: 'tomato'
# Ingredient: 'onion'
# Ingredient: 'pickle'
# Ingredient: 'pepperoncini'
# Ingredient: 'lettuce'
# Category: breads
# Category: meats
# Ingredient Type: chicken
# Ingredient being searched: 'chicken'
# {'cost': 2.0, 'calories': 200}
# Category: cheeses
# Ingredient Type: cheddar
# Ingredient being searched: 'cheddar'
# {'cost': 1.0, 'calories': 110}
# Category: vegetables
# Ingredient Type: tomato
# Ingredient being searched: 'tomato'
# {'cost': 0.6, 'calories': 20}
# Ingredient Type: onion
# Ingredient being searched: 'onion'
# {'cost': 0.4, 'calories': 40}
# Ingredient Type: pickle
# Ingredient being searched: 'pickle'
# {'cost': 0.5, 'calories': 5}
# Ingredient Type: pepper
# Ingredient being searched: 'pepper'
# {'cost': 0.7, 'calories': 20}
# Ingredient Type: lettuce
# Ingredient being searched: 'lettuce'
# {'cost': 0.5, 'calories': 10}
# Category: condiments
# Ingredient Type: sauce
# Ingredient being searched: 'sauce'
# {'cost': 0.5, 'calories': 50}
# Ingredient Type: mayonnaise
# Ingredient being searched: 'mayonnaise'
# {'cost': 1.0, 'calories': 100}
# Ingredient Type: mustard
# Ingredient being searched: 'mustard'
# {'cost': 0.5, 'calories': 5}
# Category: spices
# Total Cost: 7.7
# Total Calories: 560
# Rating: 5
# {'ingredients': {'breads': {}, 'meats': {'chicken': ['chicken breast']}, 'cheeses': {'cheddar': ['cheddar']}, 'vegetables': {'tomato': ['tomato'], 'onion': ['onion'], 'pickle': ['pickle'], 'pepper': ['pepperoncini'], 'lettuce': ['lettuce']}, 'condiments': {'sauce': ['bbq sauce', 'garlic sauce'], 'mayonnaise': ['mayonnaise'], 'mustard': ['mustard']}, 'spices': {}}, 'cost': 7.7, 'calories': 560, 'rating': 5, 'dietary_tags': [], 'review_count': 1, 'reviews': []}
# Cost: 14.39
#
#
#
#
# Parsing sandwich...
# ID: 11
# Cuisine: None
# Restaurant: mr_pickles
# Name: Mama Mia!
# Ingredient: 'meatball'
# Ingredient: 'capicola'
# Ingredient: 'pepperoni'
# Ingredient: 'pepper jack'
# Ingredient: 'marinara sauce'
# Ingredient: 'garlic sauce'
# Ingredient: 'jalapeño'
# Category: breads
# Category: meats
# Ingredient Type: meatball
# Ingredient being searched: 'meatball'
# {'cost': 2.0, 'calories': 150}
# Ingredient Type: capicola
# Ingredient being searched: 'capicola'
# {'cost': 2.5, 'calories': 90}
# Ingredient Type: pepperoni
# Ingredient being searched: 'pepperoni'
# {'cost': 1.5, 'calories': 80}
# Category: cheeses
# Ingredient Type: pepper jack
# Ingredient being searched: 'pepper jack'
# {'cost': 1.0, 'calories': 90}
# Category: vegetables
# Category: condiments
# Ingredient Type: sauce
# Ingredient being searched: 'sauce'
# {'cost': 0.5, 'calories': 50}
# Category: spices
# Total Cost: 7.5
# Total Calories: 460
# Rating: 5
# {'ingredients': {'breads': {}, 'meats': {'meatball': ['meatball'], 'capicola': ['capicola'], 'pepperoni': ['pepperoni']}, 'cheeses': {'pepper jack': ['pepper jack']}, 'vegetables': {}, 'condiments': {'sauce': ['marinara sauce', 'garlic sauce']}, 'spices': {}}, 'cost': 7.5, 'calories': 460, 'rating': 5, 'dietary_tags': [], 'review_count': 1, 'reviews': []}
# Cost: 14.99
#
#
#
#
# Parsing sandwich...
# ID: 12
# Cuisine: None
# Restaurant: mr_pickles
# Name: Meatball
# Ingredient: 'meatball'
# Ingredient: 'provolone'
# Ingredient: 'marinara sauce'
# Ingredient: 'garlic sauce'
# Category: breads
# Category: meats
# Ingredient Type: meatball
# Ingredient being searched: 'meatball'
# {'cost': 2.0, 'calories': 150}
# Category: cheeses
# Ingredient Type: provolone
# Ingredient being searched: 'provolone'
# {'cost': 1.0, 'calories': 90}
# Category: vegetables
# Category: condiments
# Ingredient Type: sauce
# Ingredient being searched: 'sauce'
# {'cost': 0.5, 'calories': 50}
# Category: spices
# Total Cost: 3.5
# Total Calories: 290
# Rating: 4
# {'ingredients': {'breads': {}, 'meats': {'meatball': ['meatball']}, 'cheeses': {'provolone': ['provolone']}, 'vegetables': {}, 'condiments': {'sauce': ['marinara sauce', 'garlic sauce']}, 'spices': {}}, 'cost': 3.5, 'calories': 290, 'rating': 4, 'dietary_tags': [], 'review_count': 1, 'reviews': []}
# Cost: 14.69
#
#
#
#
# Parsing sandwich...
# ID: 13
# Cuisine: None
# Restaurant: mr_pickles
# Name: Got Beef
# Ingredient: 'roast beef'
# Ingredient: 'pastrami'
# Ingredient: 'monterey jack'
# Ingredient: 'mayonnaise'
# Ingredient: 'mustard'
# Ingredient: 'garlic sauce'
# Ingredient: 'tomato'
# Ingredient: 'onion'
# Ingredient: 'pickle'
# Ingredient: 'pepperoncini'
# Ingredient: 'lettuce'
# Category: breads
# Category: meats
# Ingredient Type: beef
# Ingredient being searched: 'beef'
# {'cost': 3.0, 'calories': 250}
# Ingredient Type: pastrami
# Ingredient being searched: 'pastrami'
# {'cost': 2.0, 'calories': 120}
# Category: cheeses
# Ingredient Type: monterey jack
# Ingredient being searched: 'monterey jack'
# {'cost': 1.0, 'calories': 90}
# Category: vegetables
# Ingredient Type: tomato
# Ingredient being searched: 'tomato'
# {'cost': 0.6, 'calories': 20}
# Ingredient Type: onion
# Ingredient being searched: 'onion'
# {'cost': 0.4, 'calories': 40}
# Ingredient Type: pickle
# Ingredient being searched: 'pickle'
# {'cost': 0.5, 'calories': 5}
# Ingredient Type: pepper
# Ingredient being searched: 'pepper'
# {'cost': 0.7, 'calories': 20}
# Ingredient Type: lettuce
# Ingredient being searched: 'lettuce'
# {'cost': 0.5, 'calories': 10}
# Category: condiments
# Ingredient Type: mayonnaise
# Ingredient being searched: 'mayonnaise'
# {'cost': 1.0, 'calories': 100}
# Ingredient Type: mustard
# Ingredient being searched: 'mustard'
# {'cost': 0.5, 'calories': 5}
# Ingredient Type: sauce
# Ingredient being searched: 'sauce'
# {'cost': 0.5, 'calories': 50}
# Category: spices
# Total Cost: 10.7
# Total Calories: 710
# Rating: 4
# {'ingredients': {'breads': {}, 'meats': {'beef': ['roast beef'], 'pastrami': ['pastrami']}, 'cheeses': {'monterey jack': ['monterey jack']}, 'vegetables': {'tomato': ['tomato'], 'onion': ['onion'], 'pickle': ['pickle'], 'pepper': ['pepperoncini'], 'lettuce': ['lettuce']}, 'condiments': {'mayonnaise': ['mayonnaise'], 'mustard': ['mustard'], 'sauce': ['garlic sauce']}, 'spices': {}}, 'cost': 10.7, 'calories': 710, 'rating': 4, 'dietary_tags': [], 'review_count': 1, 'reviews': []}
# Cost: 14.99
#
#
#
#
# Parsing sandwich...
# ID: 14
# Cuisine: None
# Restaurant: mr_pickles
# Name: French Dip
# Ingredient: 'roast beef'
# Ingredient: 'swis'
# Ingredient: 'horseradish mayo'
# Ingredient: 'garlic sauce'
# Ingredient: 'au ju'
# Category: breads
# Category: meats
# Ingredient Type: beef
# Ingredient being searched: 'beef'
# {'cost': 3.0, 'calories': 250}
# Category: cheeses
# Category: vegetables
# Category: condiments
# Ingredient Type: horseradish
# Ingredient being searched: 'horseradish'
# {'cost': 0.8, 'calories': 10}
# Ingredient Type: sauce
# Ingredient being searched: 'sauce'
# {'cost': 0.5, 'calories': 50}
# Category: spices
# Total Cost: 4.3
# Total Calories: 310
# Rating: 5
# {'ingredients': {'breads': {}, 'meats': {'beef': ['roast beef']}, 'cheeses': {}, 'vegetables': {}, 'condiments': {'horseradish': ['horseradish mayo'], 'sauce': ['garlic sauce']}, 'spices': {}}, 'cost': 4.3, 'calories': 310, 'rating': 5, 'dietary_tags': [], 'review_count': 1, 'reviews': []}
# Cost: 14.99
#
#
#
#
# Parsing sandwich...
# ID: 15
# Cuisine: None
# Restaurant: mr_pickles
# Name: Baja Cheesesteak
# Ingredient: 'roast beef'
# Ingredient: 'pepper jack'
# Ingredient: 'baja sauce'
# Ingredient: 'red bell pepper'
# Ingredient: 'onion'
# Ingredient: 'pepperoncini'
# Category: breads
# Category: meats
# Ingredient Type: beef
# Ingredient being searched: 'beef'
# {'cost': 3.0, 'calories': 250}
# Category: cheeses
# Ingredient Type: pepper jack
# Ingredient being searched: 'pepper jack'
# {'cost': 1.0, 'calories': 90}
# Category: vegetables
# Ingredient Type: pepper
# Ingredient being searched: 'pepper'
# {'cost': 0.7, 'calories': 20}
# Ingredient Type: onion
# Ingredient being searched: 'onion'
# {'cost': 0.4, 'calories': 40}
# Category: condiments
# Ingredient Type: sauce
# Ingredient being searched: 'sauce'
# {'cost': 0.5, 'calories': 50}
# Category: spices
# Total Cost: 5.6
# Total Calories: 450
# Rating: 5
# {'ingredients': {'breads': {}, 'meats': {'beef': ['roast beef']}, 'cheeses': {'pepper jack': ['pepper jack']}, 'vegetables': {'pepper': ['red bell pepper', 'pepperoncini'], 'onion': ['onion']}, 'condiments': {'sauce': ['baja sauce']}, 'spices': {}}, 'cost': 5.6, 'calories': 450, 'rating': 5, 'dietary_tags': [], 'review_count': 1, 'reviews': []}
# Cost: 14.99
#
#
#
#
# Parsing sandwich...
# ID: 16
# Cuisine: None
# Restaurant: mr_pickles
# Name: Santa Maria Tri-Tip
# Ingredient: 'tri-tip'
# Ingredient: 'mayonnaise'
# Ingredient: 'mustard'
# Ingredient: 'garlic sauce'
# Ingredient: 'tomato'
# Ingredient: 'onion'
# Ingredient: 'pickle'
# Ingredient: 'pepperoncini'
# Ingredient: 'lettuce'
# Category: breads
# Category: meats
# Category: cheeses
# Category: vegetables
# Ingredient Type: tomato
# Ingredient being searched: 'tomato'
# {'cost': 0.6, 'calories': 20}
# Ingredient Type: onion
# Ingredient being searched: 'onion'
# {'cost': 0.4, 'calories': 40}
# Ingredient Type: pickle
# Ingredient being searched: 'pickle'
# {'cost': 0.5, 'calories': 5}
# Ingredient Type: pepper
# Ingredient being searched: 'pepper'
# {'cost': 0.7, 'calories': 20}
# Ingredient Type: lettuce
# Ingredient being searched: 'lettuce'
# {'cost': 0.5, 'calories': 10}
# Category: condiments
# Ingredient Type: mayonnaise
# Ingredient being searched: 'mayonnaise'
# {'cost': 1.0, 'calories': 100}
# Ingredient Type: mustard
# Ingredient being searched: 'mustard'
# {'cost': 0.5, 'calories': 5}
# Ingredient Type: sauce
# Ingredient being searched: 'sauce'
# {'cost': 0.5, 'calories': 50}
# Category: spices
# Total Cost: 4.7
# Total Calories: 250
# Rating: 4
# {'ingredients': {'breads': {}, 'meats': {}, 'cheeses': {}, 'vegetables': {'tomato': ['tomato'], 'onion': ['onion'], 'pickle': ['pickle'], 'pepper': ['pepperoncini'], 'lettuce': ['lettuce']}, 'condiments': {'mayonnaise': ['mayonnaise'], 'mustard': ['mustard'], 'sauce': ['garlic sauce']}, 'spices': {}}, 'cost': 4.7, 'calories': 250, 'rating': 4, 'dietary_tags': ['vegan'], 'review_count': 1, 'reviews': []}
# Cost: 15.99
#
#
#
#
# Parsing sandwich...
# ID: 17
# Cuisine: None
# Restaurant: mr_pickles
# Name: Goomba
# Ingredient: 'ham'
# Ingredient: 'capicola'
# Ingredient: 'salami'
# Ingredient: 'pepperoni'
# Ingredient: 'provolone'
# Ingredient: 'red wine vinegar'
# Ingredient: 'tomato'
# Ingredient: 'onion'
# Ingredient: 'pickle'
# Ingredient: 'pepperoncini'
# Ingredient: 'lettuce'
# Category: breads
# Category: meats
# Ingredient Type: ham
# Ingredient being searched: 'ham'
# {'cost': 2.0, 'calories': 150}
# Ingredient Type: capicola
# Ingredient being searched: 'capicola'
# {'cost': 2.5, 'calories': 90}
# Ingredient Type: salami
# Ingredient being searched: 'salami'
# {'cost': 2.0, 'calories': 120}
# Ingredient Type: pepperoni
# Ingredient being searched: 'pepperoni'
# {'cost': 1.5, 'calories': 80}
# Category: cheeses
# Ingredient Type: provolone
# Ingredient being searched: 'provolone'
# {'cost': 1.0, 'calories': 90}
# Category: vegetables
# Ingredient Type: tomato
# Ingredient being searched: 'tomato'
# {'cost': 0.6, 'calories': 20}
# Ingredient Type: onion
# Ingredient being searched: 'onion'
# {'cost': 0.4, 'calories': 40}
# Ingredient Type: pickle
# Ingredient being searched: 'pickle'
# {'cost': 0.5, 'calories': 5}
# Ingredient Type: pepper
# Ingredient being searched: 'pepper'
# {'cost': 0.7, 'calories': 20}
# Ingredient Type: lettuce
# Ingredient being searched: 'lettuce'
# {'cost': 0.5, 'calories': 10}
# Category: condiments
# Ingredient Type: vinegar
# Ingredient being searched: 'vinegar'
# {'cost': 0.3, 'calories': 0}
# Category: spices
# Total Cost: 12.0
# Total Calories: 625
# Rating: 3
# {'ingredients': {'breads': {}, 'meats': {'ham': ['ham'], 'capicola': ['capicola'], 'salami': ['salami'], 'pepperoni': ['pepperoni']}, 'cheeses': {'provolone': ['provolone']}, 'vegetables': {'tomato': ['tomato'], 'onion': ['onion'], 'pickle': ['pickle'], 'pepper': ['pepperoncini'], 'lettuce': ['lettuce']}, 'condiments': {'vinegar': ['red wine vinegar']}, 'spices': {}}, 'cost': 12.0, 'calories': 625, 'rating': 3, 'dietary_tags': [], 'review_count': 1, 'reviews': []}
# Cost: 14.39
#
#
#
#
# Parsing sandwich...
# ID: 18
# Cuisine: None
# Restaurant: mr_pickles
# Name: Listen Linda
# Ingredient: 'turkey breast'
# Ingredient: 'bacon'
# Ingredient: 'swis'
# Ingredient: 'avocado'
# Ingredient: 'mayonnaise'
# Ingredient: 'mustard'
# Ingredient: 'garlic sauce'
# Ingredient: 'tomato'
# Ingredient: 'onion'
# Ingredient: 'pickle'
# Ingredient: 'pepperoncini'
# Ingredient: 'lettuce'
# Category: breads
# Category: meats
# Ingredient Type: turkey
# Ingredient being searched: 'turkey'
# {'cost': 2.5, 'calories': 180}
# Ingredient Type: bacon
# Ingredient being searched: 'bacon'
# {'cost': 1.0, 'calories': 50}
# Category: cheeses
# Category: vegetables
# Ingredient Type: avocado
# Ingredient being searched: 'avocado'
# {'cost': 1.5, 'calories': 150}
# Ingredient Type: tomato
# Ingredient being searched: 'tomato'
# {'cost': 0.6, 'calories': 20}
# Ingredient Type: onion
# Ingredient being searched: 'onion'
# {'cost': 0.4, 'calories': 40}
# Ingredient Type: pickle
# Ingredient being searched: 'pickle'
# {'cost': 0.5, 'calories': 5}
# Ingredient Type: pepper
# Ingredient being searched: 'pepper'
# {'cost': 0.7, 'calories': 20}
# Ingredient Type: lettuce
# Ingredient being searched: 'lettuce'
# {'cost': 0.5, 'calories': 10}
# Category: condiments
# Ingredient Type: mayonnaise
# Ingredient being searched: 'mayonnaise'
# {'cost': 1.0, 'calories': 100}
# Ingredient Type: mustard
# Ingredient being searched: 'mustard'
# {'cost': 0.5, 'calories': 5}
# Ingredient Type: sauce
# Ingredient being searched: 'sauce'
# {'cost': 0.5, 'calories': 50}
# Category: spices
# Total Cost: 9.7
# Total Calories: 630
# Rating: 2
# {'ingredients': {'breads': {}, 'meats': {'turkey': ['turkey breast'], 'bacon': ['bacon']}, 'cheeses': {}, 'vegetables': {'avocado': ['avocado'], 'tomato': ['tomato'], 'onion': ['onion'], 'pickle': ['pickle'], 'pepper': ['pepperoncini'], 'lettuce': ['lettuce']}, 'condiments': {'mayonnaise': ['mayonnaise'], 'mustard': ['mustard'], 'sauce': ['garlic sauce']}, 'spices': {}}, 'cost': 9.7, 'calories': 630, 'rating': 2, 'dietary_tags': [], 'review_count': 1, 'reviews': []}
# Cost: 14.69
#
#
#
#
# Parsing sandwich...
# ID: 19
# Cuisine: None
# Restaurant: mr_pickles
# Name: Big Jake
# Ingredient: 'turkey breast'
# Ingredient: 'cream cheese'
# Ingredient: 'avocado'
# Ingredient: 'mayonnaise'
# Ingredient: 'mustard'
# Ingredient: 'garlic sauce'
# Ingredient: 'tomato'
# Ingredient: 'onion'
# Ingredient: 'pickle'
# Ingredient: 'pepperoncini'
# Ingredient: 'lettuce'
# Category: breads
# Category: meats
# Ingredient Type: turkey
# Ingredient being searched: 'turkey'
# {'cost': 2.5, 'calories': 180}
# Category: cheeses
# Ingredient Type: cream cheese
# Ingredient being searched: 'cream cheese'
# {'cost': 0.8, 'calories': 50}
# Category: vegetables
# Ingredient Type: avocado
# Ingredient being searched: 'avocado'
# {'cost': 1.5, 'calories': 150}
# Ingredient Type: tomato
# Ingredient being searched: 'tomato'
# {'cost': 0.6, 'calories': 20}
# Ingredient Type: onion
# Ingredient being searched: 'onion'
# {'cost': 0.4, 'calories': 40}
# Ingredient Type: pickle
# Ingredient being searched: 'pickle'
# {'cost': 0.5, 'calories': 5}
# Ingredient Type: pepper
# Ingredient being searched: 'pepper'
# {'cost': 0.7, 'calories': 20}
# Ingredient Type: lettuce
# Ingredient being searched: 'lettuce'
# {'cost': 0.5, 'calories': 10}
# Category: condiments
# Ingredient Type: mayonnaise
# Ingredient being searched: 'mayonnaise'
# {'cost': 1.0, 'calories': 100}
# Ingredient Type: mustard
# Ingredient being searched: 'mustard'
# {'cost': 0.5, 'calories': 5}
# Ingredient Type: sauce
# Ingredient being searched: 'sauce'
# {'cost': 0.5, 'calories': 50}
# Category: spices
# Total Cost: 9.5
# Total Calories: 630
# Rating: 1
# {'ingredients': {'breads': {}, 'meats': {'turkey': ['turkey breast']}, 'cheeses': {'cream cheese': ['cream cheese']}, 'vegetables': {'avocado': ['avocado'], 'tomato': ['tomato'], 'onion': ['onion'], 'pickle': ['pickle'], 'pepper': ['pepperoncini'], 'lettuce': ['lettuce']}, 'condiments': {'mayonnaise': ['mayonnaise'], 'mustard': ['mustard'], 'sauce': ['garlic sauce']}, 'spices': {}}, 'cost': 9.5, 'calories': 630, 'rating': 1, 'dietary_tags': [], 'review_count': 1, 'reviews': []}
# Cost: 14.69
#
#
#
#
# Parsing sandwich...
# ID: 20
# Cuisine: None
# Restaurant: mr_pickles
# Name: Italian
# Ingredient: 'pastrami'
# Ingredient: 'ham'
# Ingredient: 'salami'
# Ingredient: 'provolone'
# Ingredient: 'italian dressing'
# Ingredient: 'mayonnaise'
# Ingredient: 'mustard'
# Ingredient: 'garlic sauce'
# Ingredient: 'tomato'
# Ingredient: 'onion'
# Ingredient: 'pickle'
# Ingredient: 'pepperoncini'
# Ingredient: 'lettuce'
# Category: breads
# Category: meats
# Ingredient Type: pastrami
# Ingredient being searched: 'pastrami'
# {'cost': 2.0, 'calories': 120}
# Ingredient Type: ham
# Ingredient being searched: 'ham'
# {'cost': 2.0, 'calories': 150}
# Ingredient Type: salami
# Ingredient being searched: 'salami'
# {'cost': 2.0, 'calories': 120}
# Category: cheeses
# Ingredient Type: provolone
# Ingredient being searched: 'provolone'
# {'cost': 1.0, 'calories': 90}
# Category: vegetables
# Ingredient Type: tomato
# Ingredient being searched: 'tomato'
# {'cost': 0.6, 'calories': 20}
# Ingredient Type: onion
# Ingredient being searched: 'onion'
# {'cost': 0.4, 'calories': 40}
# Ingredient Type: pickle
# Ingredient being searched: 'pickle'
# {'cost': 0.5, 'calories': 5}
# Ingredient Type: pepper
# Ingredient being searched: 'pepper'
# {'cost': 0.7, 'calories': 20}
# Ingredient Type: lettuce
# Ingredient being searched: 'lettuce'
# {'cost': 0.5, 'calories': 10}
# Category: condiments
# Ingredient Type: dressing
# Ingredient being searched: 'dressing'
# {'cost': 1.0, 'calories': 80}
# Ingredient Type: mayonnaise
# Ingredient being searched: 'mayonnaise'
# {'cost': 1.0, 'calories': 100}
# Ingredient Type: mustard
# Ingredient being searched: 'mustard'
# {'cost': 0.5, 'calories': 5}
# Ingredient Type: sauce
# Ingredient being searched: 'sauce'
# {'cost': 0.5, 'calories': 50}
# Category: spices
# Total Cost: 12.7
# Total Calories: 810
# Rating: 2
# {'ingredients': {'breads': {}, 'meats': {'pastrami': ['pastrami'], 'ham': ['ham'], 'salami': ['salami']}, 'cheeses': {'provolone': ['provolone']}, 'vegetables': {'tomato': ['tomato'], 'onion': ['onion'], 'pickle': ['pickle'], 'pepper': ['pepperoncini'], 'lettuce': ['lettuce']}, 'condiments': {'dressing': ['italian dressing'], 'mayonnaise': ['mayonnaise'], 'mustard': ['mustard'], 'sauce': ['garlic sauce']}, 'spices': {}}, 'cost': 12.7, 'calories': 810, 'rating': 2, 'dietary_tags': [], 'review_count': 1, 'reviews': []}
# Cost: 14.39
#
#
#
#
# Parsing sandwich...
# ID: 21
# Cuisine: None
# Restaurant: mr_pickles
# Name: Tom Turkey
# Ingredient: 'turkey breast'
# Ingredient: 'bacon'
# Ingredient: 'swis'
# Ingredient: 'mayonnaise'
# Ingredient: 'mustard'
# Ingredient: 'garlic sauce'
# Ingredient: 'tomato'
# Ingredient: 'onion'
# Ingredient: 'pickle'
# Ingredient: 'pepperoncini'
# Ingredient: 'lettuce'
# Category: breads
# Category: meats
# Ingredient Type: turkey
# Ingredient being searched: 'turkey'
# {'cost': 2.5, 'calories': 180}
# Ingredient Type: bacon
# Ingredient being searched: 'bacon'
# {'cost': 1.0, 'calories': 50}
# Category: cheeses
# Category: vegetables
# Ingredient Type: tomato
# Ingredient being searched: 'tomato'
# {'cost': 0.6, 'calories': 20}
# Ingredient Type: onion
# Ingredient being searched: 'onion'
# {'cost': 0.4, 'calories': 40}
# Ingredient Type: pickle
# Ingredient being searched: 'pickle'
# {'cost': 0.5, 'calories': 5}
# Ingredient Type: pepper
# Ingredient being searched: 'pepper'
# {'cost': 0.7, 'calories': 20}
# Ingredient Type: lettuce
# Ingredient being searched: 'lettuce'
# {'cost': 0.5, 'calories': 10}
# Category: condiments
# Ingredient Type: mayonnaise
# Ingredient being searched: 'mayonnaise'
# {'cost': 1.0, 'calories': 100}
# Ingredient Type: mustard
# Ingredient being searched: 'mustard'
# {'cost': 0.5, 'calories': 5}
# Ingredient Type: sauce
# Ingredient being searched: 'sauce'
# {'cost': 0.5, 'calories': 50}
# Category: spices
# Total Cost: 8.2
# Total Calories: 480
# Rating: 5
# {'ingredients': {'breads': {}, 'meats': {'turkey': ['turkey breast'], 'bacon': ['bacon']}, 'cheeses': {}, 'vegetables': {'tomato': ['tomato'], 'onion': ['onion'], 'pickle': ['pickle'], 'pepper': ['pepperoncini'], 'lettuce': ['lettuce']}, 'condiments': {'mayonnaise': ['mayonnaise'], 'mustard': ['mustard'], 'sauce': ['garlic sauce']}, 'spices': {}}, 'cost': 8.2, 'calories': 480, 'rating': 5, 'dietary_tags': [], 'review_count': 1, 'reviews': []}
# Cost: 14.39
#
#
#
#
# Parsing sandwich...
# ID: 22
# Cuisine: None
# Restaurant: mr_pickles
# Name: Della's Deli
# Ingredient: 'turkey breast'
# Ingredient: 'salami'
# Ingredient: 'ham'
# Ingredient: 'cheddar'
# Ingredient: 'mayonnaise'
# Ingredient: 'mustard'
# Ingredient: 'garlic sauce'
# Ingredient: 'tomato'
# Ingredient: 'onion'
# Ingredient: 'pickle'
# Ingredient: 'pepperoncini'
# Ingredient: 'lettuce'
# Category: breads
# Category: meats
# Ingredient Type: turkey
# Ingredient being searched: 'turkey'
# {'cost': 2.5, 'calories': 180}
# Ingredient Type: salami
# Ingredient being searched: 'salami'
# {'cost': 2.0, 'calories': 120}
# Ingredient Type: ham
# Ingredient being searched: 'ham'
# {'cost': 2.0, 'calories': 150}
# Category: cheeses
# Ingredient Type: cheddar
# Ingredient being searched: 'cheddar'
# {'cost': 1.0, 'calories': 110}
# Category: vegetables
# Ingredient Type: tomato
# Ingredient being searched: 'tomato'
# {'cost': 0.6, 'calories': 20}
# Ingredient Type: onion
# Ingredient being searched: 'onion'
# {'cost': 0.4, 'calories': 40}
# Ingredient Type: pickle
# Ingredient being searched: 'pickle'
# {'cost': 0.5, 'calories': 5}
# Ingredient Type: pepper
# Ingredient being searched: 'pepper'
# {'cost': 0.7, 'calories': 20}
# Ingredient Type: lettuce
# Ingredient being searched: 'lettuce'
# {'cost': 0.5, 'calories': 10}
# Category: condiments
# Ingredient Type: mayonnaise
# Ingredient being searched: 'mayonnaise'
# {'cost': 1.0, 'calories': 100}
# Ingredient Type: mustard
# Ingredient being searched: 'mustard'
# {'cost': 0.5, 'calories': 5}
# Ingredient Type: sauce
# Ingredient being searched: 'sauce'
# {'cost': 0.5, 'calories': 50}
# Category: spices
# Total Cost: 12.2
# Total Calories: 810
# Rating: 2
# {'ingredients': {'breads': {}, 'meats': {'turkey': ['turkey breast'], 'salami': ['salami'], 'ham': ['ham']}, 'cheeses': {'cheddar': ['cheddar']}, 'vegetables': {'tomato': ['tomato'], 'onion': ['onion'], 'pickle': ['pickle'], 'pepper': ['pepperoncini'], 'lettuce': ['lettuce']}, 'condiments': {'mayonnaise': ['mayonnaise'], 'mustard': ['mustard'], 'sauce': ['garlic sauce']}, 'spices': {}}, 'cost': 12.2, 'calories': 810, 'rating': 2, 'dietary_tags': [], 'review_count': 1, 'reviews': []}
# Cost: 14.39
#
#
#
#
# Parsing sandwich...
# ID: 23
# Cuisine: None
# Restaurant: mr_pickles
# Name: Big Easy
# Ingredient: 'chicken salad'
# Ingredient: 'swis'
# Ingredient: 'avocado'
# Ingredient: 'mayonnaise'
# Ingredient: 'mustard'
# Ingredient: 'garlic sauce'
# Ingredient: 'tomato'
# Ingredient: 'onion'
# Ingredient: 'pickle'
# Ingredient: 'pepperoncini'
# Ingredient: 'lettuce'
# Category: breads
# Category: meats
# Ingredient Type: chicken
# Ingredient being searched: 'chicken'
# {'cost': 2.0, 'calories': 200}
# Category: cheeses
# Category: vegetables
# Ingredient Type: avocado
# Ingredient being searched: 'avocado'
# {'cost': 1.5, 'calories': 150}
# Ingredient Type: tomato
# Ingredient being searched: 'tomato'
# {'cost': 0.6, 'calories': 20}
# Ingredient Type: onion
# Ingredient being searched: 'onion'
# {'cost': 0.4, 'calories': 40}
# Ingredient Type: pickle
# Ingredient being searched: 'pickle'
# {'cost': 0.5, 'calories': 5}
# Ingredient Type: pepper
# Ingredient being searched: 'pepper'
# {'cost': 0.7, 'calories': 20}
# Ingredient Type: lettuce
# Ingredient being searched: 'lettuce'
# {'cost': 0.5, 'calories': 10}
# Category: condiments
# Ingredient Type: mayonnaise
# Ingredient being searched: 'mayonnaise'
# {'cost': 1.0, 'calories': 100}
# Ingredient Type: mustard
# Ingredient being searched: 'mustard'
# {'cost': 0.5, 'calories': 5}
# Ingredient Type: sauce
# Ingredient being searched: 'sauce'
# {'cost': 0.5, 'calories': 50}
# Category: spices
# Total Cost: 8.2
# Total Calories: 600
# Rating: 4
# {'ingredients': {'breads': {}, 'meats': {'chicken': ['chicken salad']}, 'cheeses': {}, 'vegetables': {'avocado': ['avocado'], 'tomato': ['tomato'], 'onion': ['onion'], 'pickle': ['pickle'], 'pepper': ['pepperoncini'], 'lettuce': ['lettuce']}, 'condiments': {'mayonnaise': ['mayonnaise'], 'mustard': ['mustard'], 'sauce': ['garlic sauce']}, 'spices': {}}, 'cost': 8.2, 'calories': 600, 'rating': 4, 'dietary_tags': [], 'review_count': 1, 'reviews': []}
# Cost: 14.39
#
#
#
#
# Parsing sandwich...
# ID: 24
# Cuisine: None
# Restaurant: mr_pickles
# Name: Cali Tuna
# Ingredient: 'albacore tuna salad'
# Ingredient: 'swis'
# Ingredient: 'avocado'
# Ingredient: 'cucumber'
# Ingredient: 'mayonnaise'
# Ingredient: 'mustard'
# Ingredient: 'garlic sauce'
# Ingredient: 'tomato'
# Ingredient: 'onion'
# Ingredient: 'pickle'
# Ingredient: 'pepperoncini'
# Ingredient: 'lettuce'
# Category: breads
# Category: meats
# Ingredient Type: tuna
# Ingredient being searched: 'tuna'
# {'cost': 2.0, 'calories': 150}
# Category: cheeses
# Category: vegetables
# Ingredient Type: avocado
# Ingredient being searched: 'avocado'
# {'cost': 1.5, 'calories': 150}
# Ingredient Type: cucumber
# Ingredient being searched: 'cucumber'
# {'cost': 0.4, 'calories': 10}
# Ingredient Type: tomato
# Ingredient being searched: 'tomato'
# {'cost': 0.6, 'calories': 20}
# Ingredient Type: onion
# Ingredient being searched: 'onion'
# {'cost': 0.4, 'calories': 40}
# Ingredient Type: pickle
# Ingredient being searched: 'pickle'
# {'cost': 0.5, 'calories': 5}
# Ingredient Type: pepper
# Ingredient being searched: 'pepper'
# {'cost': 0.7, 'calories': 20}
# Ingredient Type: lettuce
# Ingredient being searched: 'lettuce'
# {'cost': 0.5, 'calories': 10}
# Category: condiments
# Ingredient Type: mayonnaise
# Ingredient being searched: 'mayonnaise'
# {'cost': 1.0, 'calories': 100}
# Ingredient Type: mustard
# Ingredient being searched: 'mustard'
# {'cost': 0.5, 'calories': 5}
# Ingredient Type: sauce
# Ingredient being searched: 'sauce'
# {'cost': 0.5, 'calories': 50}
# Category: spices
# Total Cost: 8.6
# Total Calories: 560
# Rating: 3
# {'ingredients': {'breads': {}, 'meats': {'tuna': ['albacore tuna salad']}, 'cheeses': {}, 'vegetables': {'avocado': ['avocado'], 'cucumber': ['cucumber'], 'tomato': ['tomato'], 'onion': ['onion'], 'pickle': ['pickle'], 'pepper': ['pepperoncini'], 'lettuce': ['lettuce']}, 'condiments': {'mayonnaise': ['mayonnaise'], 'mustard': ['mustard'], 'sauce': ['garlic sauce']}, 'spices': {}}, 'cost': 8.6, 'calories': 560, 'rating': 3, 'dietary_tags': [], 'review_count': 1, 'reviews': []}
# Cost: 15.39
#
#
#
#
# Parsing sandwich...
# ID: 25
# Cuisine: None
# Restaurant: mr_pickles
# Name: The Hero
# Ingredient: 'roast beef'
# Ingredient: 'turkey breast'
# Ingredient: 'ham'
# Ingredient: 'cheddar'
# Ingredient: 'mayonnaise'
# Ingredient: 'mustard'
# Ingredient: 'garlic sauce'
# Ingredient: 'tomato'
# Ingredient: 'onion'
# Ingredient: 'pickle'
# Ingredient: 'pepperoncini'
# Ingredient: 'lettuce'
# Category: breads
# Category: meats
# Ingredient Type: beef
# Ingredient being searched: 'beef'
# {'cost': 3.0, 'calories': 250}
# Ingredient Type: turkey
# Ingredient being searched: 'turkey'
# {'cost': 2.5, 'calories': 180}
# Ingredient Type: ham
# Ingredient being searched: 'ham'
# {'cost': 2.0, 'calories': 150}
# Category: cheeses
# Ingredient Type: cheddar
# Ingredient being searched: 'cheddar'
# {'cost': 1.0, 'calories': 110}
# Category: vegetables
# Ingredient Type: tomato
# Ingredient being searched: 'tomato'
# {'cost': 0.6, 'calories': 20}
# Ingredient Type: onion
# Ingredient being searched: 'onion'
# {'cost': 0.4, 'calories': 40}
# Ingredient Type: pickle
# Ingredient being searched: 'pickle'
# {'cost': 0.5, 'calories': 5}
# Ingredient Type: pepper
# Ingredient being searched: 'pepper'
# {'cost': 0.7, 'calories': 20}
# Ingredient Type: lettuce
# Ingredient being searched: 'lettuce'
# {'cost': 0.5, 'calories': 10}
# Category: condiments
# Ingredient Type: mayonnaise
# Ingredient being searched: 'mayonnaise'
# {'cost': 1.0, 'calories': 100}
# Ingredient Type: mustard
# Ingredient being searched: 'mustard'
# {'cost': 0.5, 'calories': 5}
# Ingredient Type: sauce
# Ingredient being searched: 'sauce'
# {'cost': 0.5, 'calories': 50}
# Category: spices
# Total Cost: 13.2
# Total Calories: 940
# Rating: 3
# {'ingredients': {'breads': {}, 'meats': {'beef': ['roast beef'], 'turkey': ['turkey breast'], 'ham': ['ham']}, 'cheeses': {'cheddar': ['cheddar']}, 'vegetables': {'tomato': ['tomato'], 'onion': ['onion'], 'pickle': ['pickle'], 'pepper': ['pepperoncini'], 'lettuce': ['lettuce']}, 'condiments': {'mayonnaise': ['mayonnaise'], 'mustard': ['mustard'], 'sauce': ['garlic sauce']}, 'spices': {}}, 'cost': 13.2, 'calories': 940, 'rating': 3, 'dietary_tags': [], 'review_count': 1, 'reviews': []}
# Cost: 15.99
#
#
#
#
# Parsing sandwich...
# ID: 26
# Cuisine: None
# Restaurant: mr_pickles
# Name: Veggie Pestoli
# Ingredient: 'pesto aioli'
# Ingredient: 'avocado'
# Ingredient: 'cheddar'
# Ingredient: 'red bell pepper'
# Ingredient: 'cucumber'
# Ingredient: 'tomato'
# Ingredient: 'onion'
# Ingredient: 'pickle'
# Ingredient: 'lettuce'
# Ingredient: 'pepperoncini'
# Category: breads
# Category: meats
# Category: cheeses
# Ingredient Type: cheddar
# Ingredient being searched: 'cheddar'
# {'cost': 1.0, 'calories': 110}
# Category: vegetables
# Ingredient Type: avocado
# Ingredient being searched: 'avocado'
# {'cost': 1.5, 'calories': 150}
# Ingredient Type: pepper
# Ingredient being searched: 'pepper'
# {'cost': 0.7, 'calories': 20}
# Ingredient Type: cucumber
# Ingredient being searched: 'cucumber'
# {'cost': 0.4, 'calories': 10}
# Ingredient Type: tomato
# Ingredient being searched: 'tomato'
# {'cost': 0.6, 'calories': 20}
# Ingredient Type: onion
# Ingredient being searched: 'onion'
# {'cost': 0.4, 'calories': 40}
# Ingredient Type: pickle
# Ingredient being searched: 'pickle'
# {'cost': 0.5, 'calories': 5}
# Ingredient Type: lettuce
# Ingredient being searched: 'lettuce'
# {'cost': 0.5, 'calories': 10}
# Category: condiments
# Ingredient Type: pesto
# Ingredient being searched: 'pesto'
# {'cost': 1.5, 'calories': 80}
# Category: spices
# Total Cost: 7.1
# Total Calories: 445
# Rating: 3
# {'ingredients': {'breads': {}, 'meats': {}, 'cheeses': {'cheddar': ['cheddar']}, 'vegetables': {'avocado': ['avocado'], 'pepper': ['red bell pepper', 'pepperoncini'], 'cucumber': ['cucumber'], 'tomato': ['tomato'], 'onion': ['onion'], 'pickle': ['pickle'], 'lettuce': ['lettuce']}, 'condiments': {'pesto': ['pesto aioli']}, 'spices': {}}, 'cost': 7.1, 'calories': 445, 'rating': 3, 'dietary_tags': ['vegetarian'], 'review_count': 1, 'reviews': []}
# Cost: 13.99
#
#
#
#
# Parsing sandwich...
# ID: 27
# Cuisine: None
# Restaurant: mr_pickles
# Name: Truly Vegan
# Ingredient: 'roasted red pepper hummu'
# Ingredient: 'avocado'
# Ingredient: 'red bell pepper'
# Ingredient: 'cucumber'
# Ingredient: 'tomato'
# Ingredient: 'onion'
# Ingredient: 'pickle'
# Ingredient: 'lettuce'
# Ingredient: 'pepperoncini'
# Ingredient: 'mustard'
# Ingredient: 'garlic sauce'
# Category: breads
# Category: meats
# Category: cheeses
# Category: vegetables
# Ingredient Type: pepper
# Ingredient being searched: 'pepper'
# {'cost': 0.7, 'calories': 20}
# Ingredient Type: avocado
# Ingredient being searched: 'avocado'
# {'cost': 1.5, 'calories': 150}
# Ingredient Type: cucumber
# Ingredient being searched: 'cucumber'
# {'cost': 0.4, 'calories': 10}
# Ingredient Type: tomato
# Ingredient being searched: 'tomato'
# {'cost': 0.6, 'calories': 20}
# Ingredient Type: onion
# Ingredient being searched: 'onion'
# {'cost': 0.4, 'calories': 40}
# Ingredient Type: pickle
# Ingredient being searched: 'pickle'
# {'cost': 0.5, 'calories': 5}
# Ingredient Type: lettuce
# Ingredient being searched: 'lettuce'
# {'cost': 0.5, 'calories': 10}
# Category: condiments
# Ingredient Type: mustard
# Ingredient being searched: 'mustard'
# {'cost': 0.5, 'calories': 5}
# Ingredient Type: sauce
# Ingredient being searched: 'sauce'
# {'cost': 0.5, 'calories': 50}
# Category: spices
# Total Cost: 5.6
# Total Calories: 310
# Rating: 1
# {'ingredients': {'breads': {}, 'meats': {}, 'cheeses': {}, 'vegetables': {'pepper': ['roasted red pepper hummu', 'red bell pepper', 'pepperoncini'], 'avocado': ['avocado'], 'cucumber': ['cucumber'], 'tomato': ['tomato'], 'onion': ['onion'], 'pickle': ['pickle'], 'lettuce': ['lettuce']}, 'condiments': {'mustard': ['mustard'], 'sauce': ['garlic sauce']}, 'spices': {}}, 'cost': 5.6, 'calories': 310, 'rating': 1, 'dietary_tags': ['vegan'], 'review_count': 1, 'reviews': []}
# Cost: 13.99
#
#
#
#
# Parsing sandwich...
# ID: 28
# Cuisine: None
# Restaurant: mr_pickles
# Name: Summer Love Wrap
# Ingredient: 'turkey breast'
# Ingredient: 'avocado'
# Ingredient: 'roasted red pepper hummu'
# Ingredient: 'baja sauce'
# Ingredient: 'mayonnaise'
# Ingredient: 'mustard'
# Ingredient: 'garlic sauce'
# Ingredient: 'tomato'
# Ingredient: 'onion'
# Ingredient: 'pickle'
# Ingredient: 'pepperoncini'
# Ingredient: 'lettuce'
# Ingredient: 'wrap'
# Category: breads
# Ingredient Type: wrap
# Ingredient being searched: 'wrap'
# {'cost': 1.0, 'calories': 150}
# Category: meats
# Ingredient Type: turkey
# Ingredient being searched: 'turkey'
# {'cost': 2.5, 'calories': 180}
# Category: cheeses
# Category: vegetables
# Ingredient Type: avocado
# Ingredient being searched: 'avocado'
# {'cost': 1.5, 'calories': 150}
# Ingredient Type: pepper
# Ingredient being searched: 'pepper'
# {'cost': 0.7, 'calories': 20}
# Ingredient Type: tomato
# Ingredient being searched: 'tomato'
# {'cost': 0.6, 'calories': 20}
# Ingredient Type: onion
# Ingredient being searched: 'onion'
# {'cost': 0.4, 'calories': 40}
# Ingredient Type: pickle
# Ingredient being searched: 'pickle'
# {'cost': 0.5, 'calories': 5}
# Ingredient Type: lettuce
# Ingredient being searched: 'lettuce'
# {'cost': 0.5, 'calories': 10}
# Category: condiments
# Ingredient Type: sauce
# Ingredient being searched: 'sauce'
# {'cost': 0.5, 'calories': 50}
# Ingredient Type: mayonnaise
# Ingredient being searched: 'mayonnaise'
# {'cost': 1.0, 'calories': 100}
# Ingredient Type: mustard
# Ingredient being searched: 'mustard'
# {'cost': 0.5, 'calories': 5}
# Category: spices
# Total Cost: 9.7
# Total Calories: 730
# Rating: 3
# {'ingredients': {'breads': {'wrap': ['wrap']}, 'meats': {'turkey': ['turkey breast']}, 'cheeses': {}, 'vegetables': {'avocado': ['avocado'], 'pepper': ['roasted red pepper hummu', 'pepperoncini'], 'tomato': ['tomato'], 'onion': ['onion'], 'pickle': ['pickle'], 'lettuce': ['lettuce']}, 'condiments': {'sauce': ['baja sauce', 'garlic sauce'], 'mayonnaise': ['mayonnaise'], 'mustard': ['mustard']}, 'spices': {}}, 'cost': 9.7, 'calories': 730, 'rating': 3, 'dietary_tags': [], 'review_count': 1, 'reviews': []}
# Cost: 14.39
#
#
#
#
# Parsing sandwich...
# ID: 29
# Cuisine: None
# Restaurant: mr_pickles
# Name: Club
# Ingredient: 'turkey breast'
# Ingredient: 'ham'
# Ingredient: 'bacon'
# Ingredient: 'cheddar'
# Ingredient: 'tomato'
# Ingredient: 'lettuce'
# Ingredient: 'mayo'
# Ingredient: 'toasted multi-grain'
# Category: breads
# Category: meats
# Ingredient Type: turkey
# Ingredient being searched: 'turkey'
# {'cost': 2.5, 'calories': 180}
# Ingredient Type: ham
# Ingredient being searched: 'ham'
# {'cost': 2.0, 'calories': 150}
# Ingredient Type: bacon
# Ingredient being searched: 'bacon'
# {'cost': 1.0, 'calories': 50}
# Category: cheeses
# Ingredient Type: cheddar
# Ingredient being searched: 'cheddar'
# {'cost': 1.0, 'calories': 110}
# Category: vegetables
# Ingredient Type: tomato
# Ingredient being searched: 'tomato'
# {'cost': 0.6, 'calories': 20}
# Ingredient Type: lettuce
# Ingredient being searched: 'lettuce'
# {'cost': 0.5, 'calories': 10}
# Category: condiments
# Category: spices
# Total Cost: 7.6
# Total Calories: 520
# Rating: 1
# {'ingredients': {'breads': {}, 'meats': {'turkey': ['turkey breast'], 'ham': ['ham'], 'bacon': ['bacon']}, 'cheeses': {'cheddar': ['cheddar']}, 'vegetables': {'tomato': ['tomato'], 'lettuce': ['lettuce']}, 'condiments': {}, 'spices': {}}, 'cost': 7.6, 'calories': 520, 'rating': 1, 'dietary_tags': [], 'review_count': 1, 'reviews': []}
# Cost: 14.69
#
#
#
#
# Parsing sandwich...
# ID: 30
# Cuisine: None
# Restaurant: mr_pickles
# Name: BLAT
# Ingredient: 'bacon'
# Ingredient: 'lettuce'
# Ingredient: 'avocado'
# Ingredient: 'tomato'
# Ingredient: 'mayo'
# Ingredient: 'toasted multi-grain'
# Category: breads
# Category: meats
# Ingredient Type: bacon
# Ingredient being searched: 'bacon'
# {'cost': 1.0, 'calories': 50}
# Category: cheeses
# Category: vegetables
# Ingredient Type: lettuce
# Ingredient being searched: 'lettuce'
# {'cost': 0.5, 'calories': 10}
# Ingredient Type: avocado
# Ingredient being searched: 'avocado'
# {'cost': 1.5, 'calories': 150}
# Ingredient Type: tomato
# Ingredient being searched: 'tomato'
# {'cost': 0.6, 'calories': 20}
# Category: condiments
# Category: spices
# Total Cost: 3.6
# Total Calories: 230
# Rating: 3
# {'ingredients': {'breads': {}, 'meats': {'bacon': ['bacon']}, 'cheeses': {}, 'vegetables': {'lettuce': ['lettuce'], 'avocado': ['avocado'], 'tomato': ['tomato']}, 'condiments': {}, 'spices': {}}, 'cost': 3.6, 'calories': 230, 'rating': 3, 'dietary_tags': [], 'review_count': 1, 'reviews': []}
# Cost: 14.39
#
#
#
#
# Parsing sandwich...
# ID: 31
# Cuisine: None
# Restaurant: mr_pickles
# Name: BLT
# Ingredient: 'bacon'
# Ingredient: 'lettuce'
# Ingredient: 'tomato'
# Ingredient: 'mayo'
# Ingredient: 'toasted multi-grain'
# Category: breads
# Category: meats
# Ingredient Type: bacon
# Ingredient being searched: 'bacon'
# {'cost': 1.0, 'calories': 50}
# Category: cheeses
# Category: vegetables
# Ingredient Type: lettuce
# Ingredient being searched: 'lettuce'
# {'cost': 0.5, 'calories': 10}
# Ingredient Type: tomato
# Ingredient being searched: 'tomato'
# {'cost': 0.6, 'calories': 20}
# Category: condiments
# Category: spices
# Total Cost: 2.1
# Total Calories: 80
# Rating: 1
# {'ingredients': {'breads': {}, 'meats': {'bacon': ['bacon']}, 'cheeses': {}, 'vegetables': {'lettuce': ['lettuce'], 'tomato': ['tomato']}, 'condiments': {}, 'spices': {}}, 'cost': 2.1, 'calories': 80, 'rating': 1, 'dietary_tags': [], 'review_count': 1, 'reviews': []}
# Cost: 14.39
