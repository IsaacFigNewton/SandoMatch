# %%
import random
import re
import pandas as pd
import numpy as np
import json
import requests
from google.colab import files

# %% [markdown]
# # Config

# %%
originating_restaurant = "subway"
restaurant_path = f"https://github.com/IsaacFigNewton/SandoMatch/raw/refs/heads/main/sandwich-dataset/restaurant-sandos/{originating_restaurant}/{originating_restaurant}"

vegetarian_bases = {"egg", "veggie patty"}
vegan_bases = {"veggie patty"}

# Define the set of words to remove
filter_words = {"ground", "chopped", "sliced", "freshly", "fresh"}

# %%
# use this document to determine which ingredients are valid
#   and thus, which will be classified as subtypes of others
json_data = requests.get("https://github.com/IsaacFigNewton/SandoMatch/raw/refs/heads/main/sandwich-dataset/db-entry-requirements/valid_ingredient_types.json").json()

# create lists of equal length for dataframe columns
max_len = max(len(v) for v in json_data.values())

processed_data = {
    k: v + [np.nan] * (max_len - len(v))
    for k, v in json_data.items()
}

valid_ingredients = pd.DataFrame(processed_data)

# %%
valid_ingredients[:50]
# Out:
#             breads        meats          cheeses        vegetables  \
# 0         baguette         beef          cheddar           lettuce
# 1         ciabatta      chicken       mozzarella            tomato
# 2             pita       turkey            swiss             onion
# 3             naan         pork        provolone            pepper
# 4         tortilla          ham             brie           spinach
# 5             roll        bacon       gorgonzola          cucumber
# 6        sourdough      sausage             feta             basil
# 7              rye    bratwurst         parmesan           sprouts
# 8       multigrain       salami            gouda           avocado
# 9      whole wheat   prosciutto          ricotta              kale
# 10     white bread    pepperoni      blue cheese          zucchini
# 11         brioche     pastrami      goat cheese            carrot
# 12        focaccia   mortadella    monterey jack            radish
# 13          panini         lamb     cream cheese            celery
# 14  english muffin         duck  american cheese         mushrooms
# 15           bagel   roast beef            colby            pickle
# 16       croissant         veal      pepper jack          scallion
# 17      milk bread      venison          gruyere        watercress
# 18       flatbread      chorizo        camembert          eggplant
# 19    pumpernickel     capicola           asiago              beet
# 20    pretzel roll     bresaola           romano            fennel
# 21    potato bread     pancetta          havarti         artichoke
# 22         bolillo  smoked fish          burrata            garlic
# 23           torta         tuna    stracciatella             olive
# 24          lavash       shrimp     queso fresco  sun-dried tomato
# 25       cornbread         crab           cotija            kimchi
# 26         chapati      lobster           paneer           cabbage
# 27         paratha    meatballs         halloumi            greens
# 28            wrap  pulled pork              NaN             herbs
# 29             bun     carnitas              NaN               NaN
# 30     steamed bun  corned beef              NaN               NaN
# 31             NaN      brisket              NaN               NaN
# 32             NaN         gyro              NaN               NaN
# 33             NaN     char siu              NaN               NaN
# 34             NaN     shawarma              NaN               NaN
# 35             NaN        jerky              NaN               NaN
#
#       condiments             spices
# 0     mayonnaise               salt
# 1        mustard       black pepper
# 2            oil              cumin
# 3         butter            paprika
# 4        ketchup          coriander
# 5         relish            oregano
# 6        vinegar              basil
# 7       dressing              thyme
# 8          salsa           rosemary
# 9          sauce     cayenne pepper
# 10         pesto       chili powder
# 11   chimichurri           turmeric
# 12         aioli      garlic powder
# 13        tahini       onion powder
# 14         honey            parsley
# 15   horseradish               dill
# 16        hummus           cinnamon
# 17     guacamole             nutmeg
# 18  tartar sauce           allspice
# 19  yogurt sauce             cloves
# 20         dijon           cardamom
# 21      marinara           bay leaf
# 22         glaze            saffron
# 23       chutney               sage
# 24           NaN       mustard seed
# 25           NaN          fenugreek
# 26           NaN              anise
# 27           NaN         five-spice
# 28           NaN       curry powder
# 29           NaN   creole seasoning
# 30           NaN  italian seasoning
# 31           NaN            za'atar
# 32           NaN              sumac
# 33           NaN                NaN
# 34           NaN                NaN
# 35           NaN                NaN

# %% [markdown]
# # Read JSON into Pandas Tables

# %%
sandwiches_table = pd.read_json(f"{restaurant_path}_menu.json")
ingredients_table = pd.read_csv(f"{restaurant_path}_ingredients.csv")

# %% [markdown]
# ## Clean the ingredients table

# %%
ingredients_table['category'] = ingredients_table['category']\
                                                              .str\
                                                              .lower()
ingredients_table['ingredient'] = ingredients_table['ingredient']\
                                                              .str\
                                                              .lower()

# %%
try:
  ingredients_table['cost'] = ingredients_table['cost'].astype(float)
except ValueError as e:
  print(f"Bad cost value: {e}")
  ingredients_table['cost'] = np.nan
try:
  ingredients_table['calories'] = ingredients_table['calories'].astype(int)
except ValueError as e:
  print(f"Bad calorie value: {e}")
  ingredients_table['calories'] = np.nan
# Out:
# Bad calorie value: cannot convert float NaN to integer

# %%
ingredients_table.fillna(0, inplace=True)
ingredients_table["ingredient"] = ingredients_table["ingredient"].apply(lambda x: x.replace(" ", "_"))

# %%
ingredients_table.head()
# Out:
#   category        ingredient  cost  calories
# 0    meats  black_forest_ham  3.75       0.0
# 1    meats  honey-smoked_ham  3.75       0.0
# 2    meats             steak  3.75       0.0
# 3    meats     turkey_breast  3.75       0.0
# 4    meats    chicken_breast  3.75       0.0

# %% [markdown]
# ## Process ingredients table

# %%
ingredients_table_json = {
  "breads": dict(),
  "meats": dict(),
  "vegetables": dict(),
  "cheeses": dict(),
  "condiments": dict(),
  "spices": dict()
}

for _, row in ingredients_table.iterrows():
    category = row['category']\
                .lower()\
                .replace('_', ' ')
    ingredient = row['ingredient']\
                .lower()\
                .replace('_', ' ')

    # print(f"Category: {category}\
    #       \nIngredient: {ingredient}")

    # if the ingredient doesn't exist
    if ingredient not in ingredients_table_json[category].keys():
        ingredients_table_json[category][ingredient] = dict()

    if 'cost' not in ingredients_table_json[category][ingredient].keys():
        ingredients_table_json[category][ingredient]['cost'] = row["cost"]

    # defaults to null if no calorie count provided
    if 'calories' not in ingredients_table_json[category][ingredient].keys():
        ingredients_table_json[category][ingredient]['calories'] = row["calories"]

# %%
ingredients_table = pd\
                      .DataFrame({originating_restaurant: ingredients_table_json})\
                      .transpose()\
                      .reset_index()\
                      .rename(columns={"index": "_id"})
ingredients_table.head()
# Out:
#       _id                                             breads  \
# 0  subway  {'white': {'cost': 4.0, 'calories': 0.0}, '9-g...
#
#                                                meats  \
# 0  {'black forest ham': {'cost': 3.75, 'calories'...
#
#                                           vegetables  \
# 0  {'avocado': {'cost': 0.0, 'calories': 0.0}, 'l...
#
#                                              cheeses  \
# 0  {'smoked cheddar': {'cost': 3.75, 'calories': ...
#
#                                           condiments spices
# 0  {'caesar dressing': {'cost': 0.0, 'calories': ...     {}

# %% [markdown]
# ## Clean sandwich/menu table

# %%
# # only use the default ingredients list, to make ingredient set more generalizable
# ingredients_table = pd\
#                       .read_json("https://github.com/IsaacFigNewton/SandoMatch/raw/refs/heads/main/sandwich-dataset/db-tables/restaurant_ingredients.json")
# ingredients_table = ingredients_table.loc[ingredients_table["_id"] == "default"].drop(columns=["_id"])
# ingredients_table.head()

# %%
# basically reset the indices
sandwiches_table.drop(columns=["id"], inplace=True)

# reset the index
ingredients_table.set_index("_id", inplace=True)

# %%
sandwiches_table.head()
# Out:
#                           name  \
# 0  Elite Chicken & Bacon Ranch
# 1                   The Philly
# 2                  Subway Club
# 3            All-American Club
# 4         The Hotshot Italiano
#
#                                        ingredients   cuisine   cost  calories
# 0  [Chicken Breast, Bacon, Ranch Dressing, Cheese]      None  15.28       580
# 1                                  [Steak, Cheese]  American  13.78       505
# 2    [Turkey Breast, Black Forest Ham, Roast Beef]      None  14.78       500
# 3         [Turkey Breast, Black Forest Ham, Bacon]  American  14.28       540
# 4                   [Genoa Salami, Pepperoni, Ham]   Italian  12.28       630

# %%
ingredients_table.head()
# Out:
#                                                    breads  \
# _id
# subway  {'white': {'cost': 4.0, 'calories': 0.0}, '9-g...
#
#                                                     meats  \
# _id
# subway  {'black forest ham': {'cost': 3.75, 'calories'...
#
#                                                vegetables  \
# _id
# subway  {'avocado': {'cost': 0.0, 'calories': 0.0}, 'l...
#
#                                                   cheeses  \
# _id
# subway  {'smoked cheddar': {'cost': 3.75, 'calories': ...
#
#                                                condiments spices
# _id
# subway  {'caesar dressing': {'cost': 0.0, 'calories': ...     {}

# %% [markdown]
# # Helper Functions

# %%
ingredients_table.head()
# Out:
#                                                    breads  \
# _id
# subway  {'white': {'cost': 4.0, 'calories': 0.0}, '9-g...
#
#                                                     meats  \
# _id
# subway  {'black forest ham': {'cost': 3.75, 'calories'...
#
#                                                vegetables  \
# _id
# subway  {'avocado': {'cost': 0.0, 'calories': 0.0}, 'l...
#
#                                                   cheeses  \
# _id
# subway  {'smoked cheddar': {'cost': 3.75, 'calories': ...
#
#                                                condiments spices
# _id
# subway  {'caesar dressing': {'cost': 0.0, 'calories': ...     {}

# %%
def add_ingredient_to_entry(entry,
                            ingredient,
                            ingredient_category,
                            exclusion_set1="",
                            exclusion_set2="",
                            exclusion_words=set()):
    # print(f"Ingredient Category: {ingredient_category}")
    for ingred_type in valid_ingredients[ingredient_category]:

      # print(f"\t\tIngredient Type: {ingred_type}")
      if not ingred_type is np.nan and ingred_type in ingredient:
          # print(f"\t\tIngredient Type Found in Ingredient: {ingredient}")

          # Build exclusion set
          exclusion_set = exclusion_words
          if exclusion_set1 and exclusion_set2:
              exclusion_set = exclusion_set.union(set(ingredients_table[exclusion_set1].keys()))
              exclusion_set = exclusion_set.union(set(ingredients_table[exclusion_set2].keys()))

          print(f"Exclusion Set: {exclusion_set}")
          # Check for exclusions
          if not any(ex_word in ingredient for ex_word in exclusion_set):

              if ingred_type not in entry["ingredients"][ingredient_category]:
                  entry["ingredients"][ingredient_category][ingred_type] = []

              entry["ingredients"][ingredient_category][ingred_type].append(ingredient)
              break

# %%
def categorize_ingredients(ingredients_dict):
    entry = {
        "ingredients": {
            "breads": dict(),
            "meats": dict(),
            "cheeses": dict(),
            "vegetables": dict(),
            "condiments": dict(),
            "spices": dict()
        },
        "cost": 0,
        "calories": 0,
        "rating": random.randint(1, 5),
        "dietary_tags": [],
        # store reviews as list of {rating, text} objects or maybe object ref ids?
        "reviews": []
    }

    # for each ingredient in a sandwich's recipe
    for ingredient in ingredients_dict:
        # Remove filter words
        pattern = r"\b(" + "|".join(map(re.escape, filter_words)) + r")\b"
        ingredient = re.sub(pattern, "", ingredient.lower()).strip()

        # Simple plural handling
        if ingredient.endswith('s'):
            ingredient = ingredient[:-1]

        print(f"Ingredient: '{ingredient}'")

        add_ingredient_to_entry(entry, ingredient, "breads")
        add_ingredient_to_entry(entry, ingredient, "meats")
        add_ingredient_to_entry(entry, ingredient, "cheeses")
        add_ingredient_to_entry(entry, ingredient, "vegetables",
                                exclusion_set1="condiments",
                                exclusion_set2="spices",
                                exclusion_words={"oil", "pepper jack", "pepperoni"})
        add_ingredient_to_entry(entry, ingredient, "condiments")
        add_ingredient_to_entry(entry, ingredient, "spices")

    # Compute cost and calories
    for category in entry["ingredients"]:
        print(f"Category: {category}")
        for ingredient_type in entry["ingredients"][category]:
            print(f"\tIngredient Type: {ingredient_type}")
            lookup_key = ingredient_type
            print(f"\tIngredient being searched: '{lookup_key}'")

            try:
                ingredient_data = ingredients_table[category][lookup_key]
                print(ingredient_data)

                # Estimate the sandwich's total cost
                entry["cost"] += ingredient_data["cost"]
                # Estimate the sandwich's total calorie count
                entry["calories"] += ingredient_data["calories"]

            except Exception as e:
                print(f"Exception: {e}")
                continue

    # Round the cost and calories to the nearest hundredth
    entry["cost"] = round(entry["cost"], 2)
    entry["calories"] = round(entry["calories"], 2)


    # Add dietary tags based on ingredients
    # If the base is a veggie patty, egg, or vegetable
    sandwich_bases = set(entry["ingredients"]["meats"].keys())
    if (not sandwich_bases.difference(vegan_bases)\
        or not sandwich_bases) and not entry["ingredients"]["cheeses"]:
        entry["dietary_tags"].append("vegan")
    elif not sandwich_bases.difference(vegetarian_bases)\
        or not sandwich_bases:
        entry["dietary_tags"].append("vegetarian")

    print(f"Total Cost: {entry['cost']}")
    print(f"Total Calories: {entry['calories']}")
    print(f"Rating: {entry['rating']}")
    print(entry)
    return entry

# %% [markdown]
# #Main

# %%
def get_sando_name(sandwich, formatted_entry):
  name = ""
  # if a cuisine type was provided, prefix the name with it
  if sandwich.get("cuisine"):
      name = sandwich["cuisine"] + " "

  ingredients = formatted_entry["ingredients"]
  # if a name isn't provided, name it after the first meat in the list
  if len(ingredients["meats"]) > 0:
      name += (list(ingredients["meats"].keys()))[0]
  # or the first cheese
  elif len(ingredients["cheeses"]) > 0:
      name += (list(ingredients["cheeses"].keys()))[0]
  # or the first vegetable
  elif len(ingredients["vegetables"]) > 0:
      name += (list(ingredients["vegetables"].keys()))[0]

  return name

# %%
def format_entry(sandwich):
  formatted_entry = {
      "id_": i,
      "cuisine": sandwich.get("cuisine"),
      "restaurant": None
  }

  # If it's indicated that the sandwich came from a specific restaurant
  if originating_restaurant:
      print(f"Restaurant: {originating_restaurant}")
      formatted_entry["restaurant"] = originating_restaurant

  # If the sandwich entry comes with a sandwich name
  if sandwich.get("name"):
      print(f"Name: {sandwich['name']}")
      formatted_entry["name"] = sandwich["name"]


  formatted_entry.update(categorize_ingredients(sandwich["ingredients"]))

  # if a name was not provided for the sandwich
  if not sandwich.get("name"):
      name = get_sando_name(sandwich, formatted_entry)

      # set the name
      formatted_entry["name"] = (name + " sandwich")\
                                  .replace("_", " ")\
                                  .title()

  # If the sandwich entry comes with a cost, overwrite the estimate
  #   do this after getting the estimate so that future regression models
  #   can be more easily applied to this data
  if sandwich.get("cost"):
      print(f"Cost: {sandwich['cost']}")
      formatted_entry["cost"] = sandwich["cost"]
  if sandwich.get("calories"):
      print(f"Calories: {sandwich['calories']}")
      formatted_entry["calories"] = sandwich["calories"]

  return formatted_entry

# %%
# Reformat every sandwich entry
formatted_sandwiches = []
i = 0
for sandwich_name, sandwich in sandwiches_table.iterrows():
    print("Parsing sandwich...")
    print(f"ID: {sandwich_name}")
    print(f"Cuisine: {sandwich.get('cuisine')}")

    formatted_sandwiches.append(format_entry(sandwich))
    print("\n\n\n")

    i += 1
# Out:
# Parsing sandwich...
# ID: 0
# Cuisine: None
# Restaurant: subway
# Name: Elite Chicken & Bacon Ranch
# Ingredient: 'chicken breast'
# Exclusion Set: set()
# Ingredient: 'bacon'
# Exclusion Set: set()
# Ingredient: 'ranch dressing'
# Exclusion Set: set()
# Ingredient: 'cheese'
# Category: breads
# Category: meats
# 	Ingredient Type: chicken
# 	Ingredient being searched: 'chicken'
# Exception: 'chicken'
# 	Ingredient Type: bacon
# 	Ingredient being searched: 'bacon'
# Exception: 'bacon'
# Category: cheeses
# Category: vegetables
# Category: condiments
# 	Ingredient Type: dressing
# 	Ingredient being searched: 'dressing'
# Exception: 'dressing'
# Category: spices
# Total Cost: 0
# Total Calories: 0
# Rating: 2
# {'ingredients': {'breads': {}, 'meats': {'chicken': ['chicken breast'], 'bacon': ['bacon']}, 'cheeses': {}, 'vegetables': {}, 'condiments': {'dressing': ['ranch dressing']}, 'spices': {}}, 'cost': 0, 'calories': 0, 'rating': 2, 'dietary_tags': [], 'reviews': []}
# Cost: 15.28
# Calories: 580
#
#
#
#
# Parsing sandwich...
# ID: 1
# Cuisine: American
# Restaurant: subway
# Name: The Philly
# Ingredient: 'steak'
# Ingredient: 'cheese'
# Category: breads
# Category: meats
# Category: cheeses
# Category: vegetables
# Category: condiments
# Category: spices
# Total Cost: 0
# Total Calories: 0
# Rating: 1
# {'ingredients': {'breads': {}, 'meats': {}, 'cheeses': {}, 'vegetables': {}, 'condiments': {}, 'spices': {}}, 'cost': 0, 'calories': 0, 'rating': 1, 'dietary_tags': ['vegan'], 'reviews': []}
# Cost: 13.78
# Calories: 505
#
#
#
#
# Parsing sandwich...
# ID: 2
# Cuisine: None
# Restaurant: subway
# Name: Subway Club
# Ingredient: 'turkey breast'
# Exclusion Set: set()
# Ingredient: 'black forest ham'
# Exclusion Set: set()
# Ingredient: 'roast beef'
# Exclusion Set: set()
# Category: breads
# Category: meats
# 	Ingredient Type: turkey
# 	Ingredient being searched: 'turkey'
# Exception: 'turkey'
# 	Ingredient Type: ham
# 	Ingredient being searched: 'ham'
# Exception: 'ham'
# 	Ingredient Type: beef
# 	Ingredient being searched: 'beef'
# Exception: 'beef'
# Category: cheeses
# Category: vegetables
# Category: condiments
# Category: spices
# Total Cost: 0
# Total Calories: 0
# Rating: 1
# {'ingredients': {'breads': {}, 'meats': {'turkey': ['turkey breast'], 'ham': ['black forest ham'], 'beef': ['roast beef']}, 'cheeses': {}, 'vegetables': {}, 'condiments': {}, 'spices': {}}, 'cost': 0, 'calories': 0, 'rating': 1, 'dietary_tags': [], 'reviews': []}
# Cost: 14.78
# Calories: 500
#
#
#
#
# Parsing sandwich...
# ID: 3
# Cuisine: American
# Restaurant: subway
# Name: All-American Club
# Ingredient: 'turkey breast'
# Exclusion Set: set()
# Ingredient: 'black forest ham'
# Exclusion Set: set()
# Ingredient: 'bacon'
# Exclusion Set: set()
# Category: breads
# Category: meats
# 	Ingredient Type: turkey
# 	Ingredient being searched: 'turkey'
# Exception: 'turkey'
# 	Ingredient Type: ham
# 	Ingredient being searched: 'ham'
# Exception: 'ham'
# 	Ingredient Type: bacon
# 	Ingredient being searched: 'bacon'
# Exception: 'bacon'
# Category: cheeses
# Category: vegetables
# Category: condiments
# Category: spices
# Total Cost: 0
# Total Calories: 0
# Rating: 2
# {'ingredients': {'breads': {}, 'meats': {'turkey': ['turkey breast'], 'ham': ['black forest ham'], 'bacon': ['bacon']}, 'cheeses': {}, 'vegetables': {}, 'condiments': {}, 'spices': {}}, 'cost': 0, 'calories': 0, 'rating': 2, 'dietary_tags': [], 'reviews': []}
# Cost: 14.28
# Calories: 540
#
#
#
#
# Parsing sandwich...
# ID: 4
# Cuisine: Italian
# Restaurant: subway
# Name: The Hotshot Italiano
# Ingredient: 'genoa salami'
# Exclusion Set: set()
# Ingredient: 'pepperoni'
# Exclusion Set: set()
# Exclusion Set: {'pepper jack', 'oil', 'subway', 'pepperoni'}
# Ingredient: 'ham'
# Exclusion Set: set()
# Category: breads
# Category: meats
# 	Ingredient Type: salami
# 	Ingredient being searched: 'salami'
# Exception: 'salami'
# 	Ingredient Type: pepperoni
# 	Ingredient being searched: 'pepperoni'
# Exception: 'pepperoni'
# 	Ingredient Type: ham
# 	Ingredient being searched: 'ham'
# Exception: 'ham'
# Category: cheeses
# Category: vegetables
# Category: condiments
# Category: spices
# Total Cost: 0
# Total Calories: 0
# Rating: 3
# {'ingredients': {'breads': {}, 'meats': {'salami': ['genoa salami'], 'pepperoni': ['pepperoni'], 'ham': ['ham']}, 'cheeses': {}, 'vegetables': {}, 'condiments': {}, 'spices': {}}, 'cost': 0, 'calories': 0, 'rating': 3, 'dietary_tags': [], 'reviews': []}
# Cost: 12.28
# Calories: 630
#
#
#
#
# Parsing sandwich...
# ID: 5
# Cuisine: Italian
# Restaurant: subway
# Name: The Ultimate B.M.T.
# Ingredient: 'ham'
# Exclusion Set: set()
# Ingredient: 'genoa salami'
# Exclusion Set: set()
# Ingredient: 'pepperoni'
# Exclusion Set: set()
# Exclusion Set: {'pepper jack', 'oil', 'subway', 'pepperoni'}
# Category: breads
# Category: meats
# 	Ingredient Type: ham
# 	Ingredient being searched: 'ham'
# Exception: 'ham'
# 	Ingredient Type: salami
# 	Ingredient being searched: 'salami'
# Exception: 'salami'
# 	Ingredient Type: pepperoni
# 	Ingredient being searched: 'pepperoni'
# Exception: 'pepperoni'
# Category: cheeses
# Category: vegetables
# Category: condiments
# Category: spices
# Total Cost: 0
# Total Calories: 0
# Rating: 3
# {'ingredients': {'breads': {}, 'meats': {'ham': ['ham'], 'salami': ['genoa salami'], 'pepperoni': ['pepperoni']}, 'cheeses': {}, 'vegetables': {}, 'condiments': {}, 'spices': {}}, 'cost': 0, 'calories': 0, 'rating': 3, 'dietary_tags': [], 'reviews': []}
# Cost: 12.78
# Calories: 560
#
#
#
#
# Parsing sandwich...
# ID: 6
# Cuisine: None
# Restaurant: subway
# Name: Titan Turkey
# Ingredient: 'turkey breast'
# Exclusion Set: set()
# Category: breads
# Category: meats
# 	Ingredient Type: turkey
# 	Ingredient being searched: 'turkey'
# Exception: 'turkey'
# Category: cheeses
# Category: vegetables
# Category: condiments
# Category: spices
# Total Cost: 0
# Total Calories: 0
# Rating: 5
# {'ingredients': {'breads': {}, 'meats': {'turkey': ['turkey breast']}, 'cheeses': {}, 'vegetables': {}, 'condiments': {}, 'spices': {}}, 'cost': 0, 'calories': 0, 'rating': 5, 'dietary_tags': [], 'reviews': []}
# Cost: 12.68
# Calories: 490
#
#
#
#
# Parsing sandwich...
# ID: 7
# Cuisine: None
# Restaurant: subway
# Name: Home Run Ham
# Ingredient: 'ham'
# Exclusion Set: set()
# Category: breads
# Category: meats
# 	Ingredient Type: ham
# 	Ingredient being searched: 'ham'
# Exception: 'ham'
# Category: cheeses
# Category: vegetables
# Category: condiments
# Category: spices
# Total Cost: 0
# Total Calories: 0
# Rating: 5
# {'ingredients': {'breads': {}, 'meats': {'ham': ['ham']}, 'cheeses': {}, 'vegetables': {}, 'condiments': {}, 'spices': {}}, 'cost': 0, 'calories': 0, 'rating': 5, 'dietary_tags': [], 'reviews': []}
# Cost: 12.18
# Calories: 510
#
#
#
#
# Parsing sandwich...
# ID: 8
# Cuisine: BBQ
# Restaurant: subway
# Name: Honey Mustard BBQ Chicken
# Ingredient: 'chicken breast'
# Exclusion Set: set()
# Ingredient: 'honey mustard'
# Exclusion Set: set()
# Category: breads
# Category: meats
# 	Ingredient Type: chicken
# 	Ingredient being searched: 'chicken'
# Exception: 'chicken'
# Category: cheeses
# Category: vegetables
# Category: condiments
# 	Ingredient Type: mustard
# 	Ingredient being searched: 'mustard'
# Exception: 'mustard'
# Category: spices
# Total Cost: 0
# Total Calories: 0
# Rating: 4
# {'ingredients': {'breads': {}, 'meats': {'chicken': ['chicken breast']}, 'cheeses': {}, 'vegetables': {}, 'condiments': {'mustard': ['honey mustard']}, 'spices': {}}, 'cost': 0, 'calories': 0, 'rating': 4, 'dietary_tags': [], 'reviews': []}
# Cost: 13.78
# Calories: 510
#
#
#
#
# Parsing sandwich...
# ID: 9
# Cuisine: None
# Restaurant: subway
# Name: The Boss
# Category: breads
# Category: meats
# Category: cheeses
# Category: vegetables
# Category: condiments
# Category: spices
# Total Cost: 0
# Total Calories: 0
# Rating: 2
# {'ingredients': {'breads': {}, 'meats': {}, 'cheeses': {}, 'vegetables': {}, 'condiments': {}, 'spices': {}}, 'cost': 0, 'calories': 0, 'rating': 2, 'dietary_tags': ['vegan'], 'reviews': []}
# Cost: 14.58
# Calories: 690
#
#
#
#
# Parsing sandwich...
# ID: 10
# Cuisine: None
# Restaurant: subway
# Name: Spicy Nacho Chicken
# Ingredient: 'chicken breast'
# Exclusion Set: set()
# Category: breads
# Category: meats
# 	Ingredient Type: chicken
# 	Ingredient being searched: 'chicken'
# Exception: 'chicken'
# Category: cheeses
# Category: vegetables
# Category: condiments
# Category: spices
# Total Cost: 0
# Total Calories: 0
# Rating: 4
# {'ingredients': {'breads': {}, 'meats': {'chicken': ['chicken breast']}, 'cheeses': {}, 'vegetables': {}, 'condiments': {}, 'spices': {}}, 'cost': 0, 'calories': 0, 'rating': 4, 'dietary_tags': [], 'reviews': []}
# Cost: 13.78
# Calories: 440
#
#
#
#
# Parsing sandwich...
# ID: 11
# Cuisine: None
# Restaurant: subway
# Name: Cheesy Garlic Steak
# Ingredient: 'steak'
# Ingredient: 'cheese'
# Ingredient: 'herb garlic oil'
# Exclusion Set: {'pepper jack', 'oil', 'subway', 'pepperoni'}
# Exclusion Set: set()
# Category: breads
# Category: meats
# Category: cheeses
# Category: vegetables
# Category: condiments
# 	Ingredient Type: oil
# 	Ingredient being searched: 'oil'
# Exception: 'oil'
# Category: spices
# Total Cost: 0
# Total Calories: 0
# Rating: 1
# {'ingredients': {'breads': {}, 'meats': {}, 'cheeses': {}, 'vegetables': {}, 'condiments': {'oil': ['herb garlic oil']}, 'spices': {}}, 'cost': 0, 'calories': 0, 'rating': 1, 'dietary_tags': ['vegan'], 'reviews': []}
# Cost: 13.78
# Calories: 510
#
#
#
#
# Parsing sandwich...
# ID: 12
# Cuisine: None
# Restaurant: subway
# Name: Garlic Roast Beef
# Ingredient: 'roast beef'
# Exclusion Set: set()
# Ingredient: 'herb garlic oil'
# Exclusion Set: {'pepper jack', 'oil', 'subway', 'pepperoni'}
# Exclusion Set: set()
# Category: breads
# Category: meats
# 	Ingredient Type: beef
# 	Ingredient being searched: 'beef'
# Exception: 'beef'
# Category: cheeses
# Category: vegetables
# Category: condiments
# 	Ingredient Type: oil
# 	Ingredient being searched: 'oil'
# Exception: 'oil'
# Category: spices
# Total Cost: 0
# Total Calories: 0
# Rating: 3
# {'ingredients': {'breads': {}, 'meats': {'beef': ['roast beef']}, 'cheeses': {}, 'vegetables': {}, 'condiments': {'oil': ['herb garlic oil']}, 'spices': {}}, 'cost': 0, 'calories': 0, 'rating': 3, 'dietary_tags': [], 'reviews': []}
# Cost: 10.69
# Calories: 490
#
#
#
#
# Parsing sandwich...
# ID: 13
# Cuisine: None
# Restaurant: subway
# Name: The Beast
# Category: breads
# Category: meats
# Category: cheeses
# Category: vegetables
# Category: condiments
# Category: spices
# Total Cost: 0
# Total Calories: 0
# Rating: 4
# {'ingredients': {'breads': {}, 'meats': {}, 'cheeses': {}, 'vegetables': {}, 'condiments': {}, 'spices': {}}, 'cost': 0, 'calories': 0, 'rating': 4, 'dietary_tags': ['vegan'], 'reviews': []}
# Cost: 11.19
# Calories: 740
#
#
#
#
# Parsing sandwich...
# ID: 14
# Cuisine: Japanese
# Restaurant: subway
# Name: Teriyaki Blitz
# Ingredient: 'chicken teriyaki'
# Exclusion Set: set()
# Category: breads
# Category: meats
# 	Ingredient Type: chicken
# 	Ingredient being searched: 'chicken'
# Exception: 'chicken'
# Category: cheeses
# Category: vegetables
# Category: condiments
# Category: spices
# Total Cost: 0
# Total Calories: 0
# Rating: 1
# {'ingredients': {'breads': {}, 'meats': {'chicken': ['chicken teriyaki']}, 'cheeses': {}, 'vegetables': {}, 'condiments': {}, 'spices': {}}, 'cost': 0, 'calories': 0, 'rating': 1, 'dietary_tags': [], 'reviews': []}
# Cost: 9.49
# Calories: 460
#
#
#
#
# Parsing sandwich...
# ID: 15
# Cuisine: None
# Restaurant: subway
# Name: The Outlaw
# Category: breads
# Category: meats
# Category: cheeses
# Category: vegetables
# Category: condiments
# Category: spices
# Total Cost: 0
# Total Calories: 0
# Rating: 1
# {'ingredients': {'breads': {}, 'meats': {}, 'cheeses': {}, 'vegetables': {}, 'condiments': {}, 'spices': {}}, 'cost': 0, 'calories': 0, 'rating': 1, 'dietary_tags': ['vegan'], 'reviews': []}
# Cost: 9.49
# Calories: 590
#
#
#
#
# Parsing sandwich...
# ID: 16
# Cuisine: None
# Restaurant: subway
# Name: The Monster
# Category: breads
# Category: meats
# Category: cheeses
# Category: vegetables
# Category: condiments
# Category: spices
# Total Cost: 0
# Total Calories: 0
# Rating: 3
# {'ingredients': {'breads': {}, 'meats': {}, 'cheeses': {}, 'vegetables': {}, 'condiments': {}, 'spices': {}}, 'cost': 0, 'calories': 0, 'rating': 3, 'dietary_tags': ['vegan'], 'reviews': []}
# Cost: 10.99
# Calories: 590
#
#
#
#
# Parsing sandwich...
# ID: 17
# Cuisine: Japanese
# Restaurant: subway
# Name: Sweet Onion Chicken Teriyaki
# Ingredient: 'chicken teriyaki'
# Exclusion Set: set()
# Ingredient: 'sweet onion sauce'
# Exclusion Set: {'pepper jack', 'oil', 'subway', 'pepperoni'}
# Exclusion Set: set()
# Category: breads
# Category: meats
# 	Ingredient Type: chicken
# 	Ingredient being searched: 'chicken'
# Exception: 'chicken'
# Category: cheeses
# Category: vegetables
# 	Ingredient Type: onion
# 	Ingredient being searched: 'onion'
# Exception: 'onion'
# Category: condiments
# 	Ingredient Type: sauce
# 	Ingredient being searched: 'sauce'
# Exception: 'sauce'
# Category: spices
# Total Cost: 0
# Total Calories: 0
# Rating: 1
# {'ingredients': {'breads': {}, 'meats': {'chicken': ['chicken teriyaki']}, 'cheeses': {}, 'vegetables': {'onion': ['sweet onion sauce']}, 'condiments': {'sauce': ['sweet onion sauce']}, 'spices': {}}, 'cost': 0, 'calories': 0, 'rating': 1, 'dietary_tags': [], 'reviews': []}
# Cost: 6.99
# Calories: 430
#
#
#
#
# Parsing sandwich...
# ID: 18
# Cuisine: None
# Restaurant: subway
# Name: Pickleball Club
# Category: breads
# Category: meats
# Category: cheeses
# Category: vegetables
# Category: condiments
# Category: spices
# Total Cost: 0
# Total Calories: 0
# Rating: 2
# {'ingredients': {'breads': {}, 'meats': {}, 'cheeses': {}, 'vegetables': {}, 'condiments': {}, 'spices': {}}, 'cost': 0, 'calories': 0, 'rating': 2, 'dietary_tags': ['vegan'], 'reviews': []}
# Cost: 6.99
# Calories: 500
#
#
#
#
# Parsing sandwich...
# ID: 19
# Cuisine: None
# Restaurant: subway
# Name: Black Forest Ham
# Ingredient: 'black forest ham'
# Exclusion Set: set()
# Category: breads
# Category: meats
# 	Ingredient Type: ham
# 	Ingredient being searched: 'ham'
# Exception: 'ham'
# Category: cheeses
# Category: vegetables
# Category: condiments
# Category: spices
# Total Cost: 0
# Total Calories: 0
# Rating: 5
# {'ingredients': {'breads': {}, 'meats': {'ham': ['black forest ham']}, 'cheeses': {}, 'vegetables': {}, 'condiments': {}, 'spices': {}}, 'cost': 0, 'calories': 0, 'rating': 5, 'dietary_tags': [], 'reviews': []}
# Cost: 5.99
# Calories: 320
#
#
#
#
# Parsing sandwich...
# ID: 20
# Cuisine: None
# Restaurant: subway
# Name: B.L.T.
# Ingredient: 'bacon'
# Exclusion Set: set()
# Ingredient: 'lettuce'
# Exclusion Set: {'pepper jack', 'oil', 'subway', 'pepperoni'}
# Ingredient: 'tomato'
# Exclusion Set: {'pepper jack', 'oil', 'subway', 'pepperoni'}
# Category: breads
# Category: meats
# 	Ingredient Type: bacon
# 	Ingredient being searched: 'bacon'
# Exception: 'bacon'
# Category: cheeses
# Category: vegetables
# 	Ingredient Type: lettuce
# 	Ingredient being searched: 'lettuce'
# Exception: 'lettuce'
# 	Ingredient Type: tomato
# 	Ingredient being searched: 'tomato'
# Exception: 'tomato'
# Category: condiments
# Category: spices
# Total Cost: 0
# Total Calories: 0
# Rating: 3
# {'ingredients': {'breads': {}, 'meats': {'bacon': ['bacon']}, 'cheeses': {}, 'vegetables': {'lettuce': ['lettuce'], 'tomato': ['tomato']}, 'condiments': {}, 'spices': {}}, 'cost': 0, 'calories': 0, 'rating': 3, 'dietary_tags': [], 'reviews': []}
# Cost: 5.99
# Calories: 370
#
#
#
#
# Parsing sandwich...
# ID: 21
# Cuisine: None
# Restaurant: subway
# Name: Cold Cut Combo
# Ingredient: 'turkey ham'
# Exclusion Set: set()
# Ingredient: 'turkey salami'
# Exclusion Set: set()
# Ingredient: 'turkey bologna'
# Exclusion Set: set()
# Category: breads
# Category: meats
# 	Ingredient Type: turkey
# 	Ingredient being searched: 'turkey'
# Exception: 'turkey'
# Category: cheeses
# Category: vegetables
# Category: condiments
# Category: spices
# Total Cost: 0
# Total Calories: 0
# Rating: 3
# {'ingredients': {'breads': {}, 'meats': {'turkey': ['turkey ham', 'turkey salami', 'turkey bologna']}, 'cheeses': {}, 'vegetables': {}, 'condiments': {}, 'spices': {}}, 'cost': 0, 'calories': 0, 'rating': 3, 'dietary_tags': [], 'reviews': []}
# Cost: 5.99
# Calories: 370
#
#
#
#
# Parsing sandwich...
# ID: 22
# Cuisine: None
# Restaurant: subway
# Name: Grilled Chicken
# Ingredient: 'chicken breast'
# Exclusion Set: set()
# Category: breads
# Category: meats
# 	Ingredient Type: chicken
# 	Ingredient being searched: 'chicken'
# Exception: 'chicken'
# Category: cheeses
# Category: vegetables
# Category: condiments
# Category: spices
# Total Cost: 0
# Total Calories: 0
# Rating: 4
# {'ingredients': {'breads': {}, 'meats': {'chicken': ['chicken breast']}, 'cheeses': {}, 'vegetables': {}, 'condiments': {}, 'spices': {}}, 'cost': 0, 'calories': 0, 'rating': 4, 'dietary_tags': [], 'reviews': []}
# Cost: 6.99
# Calories: 330
#
#
#
#
# Parsing sandwich...
# ID: 23
# Cuisine: Italian
# Restaurant: subway
# Name: Meatball Marinara
# Ingredient: 'italian meatball'
# Ingredient: 'marinara sauce'
# Exclusion Set: set()
# Category: breads
# Category: meats
# Category: cheeses
# Category: vegetables
# Category: condiments
# 	Ingredient Type: sauce
# 	Ingredient being searched: 'sauce'
# Exception: 'sauce'
# Category: spices
# Total Cost: 0
# Total Calories: 0
# Rating: 2
# {'ingredients': {'breads': {}, 'meats': {}, 'cheeses': {}, 'vegetables': {}, 'condiments': {'sauce': ['marinara sauce']}, 'spices': {}}, 'cost': 0, 'calories': 0, 'rating': 2, 'dietary_tags': ['vegan'], 'reviews': []}
# Cost: 6.99
# Calories: 520
#
#
#
#
# Parsing sandwich...
# ID: 24
# Cuisine: None
# Restaurant: subway
# Name: Oven-Roasted Turkey
# Ingredient: 'turkey breast'
# Exclusion Set: set()
# Category: breads
# Category: meats
# 	Ingredient Type: turkey
# 	Ingredient being searched: 'turkey'
# Exception: 'turkey'
# Category: cheeses
# Category: vegetables
# Category: condiments
# Category: spices
# Total Cost: 0
# Total Calories: 0
# Rating: 3
# {'ingredients': {'breads': {}, 'meats': {'turkey': ['turkey breast']}, 'cheeses': {}, 'vegetables': {}, 'condiments': {}, 'spices': {}}, 'cost': 0, 'calories': 0, 'rating': 3, 'dietary_tags': [], 'reviews': []}
# Cost: 5.99
# Calories: 310
#
#
#
#
# Parsing sandwich...
# ID: 25
# Cuisine: Italian
# Restaurant: subway
# Name: Pizza Sub
# Ingredient: 'pepperoni'
# Exclusion Set: set()
# Exclusion Set: {'pepper jack', 'oil', 'subway', 'pepperoni'}
# Ingredient: 'marinara sauce'
# Exclusion Set: set()
# Ingredient: 'cheese'
# Category: breads
# Category: meats
# 	Ingredient Type: pepperoni
# 	Ingredient being searched: 'pepperoni'
# Exception: 'pepperoni'
# Category: cheeses
# Category: vegetables
# Category: condiments
# 	Ingredient Type: sauce
# 	Ingredient being searched: 'sauce'
# Exception: 'sauce'
# Category: spices
# Total Cost: 0
# Total Calories: 0
# Rating: 5
# {'ingredients': {'breads': {}, 'meats': {'pepperoni': ['pepperoni']}, 'cheeses': {}, 'vegetables': {}, 'condiments': {'sauce': ['marinara sauce']}, 'spices': {}}, 'cost': 0, 'calories': 0, 'rating': 5, 'dietary_tags': [], 'reviews': []}
# Cost: 4.99
# Calories: 490
#
#
#
#
# Parsing sandwich...
# ID: 26
# Cuisine: None
# Restaurant: subway
# Name: Oven-Roasted Turkey & Ham
# Ingredient: 'turkey breast'
# Exclusion Set: set()
# Ingredient: 'ham'
# Exclusion Set: set()
# Category: breads
# Category: meats
# 	Ingredient Type: turkey
# 	Ingredient being searched: 'turkey'
# Exception: 'turkey'
# 	Ingredient Type: ham
# 	Ingredient being searched: 'ham'
# Exception: 'ham'
# Category: cheeses
# Category: vegetables
# Category: condiments
# Category: spices
# Total Cost: 0
# Total Calories: 0
# Rating: 2
# {'ingredients': {'breads': {}, 'meats': {'turkey': ['turkey breast'], 'ham': ['ham']}, 'cheeses': {}, 'vegetables': {}, 'condiments': {}, 'spices': {}}, 'cost': 0, 'calories': 0, 'rating': 2, 'dietary_tags': [], 'reviews': []}
# Cost: 5.99
# Calories: 310
#
#
#
#
# Parsing sandwich...
# ID: 27
# Cuisine: None
# Restaurant: subway
# Name: Rotisserie-Style Chicken
# Ingredient: 'chicken breast'
# Exclusion Set: set()
# Category: breads
# Category: meats
# 	Ingredient Type: chicken
# 	Ingredient being searched: 'chicken'
# Exception: 'chicken'
# Category: cheeses
# Category: vegetables
# Category: condiments
# Category: spices
# Total Cost: 0
# Total Calories: 0
# Rating: 1
# {'ingredients': {'breads': {}, 'meats': {'chicken': ['chicken breast']}, 'cheeses': {}, 'vegetables': {}, 'condiments': {}, 'spices': {}}, 'cost': 0, 'calories': 0, 'rating': 1, 'dietary_tags': [], 'reviews': []}
# Cost: 6.99
# Calories: 350
#
#
#
#
# Parsing sandwich...
# ID: 28
# Cuisine: None
# Restaurant: subway
# Name: Roast Beef
# Ingredient: 'roast beef'
# Exclusion Set: set()
# Category: breads
# Category: meats
# 	Ingredient Type: beef
# 	Ingredient being searched: 'beef'
# Exception: 'beef'
# Category: cheeses
# Category: vegetables
# Category: condiments
# Category: spices
# Total Cost: 0
# Total Calories: 0
# Rating: 3
# {'ingredients': {'breads': {}, 'meats': {'beef': ['roast beef']}, 'cheeses': {}, 'vegetables': {}, 'condiments': {}, 'spices': {}}, 'cost': 0, 'calories': 0, 'rating': 3, 'dietary_tags': [], 'reviews': []}
# Cost: 6.99
# Calories: 350
#
#
#
#
# Parsing sandwich...
# ID: 29
# Cuisine: None
# Restaurant: subway
# Name: Steak & Cheese
# Ingredient: 'steak'
# Ingredient: 'cheese'
# Category: breads
# Category: meats
# Category: cheeses
# Category: vegetables
# Category: condiments
# Category: spices
# Total Cost: 0
# Total Calories: 0
# Rating: 5
# {'ingredients': {'breads': {}, 'meats': {}, 'cheeses': {}, 'vegetables': {}, 'condiments': {}, 'spices': {}}, 'cost': 0, 'calories': 0, 'rating': 5, 'dietary_tags': ['vegan'], 'reviews': []}
# Cost: 6.99
# Calories: 370
#
#
#
#
# Parsing sandwich...
# ID: 30
# Cuisine: None
# Restaurant: subway
# Name: Tuna
# Ingredient: 'tuna'
# Exclusion Set: set()
# Category: breads
# Category: meats
# 	Ingredient Type: tuna
# 	Ingredient being searched: 'tuna'
# Exception: 'tuna'
# Category: cheeses
# Category: vegetables
# Category: condiments
# Category: spices
# Total Cost: 0
# Total Calories: 0
# Rating: 1
# {'ingredients': {'breads': {}, 'meats': {'tuna': ['tuna']}, 'cheeses': {}, 'vegetables': {}, 'condiments': {}, 'spices': {}}, 'cost': 0, 'calories': 0, 'rating': 1, 'dietary_tags': [], 'reviews': []}
# Cost: 5.99
# Calories: 510
#
#
#
#
# Parsing sandwich...
# ID: 31
# Cuisine: None
# Restaurant: subway
# Name: Veggie Delite
# Ingredient: 'lettuce'
# Exclusion Set: {'pepper jack', 'oil', 'subway', 'pepperoni'}
# Ingredient: 'tomato'
# Exclusion Set: {'pepper jack', 'oil', 'subway', 'pepperoni'}
# Ingredient: 'cucumber'
# Exclusion Set: {'pepper jack', 'oil', 'subway', 'pepperoni'}
# Ingredient: 'green pepper'
# Exclusion Set: {'pepper jack', 'oil', 'subway', 'pepperoni'}
# Ingredient: 'onion'
# Exclusion Set: {'pepper jack', 'oil', 'subway', 'pepperoni'}
# Category: breads
# Category: meats
# Category: cheeses
# Category: vegetables
# 	Ingredient Type: lettuce
# 	Ingredient being searched: 'lettuce'
# Exception: 'lettuce'
# 	Ingredient Type: tomato
# 	Ingredient being searched: 'tomato'
# Exception: 'tomato'
# 	Ingredient Type: cucumber
# 	Ingredient being searched: 'cucumber'
# Exception: 'cucumber'
# 	Ingredient Type: pepper
# 	Ingredient being searched: 'pepper'
# Exception: 'pepper'
# 	Ingredient Type: onion
# 	Ingredient being searched: 'onion'
# Exception: 'onion'
# Category: condiments
# Category: spices
# Total Cost: 0
# Total Calories: 0
# Rating: 2
# {'ingredients': {'breads': {}, 'meats': {}, 'cheeses': {}, 'vegetables': {'lettuce': ['lettuce'], 'tomato': ['tomato'], 'cucumber': ['cucumber'], 'pepper': ['green pepper'], 'onion': ['onion']}, 'condiments': {}, 'spices': {}}, 'cost': 0, 'calories': 0, 'rating': 2, 'dietary_tags': ['vegan'], 'reviews': []}
# Cost: 5.99
# Calories: 220

# %%
formatted_sandwiches
# Out:
# [{'id_': 0,
#   'cuisine': None,
#   'restaurant': 'subway',
#   'name': 'Elite Chicken & Bacon Ranch',
#   'ingredients': {'breads': {},
#    'meats': {'chicken': ['chicken breast'], 'bacon': ['bacon']},
#    'cheeses': {},
#    'vegetables': {},
#    'condiments': {'dressing': ['ranch dressing']},
#    'spices': {}},
#   'cost': 15.28,
#   'calories': 580,
#   'rating': 2,
#   'dietary_tags': [],
#   'reviews': []},
#  {'id_': 1,
#   'cuisine': 'American',
#   'restaurant': 'subway',
#   'name': 'The Philly',
#   'ingredients': {'breads': {},
#    'meats': {},
#    'cheeses': {},
#    'vegetables': {},
#    'condiments': {},
#    'spices': {}},
#   'cost': 13.78,
#   'calories': 505,
#   'rating': 1,
#   'dietary_tags': ['vegan'],
#   'reviews': []},
#  {'id_': 2,
#   'cuisine': None,
#   'restaurant': 'subway',
#   'name': 'Subway Club',
#   'ingredients': {'breads': {},
#    'meats': {'turkey': ['turkey breast'],
#     'ham': ['black forest ham'],
#     'beef': ['roast beef']},
#    'cheeses': {},
#    'vegetables': {},
#    'condiments': {},
#    'spices': {}},
#   'cost': 14.78,
#   'calories': 500,
#   'rating': 1,
#   'dietary_tags': [],
#   'reviews': []},
#  {'id_': 3,
#   'cuisine': 'American',
#   'restaurant': 'subway',
#   'name': 'All-American Club',
#   'ingredients': {'breads': {},
#    'meats': {'turkey': ['turkey breast'],
#     'ham': ['black forest ham'],
#     'bacon': ['bacon']},
#    'cheeses': {},
#    'vegetables': {},
#    'condiments': {},
#    'spices': {}},
#   'cost': 14.28,
#   'calories': 540,
#   'rating': 2,
#   'dietary_tags': [],
#   'reviews': []},
#  {'id_': 4,
#   'cuisine': 'Italian',
#   'restaurant': 'subway',
#   'name': 'The Hotshot Italiano',
#   'ingredients': {'breads': {},
#    'meats': {'salami': ['genoa salami'],
#     'pepperoni': ['pepperoni'],
#     'ham': ['ham']},
#    'cheeses': {},
#    'vegetables': {},
#    'condiments': {},
#    'spices': {}},
#   'cost': 12.28,
#   'calories': 630,
#   'rating': 3,
#   'dietary_tags': [],
#   'reviews': []},
#  {'id_': 5,
#   'cuisine': 'Italian',
#   'restaurant': 'subway',
#   'name': 'The Ultimate B.M.T.',
#   'ingredients': {'breads': {},
#    'meats': {'ham': ['ham'],
#     'salami': ['genoa salami'],
#     'pepperoni': ['pepperoni']},
#    'cheeses': {},
#    'vegetables': {},
#    'condiments': {},
#    'spices': {}},
#   'cost': 12.78,
#   'calories': 560,
#   'rating': 3,
#   'dietary_tags': [],
#   'reviews': []},
#  {'id_': 6,
#   'cuisine': None,
#   'restaurant': 'subway',
#   'name': 'Titan Turkey',
#   'ingredients': {'breads': {},
#    'meats': {'turkey': ['turkey breast']},
#    'cheeses': {},
#    'vegetables': {},
#    'condiments': {},
#    'spices': {}},
#   'cost': 12.68,
#   'calories': 490,
#   'rating': 5,
#   'dietary_tags': [],
#   'reviews': []},
#  {'id_': 7,
#   'cuisine': None,
#   'restaurant': 'subway',
#   'name': 'Home Run Ham',
#   'ingredients': {'breads': {},
#    'meats': {'ham': ['ham']},
#    'cheeses': {},
#    'vegetables': {},
#    'condiments': {},
#    'spices': {}},
#   'cost': 12.18,
#   'calories': 510,
#   'rating': 5,
#   'dietary_tags': [],
#   'reviews': []},
#  {'id_': 8,
#   'cuisine': 'BBQ',
#   'restaurant': 'subway',
#   'name': 'Honey Mustard BBQ Chicken',
#   'ingredients': {'breads': {},
#    'meats': {'chicken': ['chicken breast']},
#    'cheeses': {},
#    'vegetables': {},
#    'condiments': {'mustard': ['honey mustard']},
#    'spices': {}},
#   'cost': 13.78,
#   'calories': 510,
#   'rating': 4,
#   'dietary_tags': [],
#   'reviews': []},
#  {'id_': 9,
#   'cuisine': None,
#   'restaurant': 'subway',
#   'name': 'The Boss',
#   'ingredients': {'breads': {},
#    'meats': {},
#    'cheeses': {},
#    'vegetables': {},
#    'condiments': {},
#    'spices': {}},
#   'cost': 14.58,
#   'calories': 690,
#   'rating': 2,
#   'dietary_tags': ['vegan'],
#   'reviews': []},
#  {'id_': 10,
#   'cuisine': None,
#   'restaurant': 'subway',
#   'name': 'Spicy Nacho Chicken',
#   'ingredients': {'breads': {},
#    'meats': {'chicken': ['chicken breast']},
#    'cheeses': {},
#    'vegetables': {},
#    'condiments': {},
#    'spices': {}},
#   'cost': 13.78,
#   'calories': 440,
#   'rating': 4,
#   'dietary_tags': [],
#   'reviews': []},
#  {'id_': 11,
#   'cuisine': None,
#   'restaurant': 'subway',
#   'name': 'Cheesy Garlic Steak',
#   'ingredients': {'breads': {},
#    'meats': {},
#    'cheeses': {},
#    'vegetables': {},
#    'condiments': {'oil': ['herb garlic oil']},
#    'spices': {}},
#   'cost': 13.78,
#   'calories': 510,
#   'rating': 1,
#   'dietary_tags': ['vegan'],
#   'reviews': []},
#  {'id_': 12,
#   'cuisine': None,
#   'restaurant': 'subway',
#   'name': 'Garlic Roast Beef',
#   'ingredients': {'breads': {},
#    'meats': {'beef': ['roast beef']},
#    'cheeses': {},
#    'vegetables': {},
#    'condiments': {'oil': ['herb garlic oil']},
#    'spices': {}},
#   'cost': 10.69,
#   'calories': 490,
#   'rating': 3,
#   'dietary_tags': [],
#   'reviews': []},
#  {'id_': 13,
#   'cuisine': None,
#   'restaurant': 'subway',
#   'name': 'The Beast',
#   'ingredients': {'breads': {},
#    'meats': {},
#    'cheeses': {},
#    'vegetables': {},
#    'condiments': {},
#    'spices': {}},
#   'cost': 11.19,
#   'calories': 740,
#   'rating': 4,
#   'dietary_tags': ['vegan'],
#   'reviews': []},
#  {'id_': 14,
#   'cuisine': 'Japanese',
#   'restaurant': 'subway',
#   'name': 'Teriyaki Blitz',
#   'ingredients': {'breads': {},
#    'meats': {'chicken': ['chicken teriyaki']},
#    'cheeses': {},
#    'vegetables': {},
#    'condiments': {},
#    'spices': {}},
#   'cost': 9.49,
#   'calories': 460,
#   'rating': 1,
#   'dietary_tags': [],
#   'reviews': []},
#  {'id_': 15,
#   'cuisine': None,
#   'restaurant': 'subway',
#   'name': 'The Outlaw',
#   'ingredients': {'breads': {},
#    'meats': {},
#    'cheeses': {},
#    'vegetables': {},
#    'condiments': {},
#    'spices': {}},
#   'cost': 9.49,
#   'calories': 590,
#   'rating': 1,
#   'dietary_tags': ['vegan'],
#   'reviews': []},
#  {'id_': 16,
#   'cuisine': None,
#   'restaurant': 'subway',
#   'name': 'The Monster',
#   'ingredients': {'breads': {},
#    'meats': {},
#    'cheeses': {},
#    'vegetables': {},
#    'condiments': {},
#    'spices': {}},
#   'cost': 10.99,
#   'calories': 590,
#   'rating': 3,
#   'dietary_tags': ['vegan'],
#   'reviews': []},
#  {'id_': 17,
#   'cuisine': 'Japanese',
#   'restaurant': 'subway',
#   'name': 'Sweet Onion Chicken Teriyaki',
#   'ingredients': {'breads': {},
#    'meats': {'chicken': ['chicken teriyaki']},
#    'cheeses': {},
#    'vegetables': {'onion': ['sweet onion sauce']},
#    'condiments': {'sauce': ['sweet onion sauce']},
#    'spices': {}},
#   'cost': 6.99,
#   'calories': 430,
#   'rating': 1,
#   'dietary_tags': [],
#   'reviews': []},
#  {'id_': 18,
#   'cuisine': None,
#   'restaurant': 'subway',
#   'name': 'Pickleball Club',
#   'ingredients': {'breads': {},
#    'meats': {},
#    'cheeses': {},
#    'vegetables': {},
#    'condiments': {},
#    'spices': {}},
#   'cost': 6.99,
#   'calories': 500,
#   'rating': 2,
#   'dietary_tags': ['vegan'],
#   'reviews': []},
#  {'id_': 19,
#   'cuisine': None,
#   'restaurant': 'subway',
#   'name': 'Black Forest Ham',
#   'ingredients': {'breads': {},
#    'meats': {'ham': ['black forest ham']},
#    'cheeses': {},
#    'vegetables': {},
#    'condiments': {},
#    'spices': {}},
#   'cost': 5.99,
#   'calories': 320,
#   'rating': 5,
#   'dietary_tags': [],
#   'reviews': []},
#  {'id_': 20,
#   'cuisine': None,
#   'restaurant': 'subway',
#   'name': 'B.L.T.',
#   'ingredients': {'breads': {},
#    'meats': {'bacon': ['bacon']},
#    'cheeses': {},
#    'vegetables': {'lettuce': ['lettuce'], 'tomato': ['tomato']},
#    'condiments': {},
#    'spices': {}},
#   'cost': 5.99,
#   'calories': 370,
#   'rating': 3,
#   'dietary_tags': [],
#   'reviews': []},
#  {'id_': 21,
#   'cuisine': None,
#   'restaurant': 'subway',
#   'name': 'Cold Cut Combo',
#   'ingredients': {'breads': {},
#    'meats': {'turkey': ['turkey ham', 'turkey salami', 'turkey bologna']},
#    'cheeses': {},
#    'vegetables': {},
#    'condiments': {},
#    'spices': {}},
#   'cost': 5.99,
#   'calories': 370,
#   'rating': 3,
#   'dietary_tags': [],
#   'reviews': []},
#  {'id_': 22,
#   'cuisine': None,
#   'restaurant': 'subway',
#   'name': 'Grilled Chicken',
#   'ingredients': {'breads': {},
#    'meats': {'chicken': ['chicken breast']},
#    'cheeses': {},
#    'vegetables': {},
#    'condiments': {},
#    'spices': {}},
#   'cost': 6.99,
#   'calories': 330,
#   'rating': 4,
#   'dietary_tags': [],
#   'reviews': []},
#  {'id_': 23,
#   'cuisine': 'Italian',
#   'restaurant': 'subway',
#   'name': 'Meatball Marinara',
#   'ingredients': {'breads': {},
#    'meats': {},
#    'cheeses': {},
#    'vegetables': {},
#    'condiments': {'sauce': ['marinara sauce']},
#    'spices': {}},
#   'cost': 6.99,
#   'calories': 520,
#   'rating': 2,
#   'dietary_tags': ['vegan'],
#   'reviews': []},
#  {'id_': 24,
#   'cuisine': None,
#   'restaurant': 'subway',
#   'name': 'Oven-Roasted Turkey',
#   'ingredients': {'breads': {},
#    'meats': {'turkey': ['turkey breast']},
#    'cheeses': {},
#    'vegetables': {},
#    'condiments': {},
#    'spices': {}},
#   'cost': 5.99,
#   'calories': 310,
#   'rating': 3,
#   'dietary_tags': [],
#   'reviews': []},
#  {'id_': 25,
#   'cuisine': 'Italian',
#   'restaurant': 'subway',
#   'name': 'Pizza Sub',
#   'ingredients': {'breads': {},
#    'meats': {'pepperoni': ['pepperoni']},
#    'cheeses': {},
#    'vegetables': {},
#    'condiments': {'sauce': ['marinara sauce']},
#    'spices': {}},
#   'cost': 4.99,
#   'calories': 490,
#   'rating': 5,
#   'dietary_tags': [],
#   'reviews': []},
#  {'id_': 26,
#   'cuisine': None,
#   'restaurant': 'subway',
#   'name': 'Oven-Roasted Turkey & Ham',
#   'ingredients': {'breads': {},
#    'meats': {'turkey': ['turkey breast'], 'ham': ['ham']},
#    'cheeses': {},
#    'vegetables': {},
#    'condiments': {},
#    'spices': {}},
#   'cost': 5.99,
#   'calories': 310,
#   'rating': 2,
#   'dietary_tags': [],
#   'reviews': []},
#  {'id_': 27,
#   'cuisine': None,
#   'restaurant': 'subway',
#   'name': 'Rotisserie-Style Chicken',
#   'ingredients': {'breads': {},
#    'meats': {'chicken': ['chicken breast']},
#    'cheeses': {},
#    'vegetables': {},
#    'condiments': {},
#    'spices': {}},
#   'cost': 6.99,
#   'calories': 350,
#   'rating': 1,
#   'dietary_tags': [],
#   'reviews': []},
#  {'id_': 28,
#   'cuisine': None,
#   'restaurant': 'subway',
#   'name': 'Roast Beef',
#   'ingredients': {'breads': {},
#    'meats': {'beef': ['roast beef']},
#    'cheeses': {},
#    'vegetables': {},
#    'condiments': {},
#    'spices': {}},
#   'cost': 6.99,
#   'calories': 350,
#   'rating': 3,
#   'dietary_tags': [],
#   'reviews': []},
#  {'id_': 29,
#   'cuisine': None,
#   'restaurant': 'subway',
#   'name': 'Steak & Cheese',
#   'ingredients': {'breads': {},
#    'meats': {},
#    'cheeses': {},
#    'vegetables': {},
#    'condiments': {},
#    'spices': {}},
#   'cost': 6.99,
#   'calories': 370,
#   'rating': 5,
#   'dietary_tags': ['vegan'],
#   'reviews': []},
#  {'id_': 30,
#   'cuisine': None,
#   'restaurant': 'subway',
#   'name': 'Tuna',
#   'ingredients': {'breads': {},
#    'meats': {'tuna': ['tuna']},
#    'cheeses': {},
#    'vegetables': {},
#    'condiments': {},
#    'spices': {}},
#   'cost': 5.99,
#   'calories': 510,
#   'rating': 1,
#   'dietary_tags': [],
#   'reviews': []},
#  {'id_': 31,
#   'cuisine': None,
#   'restaurant': 'subway',
#   'name': 'Veggie Delite',
#   'ingredients': {'breads': {},
#    'meats': {},
#    'cheeses': {},
#    'vegetables': {'lettuce': ['lettuce'],
#     'tomato': ['tomato'],
#     'cucumber': ['cucumber'],
#     'pepper': ['green pepper'],
#     'onion': ['onion']},
#    'condiments': {},
#    'spices': {}},
#   'cost': 5.99,
#   'calories': 220,
#   'rating': 2,
#   'dietary_tags': ['vegan'],
#   'reviews': []}]

# %% [markdown]
# # Download restructured files

# %%
def download_restructured_data(json_data, file_label="menu"):
  output_file = f'restructured_{originating_restaurant}_{file_label}.json'
  with open(output_file, 'w') as outfile:
      json.dump(json_data, outfile, indent=4)

  # Download the reformatted JSON file
  files.download(output_file)

# %%
download_restructured_data(ingredients_table_json, file_label="ingredients")
download_restructured_data(formatted_sandwiches, file_label="menu")
