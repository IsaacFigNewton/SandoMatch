# %%
import random
import re
import pandas as pd
import json
import requests
from google.colab import files
import ipywidgets as widgets
from IPython.display import display

originating_restaurant = "mr_pickles"

# Create a FileUpload widget that accepts JSON files
uploader = widgets.FileUpload(
    accept='.json',
    multiple=False
)

# Display the uploader widget
display(uploader)

def handle_upload(change):
    # Declare global vars because apparently I can't use ones in the broader scope
    global sandwiches_data, uploaded_filename
    if uploader.value:
        # Get the uploaded file content
        uploaded_file = next(iter(uploader.value.values()))
        uploaded_filename = uploaded_file['metadata']['name']

        # Decode the file content from bytes to a string
        json_str = uploaded_file['content'].decode('utf-8')

        sandwiches_data = json.loads(json_str)
        print(f"Successfully uploaded {uploaded_filename}")

# Observe changes in the uploader widget
uploader.observe(handle_upload, names='value')
# Out:
# FileUpload(value={}, accept='.json', description='Upload')
# Successfully uploaded subway_menu.json

# %%
print(sandwiches_data)
# Out:
# [{'id': 1, 'name': 'Elite Chicken & Bacon Ranch', 'ingredients': ['Chicken Breast', 'Bacon', 'Ranch Dressing', 'Cheese'], 'cuisine': None, 'cost': 15.28, 'calories': 580}, {'id': 2, 'name': 'The Philly', 'ingredients': ['Steak', 'Cheese'], 'cuisine': 'American', 'cost': 13.78, 'calories': 505}, {'id': 3, 'name': 'Subway Club', 'ingredients': ['Turkey Breast', 'Black Forest Ham', 'Roast Beef'], 'cuisine': None, 'cost': 14.78, 'calories': 500}, {'id': 4, 'name': 'All-American Club', 'ingredients': ['Turkey Breast', 'Black Forest Ham', 'Bacon'], 'cuisine': 'American', 'cost': 14.28, 'calories': 540}, {'id': 5, 'name': 'The Hotshot Italiano', 'ingredients': ['Genoa Salami', 'Pepperoni', 'Ham'], 'cuisine': 'Italian', 'cost': 12.28, 'calories': 630}, {'id': 6, 'name': 'The Ultimate B.M.T.', 'ingredients': ['Ham', 'Genoa Salami', 'Pepperoni'], 'cuisine': 'Italian', 'cost': 12.78, 'calories': 560}, {'id': 7, 'name': 'Titan Turkey', 'ingredients': ['Turkey Breast'], 'cuisine': None, 'cost': 12.68, 'calories': 490}, {'id': 8, 'name': 'Home Run Ham', 'ingredients': ['Ham'], 'cuisine': None, 'cost': 12.18, 'calories': 510}, {'id': 9, 'name': 'Honey Mustard BBQ Chicken', 'ingredients': ['Chicken Breast', 'Honey Mustard'], 'cuisine': 'BBQ', 'cost': 13.78, 'calories': 510}, {'id': 10, 'name': 'The Boss', 'ingredients': [], 'cuisine': None, 'cost': 14.58, 'calories': 690}, {'id': 11, 'name': 'Spicy Nacho Chicken', 'ingredients': ['Chicken Breast'], 'cuisine': None, 'cost': 13.78, 'calories': 440}, {'id': 12, 'name': 'Cheesy Garlic Steak', 'ingredients': ['Steak', 'Cheese', 'Herb Garlic Oil'], 'cuisine': None, 'cost': 13.78, 'calories': 510}, {'id': 13, 'name': 'Garlic Roast Beef', 'ingredients': ['Roast Beef', 'Herb Garlic Oil'], 'cuisine': None, 'cost': 10.69, 'calories': 490}, {'id': 14, 'name': 'The Beast', 'ingredients': [], 'cuisine': None, 'cost': 11.19, 'calories': 740}, {'id': 15, 'name': 'Teriyaki Blitz', 'ingredients': ['Chicken Teriyaki'], 'cuisine': 'Japanese', 'cost': 9.49, 'calories': 460}, {'id': 16, 'name': 'The Outlaw', 'ingredients': [], 'cuisine': None, 'cost': 9.49, 'calories': 590}, {'id': 17, 'name': 'The Monster', 'ingredients': [], 'cuisine': None, 'cost': 10.99, 'calories': 590}, {'id': 18, 'name': 'Sweet Onion Chicken Teriyaki', 'ingredients': ['Chicken Teriyaki', 'Sweet Onion Sauce'], 'cuisine': 'Japanese', 'cost': 6.99, 'calories': 430}, {'id': 19, 'name': 'Pickleball Club', 'ingredients': [], 'cuisine': None, 'cost': 6.99, 'calories': 500}, {'id': 20, 'name': 'Black Forest Ham', 'ingredients': ['Black Forest Ham'], 'cuisine': None, 'cost': 5.99, 'calories': 320}, {'id': 21, 'name': 'B.L.T.', 'ingredients': ['Bacon', 'Lettuce', 'Tomato'], 'cuisine': None, 'cost': 5.99, 'calories': 370}, {'id': 22, 'name': 'Cold Cut Combo', 'ingredients': ['Turkey Ham', 'Turkey Salami', 'Turkey Bologna'], 'cuisine': None, 'cost': 5.99, 'calories': 370}, {'id': 23, 'name': 'Grilled Chicken', 'ingredients': ['Chicken Breast'], 'cuisine': None, 'cost': 6.99, 'calories': 330}, {'id': 24, 'name': 'Meatball Marinara', 'ingredients': ['Italian Meatballs', 'Marinara Sauce'], 'cuisine': 'Italian', 'cost': 6.99, 'calories': 520}, {'id': 25, 'name': 'Oven-Roasted Turkey', 'ingredients': ['Turkey Breast'], 'cuisine': None, 'cost': 5.99, 'calories': 310}, {'id': 26, 'name': 'Pizza Sub', 'ingredients': ['Pepperoni', 'Marinara Sauce', 'Cheese'], 'cuisine': 'Italian', 'cost': 4.99, 'calories': 490}, {'id': 27, 'name': 'Oven-Roasted Turkey & Ham', 'ingredients': ['Turkey Breast', 'Ham'], 'cuisine': None, 'cost': 5.99, 'calories': 310}, {'id': 28, 'name': 'Rotisserie-Style Chicken', 'ingredients': ['Chicken Breast'], 'cuisine': None, 'cost': 6.99, 'calories': 350}, {'id': 29, 'name': 'Roast Beef', 'ingredients': ['Roast Beef'], 'cuisine': None, 'cost': 6.99, 'calories': 350}, {'id': 30, 'name': 'Steak & Cheese', 'ingredients': ['Steak', 'Cheese'], 'cuisine': None, 'cost': 6.99, 'calories': 370}, {'id': 31, 'name': 'Tuna', 'ingredients': ['Tuna'], 'cu ...

# %% [markdown]
# #Variables

# %%
vegetarian_bases = {"egg", "veggie patty"}
vegan_bases = {"veggie patty"}

# %% [markdown]
# ##Cost, calorie data

# %%
all_ingredients = {
    "breads": {
        "baguette": {"cost": 1.5, "calories": 250},
        "ciabatta": {"cost": 1.8, "calories": 250},
        "pita": {"cost": 1.0, "calories": 200},
        "naan": {"cost": 1.2, "calories": 300},
        "tortilla": {"cost": 0.8, "calories": 150},
        "roll": {"cost": 0.5, "calories": 120},
        "sourdough": {"cost": 2.0, "calories": 220},
        "rye": {"cost": 1.5, "calories": 200},
        "multigrain": {"cost": 1.5, "calories": 220},
        "whole wheat": {"cost": 1.0, "calories": 180},
        "white bread": {"cost": 1.0, "calories": 160},
        "brioche": {"cost": 2.5, "calories": 300},
        "focaccia": {"cost": 2.0, "calories": 250},
        "panini": {"cost": 2.0, "calories": 200},
        "english muffin": {"cost": 0.8, "calories": 150},
        "bagel": {"cost": 1.0, "calories": 250},
        "croissant": {"cost": 1.5, "calories": 280},
        "milk bread": {"cost": 1.8, "calories": 220},
        "flatbread": {"cost": 1.0, "calories": 180},
        "pumpernickel": {"cost": 1.8, "calories": 190},
        "pretzel roll": {"cost": 1.5, "calories": 200},
        "potato bread": {"cost": 1.0, "calories": 180},
        "bolillo": {"cost": 0.6, "calories": 150},
        "torta": {"cost": 0.8, "calories": 180},
        "lavash": {"cost": 1.0, "calories": 160},
        "cornbread": {"cost": 1.5, "calories": 180},
        "chapati": {"cost": 0.5, "calories": 120},
        "paratha": {"cost": 0.8, "calories": 150},
        "wrap": {"cost": 1.0, "calories": 150},
        "bun": {"cost": 0.5, "calories": 120},
        "steamed bun": {"cost": 0.8, "calories": 140}
    },
    "meats": {
        "beef": {"cost": 3.0, "calories": 250},
        "chicken": {"cost": 2.0, "calories": 200},
        "turkey": {"cost": 2.5, "calories": 180},
        "pork": {"cost": 2.5, "calories": 220},
        "ham": {"cost": 2.0, "calories": 150},
        "bacon": {"cost": 1.0, "calories": 50},
        "sausage": {"cost": 1.5, "calories": 180},
        "bratwurst": {"cost": 2.0, "calories": 250},
        "salami": {"cost": 2.0, "calories": 120},
        "prosciutto": {"cost": 2.5, "calories": 70},
        "pepperoni": {"cost": 1.5, "calories": 80},
        "pastrami": {"cost": 2.0, "calories": 120},
        "mortadella": {"cost": 2.0, "calories": 100},
        "lamb": {"cost": 3.5, "calories": 250},
        "duck": {"cost": 4.0, "calories": 350},
        "roast beef": {"cost": 3.0, "calories": 250},
        "veal": {"cost": 3.5, "calories": 200},
        "venison": {"cost": 4.0, "calories": 220},
        "chorizo": {"cost": 2.0, "calories": 100},
        "capicola": {"cost": 2.5, "calories": 90},
        "bresaola": {"cost": 3.0, "calories": 70},
        "pancetta": {"cost": 2.5, "calories": 80},
        "smoked fish": {"cost": 4.0, "calories": 100},
        "tuna": {"cost": 2.0, "calories": 150},
        "shrimp": {"cost": 3.0, "calories": 100},
        "crab": {"cost": 3.5, "calories": 70},
        "lobster": {"cost": 5.0, "calories": 100},
        "meatball": {"cost": 2.0, "calories": 150},
        "pulled pork": {"cost": 2.5, "calories": 200},
        "carnitas": {"cost": 2.5, "calories": 200},
        "corned beef": {"cost": 3.0, "calories": 200},
        "brisket": {"cost": 3.5, "calories": 250},
        "gyro": {"cost": 2.5, "calories": 220},
        "char siu": {"cost": 3.0, "calories": 240},
        "shawarma": {"cost": 2.5, "calories": 220},
        "jerky": {"cost": 1.5, "calories": 70},
        "egg": {"cost": 0.5, "calories": 78},
        "veggie patty": {"cost": 1.5, "calories": 124}
    },
    "cheeses": {
        "cheddar": {"cost": 1.0, "calories": 110},
        "mozzarella": {"cost": 1.0, "calories": 80},
        "swiss": {"cost": 1.2, "calories": 100},
        "provolone": {"cost": 1.0, "calories": 90},
        "brie": {"cost": 1.5, "calories": 95},
        "gorgonzola": {"cost": 1.5, "calories": 100},
        "feta": {"cost": 1.2, "calories": 70},
        "parmesan": {"cost": 1.5, "calories": 110},
        "gouda": {"cost": 1.3, "calories": 100},
        "ricotta": {"cost": 1.0, "calories": 60},
        "blue cheese": {"cost": 1.5, "calories": 100},
        "goat cheese": {"cost": 1.5, "calories": 80},
        "monterey jack": {"cost": 1.0, "calories": 90},
        "cream cheese": {"cost": 0.8, "calories": 50},
        "american cheese": {"cost": 0.7, "calories": 90},
        "colby": {"cost": 1.0, "calories": 95},
        "pepper jack": {"cost": 1.0, "calories": 90},
        "gruyere": {"cost": 1.5, "calories": 110},
        "camembert": {"cost": 1.5, "calories": 95},
        "asiago": {"cost": 1.2, "calories": 110},
        "romano": {"cost": 1.3, "calories": 110},
        "havarti": {"cost": 1.2, "calories": 100},
        "burrata": {"cost": 1.5, "calories": 80},
        "stracciatella": {"cost": 1.5, "calories": 90},
        "queso fresco": {"cost": 1.0, "calories": 60},
        "cotija": {"cost": 1.0, "calories": 80},
        "paneer": {"cost": 1.0, "calories": 100},
        "halloumi": {"cost": 1.5, "calories": 110}
    },
    "vegetables": {
        "lettuce": {"cost": 0.5, "calories": 10},
        "tomato": {"cost": 0.6, "calories": 20},
        "onion": {"cost": 0.4, "calories": 40},
        "pepper": {"cost": 0.7, "calories": 20},
        "spinach": {"cost": 0.5, "calories": 15},
        "cucumber": {"cost": 0.4, "calories": 10},
        "basil": {"cost": 1.0, "calories": 5},
        "sprouts": {"cost": 1.2, "calories": 15},
        "avocado": {"cost": 1.5, "calories": 150},
        "kale": {"cost": 1.0, "calories": 50},
        "zucchini": {"cost": 0.7, "calories": 20},
        "carrot": {"cost": 0.3, "calories": 30},
        "radish": {"cost": 0.4, "calories": 10},
        "celery": {"cost": 0.3, "calories": 5},
        "mushrooms": {"cost": 0.8, "calories": 20},
        "pickle": {"cost": 0.5, "calories": 5},
        "scallion": {"cost": 0.5, "calories": 5},
        "watercress": {"cost": 1.0, "calories": 5},
        "eggplant": {"cost": 1.0, "calories": 20},
        "beet": {"cost": 0.7, "calories": 40},
        "fennel": {"cost": 1.2, "calories": 20},
        "artichoke": {"cost": 1.5, "calories": 60},
        "garlic": {"cost": 0.5, "calories": 5},
        "olive": {"cost": 1.5, "calories": 50},
        "sun-dried tomato": {"cost": 1.5, "calories": 100},
        "kimchi": {"cost": 1.2, "calories": 20},
        "cabbage": {"cost": 0.6, "calories": 25},
        "greens": {"cost": 0.5, "calories": 15},
        "herbs": {"cost": 1.0, "calories": 5}
    },
    "condiments": {
        "mayonnaise": {"cost": 1.0, "calories": 100},
        "mustard": {"cost": 0.5, "calories": 5},
        "oil": {"cost": 0.8, "calories": 120},
        "butter": {"cost": 0.5, "calories": 100},
        "ketchup": {"cost": 0.6, "calories": 20},
        "relish": {"cost": 0.5, "calories": 10},
        "vinegar": {"cost": 0.3, "calories": 0},
        "dressing": {"cost": 1.0, "calories": 80},
        "salsa": {"cost": 0.8, "calories": 15},
        "sauce": {"cost": 0.5, "calories": 50},
        "pesto": {"cost": 1.5, "calories": 80},
        "chimichurri": {"cost": 1.2, "calories": 60},
        "aioli": {"cost": 1.0, "calories": 90},
        "tahini": {"cost": 1.2, "calories": 100},
        "honey": {"cost": 0.7, "calories": 60},
        "horseradish": {"cost": 0.8, "calories": 10},
        "hummus": {"cost": 1.0, "calories": 60},
        "guacamole": {"cost": 1.5, "calories": 50},
        "tartar sauce": {"cost": 1.0, "calories": 80},
        "yogurt sauce": {"cost": 1.0, "calories": 50},
        "dijon": {"cost": 0.6, "calories": 5},
        "marinara": {"cost": 0.8, "calories": 40},
        "glaze": {"cost": 1.2, "calories": 60},
        "chutney": {"cost": 1.0, "calories": 50}
    },
    "spices": {
        "salt": {"cost": 0.1, "calories": 0},
        "black pepper": {"cost": 0.5, "calories": 5},
        "cumin": {"cost": 0.5, "calories": 10},
        "paprika": {"cost": 0.5, "calories": 10},
        "coriander": {"cost": 0.5, "calories": 10},
        "oregano": {"cost": 0.4, "calories": 5},
        "basil": {"cost": 0.5, "calories": 5},
        "thyme": {"cost": 0.5, "calories": 5},
        "rosemary": {"cost": 0.5, "calories": 5},
        "cayenne pepper": {"cost": 0.5, "calories": 5},
        "turmeric": {"cost": 0.6, "calories": 5},
        "parsley": {"cost": 0.5, "calories": 5},
        "dill": {"cost": 0.5, "calories": 5},
        "cinnamon": {"cost": 0.6, "calories": 10},
        "nutmeg": {"cost": 0.5, "calories": 10},
        "allspice": {"cost": 0.6, "calories": 10},
        "cloves": {"cost": 0.6, "calories": 10},
        "cardamom": {"cost": 0.8, "calories": 10},
        "bay leaf": {"cost": 0.4, "calories": 0},
        "saffron": {"cost": 1.5, "calories": 5},
        "sage": {"cost": 0.5, "calories": 5},
        "mustard seed": {"cost": 0.5, "calories": 10},
        "fenugreek": {"cost": 0.6, "calories": 10},
        "anise": {"cost": 0.5, "calories": 5},
        "five-spice": {"cost": 0.6, "calories": 5},
        "powder": {"cost": 0.5, "calories": 5},
        "seasoning": {"cost": 0.6, "calories": 5},
        "za'atar": {"cost": 0.6, "calories": 5},
        "sumac": {"cost": 0.6, "calories": 5}
    }
}

# %%
# Define the set of words to remove
filter_words = {"ground", "chopped", "sliced", "freshly", "fresh"}

# %% [markdown]
# #Important Functions

# %%
def get_ingredient_subtype(ingredient):
    ingredient_tags = ingredient.split(" ")
    ingr_subtype = " ".join(ingredient_tags[:-1])

    print("Ingredient Subtype: '" + ingr_subtype + "'")
    return ingr_subtype

# %%
def add_ingredient_to_entry(entry,
                            ingredient,
                            ingredient_category,
                            exclusion_set1="",
                            exclusion_set2="",
                            exclusion_words=set()):
    for ingred_type in all_ingredients[ingredient_category].keys():
        if ingred_type in ingredient:
            # Build exclusion set
            exclusion_set = exclusion_words
            if exclusion_set1 and exclusion_set2:
                exclusion_set = exclusion_set.union(set(all_ingredients[exclusion_set1].keys()))
                exclusion_set = exclusion_set.union(set(all_ingredients[exclusion_set2].keys()))

            # Check for exclusions
            if not any(ex_word in ingredient for ex_word in exclusion_set):

                if ingred_type not in entry["ingredients"][ingredient_category]:
                    entry["ingredients"][ingredient_category][ingred_type] = []

                entry["ingredients"][ingredient_category][ingred_type].append(ingredient)
                break

# %%
def categorize_ingredients(ingredients_list):
    entry = {
        "ingredients": {
            "breads": dict(),
            "meats": dict(),
            "cheeses": dict(),
            "vegetables": dict(),
            "condiments": dict(),
            "spices": dict()
        },
        "cost": 0,
        "calories": 0,
        "rating": random.randint(1, 5),
        "dietary_tags": [],
        # increment for each new review,
        #   update rating by weighted sum of old and new ratings
        "review_count": 1,
        # store reviews as list of {rating, text} objects or maybe object ref ids?
        "reviews": []
    }

    for ingredient in ingredients_list:
        # Remove filter words
        pattern = r"\b(" + "|".join(map(re.escape, filter_words)) + r")\b"
        ingredient = re.sub(pattern, "", ingredient.lower()).strip()

        # Simple plural handling
        if ingredient.endswith('s'):
            ingredient = ingredient[:-1]

        print(f"Ingredient: '{ingredient}'")

        add_ingredient_to_entry(entry, ingredient, "breads")
        add_ingredient_to_entry(entry, ingredient, "meats")
        add_ingredient_to_entry(entry, ingredient, "cheeses")
        add_ingredient_to_entry(entry, ingredient, "vegetables",
                                exclusion_set1="condiments",
                                exclusion_set2="spices",
                                exclusion_words={"oil", "pepper jack", "pepperoni"})
        add_ingredient_to_entry(entry, ingredient, "condiments")
        add_ingredient_to_entry(entry, ingredient, "spices")

    # Compute cost and calories
    for category in entry["ingredients"]:
        print(f"Category: {category}")
        for ingredient_type in entry["ingredients"][category]:
            print(f"Ingredient Type: {ingredient_type}")
            lookup_key = ingredient_type
            print(f"Ingredient being searched: '{lookup_key}'")

            try:
                ingredient_data = all_ingredients[category][lookup_key]
                print(ingredient_data)

                # Estimate the sandwich's total cost
                entry["cost"] += ingredient_data["cost"]
                # Estimate the sandwich's total calorie count
                entry["calories"] += ingredient_data["calories"]

            except Exception as e:
                print(f"Exception: {e}")
                continue

    # Round the cost and calories to the nearest hundredth
    entry["cost"] = round(entry["cost"], 2)
    entry["calories"] = round(entry["calories"], 2)


    # Add dietary tags based on ingredients
    # If the base is a veggie patty, egg, or vegetable
    sandwich_bases = set(entry["ingredients"]["meats"].keys())
    if (not sandwich_bases.difference(vegan_bases)\
        or not sandwich_bases) and not entry["ingredients"]["cheeses"]:
        entry["dietary_tags"].append("vegan")
    elif not sandwich_bases.difference(vegetarian_bases)\
        or not sandwich_bases:
        entry["dietary_tags"].append("vegetarian")

    print(f"Total Cost: {entry['cost']}")
    print(f"Total Calories: {entry['calories']}")
    print(f"Rating: {entry['rating']}")
    print(entry)
    return entry

# %% [markdown]
# #Main

# %%
# Reformat each sandwich entry
formatted_sandwiches = []
i = 0
for sandwich in sandwiches_data:
    print("Parsing sandwich...")
    print(f"ID: {sandwich['id']}")
    print(f"Cuisine: {sandwich.get('cuisine')}")
    formatted_entry = {
        "id_": i,
        "cuisine": sandwich.get("cuisine"),
        "restaurant": None
    }

    # If it's indicated that the sandwich came from a specific restaurant
    if originating_restaurant:
        print(f"Restaurant: {originating_restaurant}")
        formatted_entry["restaurant"] = originating_restaurant

    # If the sandwich entry comes with a sandwich name
    if sandwich.get("name"):
        print(f"Name: {sandwich['name']}")
        formatted_entry["name"] = sandwich["name"]

    formatted_entry.update(categorize_ingredients(sandwich["ingredients"]))

    # If the sandwich entry comes with a cost, overwrite the estimate
    #   do this after getting the estimate so that future regression models
    #   can be more easily applied to this data
    if sandwich.get("cost"):
        print(f"Cost: {sandwich['cost']}")
        formatted_entry["cost"] = sandwich["cost"]
    if sandwich.get("calories"):
        print(f"Calories: {sandwich['calories']}")
        formatted_entry["calories"] = sandwich["calories"]

    formatted_sandwiches.append(formatted_entry)
    print("\n\n\n")

    i += 1

# Convert to a pandas DataFrame and export
output_file = 'restructured_' + uploaded_filename
with open(output_file, 'w') as outfile:
    json.dump(formatted_sandwiches, outfile, indent=4)

# Download the reformatted JSON file
files.download(output_file)
# Out:
# Parsing sandwich...
# ID: 1
# Cuisine: None
# Restaurant: mr_pickles
# Name: Elite Chicken & Bacon Ranch
# Ingredient: 'chicken breast'
# Ingredient: 'bacon'
# Ingredient: 'ranch dressing'
# Ingredient: 'cheese'
# Category: breads
# Category: meats
# Ingredient Type: chicken
# Ingredient being searched: 'chicken'
# {'cost': 2.0, 'calories': 200}
# Ingredient Type: bacon
# Ingredient being searched: 'bacon'
# {'cost': 1.0, 'calories': 50}
# Category: cheeses
# Category: vegetables
# Category: condiments
# Ingredient Type: dressing
# Ingredient being searched: 'dressing'
# {'cost': 1.0, 'calories': 80}
# Category: spices
# Total Cost: 4.0
# Total Calories: 330
# Rating: 3
# {'ingredients': {'breads': {}, 'meats': {'chicken': ['chicken breast'], 'bacon': ['bacon']}, 'cheeses': {}, 'vegetables': {}, 'condiments': {'dressing': ['ranch dressing']}, 'spices': {}}, 'cost': 4.0, 'calories': 330, 'rating': 3, 'dietary_tags': [], 'review_count': 1, 'reviews': []}
# Cost: 15.28
# Calories: 580
#
#
#
#
# Parsing sandwich...
# ID: 2
# Cuisine: American
# Restaurant: mr_pickles
# Name: The Philly
# Ingredient: 'steak'
# Ingredient: 'cheese'
# Category: breads
# Category: meats
# Category: cheeses
# Category: vegetables
# Category: condiments
# Category: spices
# Total Cost: 0
# Total Calories: 0
# Rating: 3
# {'ingredients': {'breads': {}, 'meats': {}, 'cheeses': {}, 'vegetables': {}, 'condiments': {}, 'spices': {}}, 'cost': 0, 'calories': 0, 'rating': 3, 'dietary_tags': ['vegan'], 'review_count': 1, 'reviews': []}
# Cost: 13.78
# Calories: 505
#
#
#
#
# Parsing sandwich...
# ID: 3
# Cuisine: None
# Restaurant: mr_pickles
# Name: Subway Club
# Ingredient: 'turkey breast'
# Ingredient: 'black forest ham'
# Ingredient: 'roast beef'
# Category: breads
# Category: meats
# Ingredient Type: turkey
# Ingredient being searched: 'turkey'
# {'cost': 2.5, 'calories': 180}
# Ingredient Type: ham
# Ingredient being searched: 'ham'
# {'cost': 2.0, 'calories': 150}
# Ingredient Type: beef
# Ingredient being searched: 'beef'
# {'cost': 3.0, 'calories': 250}
# Category: cheeses
# Category: vegetables
# Category: condiments
# Category: spices
# Total Cost: 7.5
# Total Calories: 580
# Rating: 1
# {'ingredients': {'breads': {}, 'meats': {'turkey': ['turkey breast'], 'ham': ['black forest ham'], 'beef': ['roast beef']}, 'cheeses': {}, 'vegetables': {}, 'condiments': {}, 'spices': {}}, 'cost': 7.5, 'calories': 580, 'rating': 1, 'dietary_tags': [], 'review_count': 1, 'reviews': []}
# Cost: 14.78
# Calories: 500
#
#
#
#
# Parsing sandwich...
# ID: 4
# Cuisine: American
# Restaurant: mr_pickles
# Name: All-American Club
# Ingredient: 'turkey breast'
# Ingredient: 'black forest ham'
# Ingredient: 'bacon'
# Category: breads
# Category: meats
# Ingredient Type: turkey
# Ingredient being searched: 'turkey'
# {'cost': 2.5, 'calories': 180}
# Ingredient Type: ham
# Ingredient being searched: 'ham'
# {'cost': 2.0, 'calories': 150}
# Ingredient Type: bacon
# Ingredient being searched: 'bacon'
# {'cost': 1.0, 'calories': 50}
# Category: cheeses
# Category: vegetables
# Category: condiments
# Category: spices
# Total Cost: 5.5
# Total Calories: 380
# Rating: 1
# {'ingredients': {'breads': {}, 'meats': {'turkey': ['turkey breast'], 'ham': ['black forest ham'], 'bacon': ['bacon']}, 'cheeses': {}, 'vegetables': {}, 'condiments': {}, 'spices': {}}, 'cost': 5.5, 'calories': 380, 'rating': 1, 'dietary_tags': [], 'review_count': 1, 'reviews': []}
# Cost: 14.28
# Calories: 540
#
#
#
#
# Parsing sandwich...
# ID: 5
# Cuisine: Italian
# Restaurant: mr_pickles
# Name: The Hotshot Italiano
# Ingredient: 'genoa salami'
# Ingredient: 'pepperoni'
# Ingredient: 'ham'
# Category: breads
# Category: meats
# Ingredient Type: salami
# Ingredient being searched: 'salami'
# {'cost': 2.0, 'calories': 120}
# Ingredient Type: pepperoni
# Ingredient being searched: 'pepperoni'
# {'cost': 1.5, 'calories': 80}
# Ingredient Type: ham
# Ingredient being searched: 'ham'
# {'cost': 2.0, 'calories': 150}
# Category: cheeses
# Category: vegetables
# Category: condiments
# Category: spices
# Total Cost: 5.5
# Total Calories: 350
# Rating: 2
# {'ingredients': {'breads': {}, 'meats': {'salami': ['genoa salami'], 'pepperoni': ['pepperoni'], 'ham': ['ham']}, 'cheeses': {}, 'vegetables': {}, 'condiments': {}, 'spices': {}}, 'cost': 5.5, 'calories': 350, 'rating': 2, 'dietary_tags': [], 'review_count': 1, 'reviews': []}
# Cost: 12.28
# Calories: 630
#
#
#
#
# Parsing sandwich...
# ID: 6
# Cuisine: Italian
# Restaurant: mr_pickles
# Name: The Ultimate B.M.T.
# Ingredient: 'ham'
# Ingredient: 'genoa salami'
# Ingredient: 'pepperoni'
# Category: breads
# Category: meats
# Ingredient Type: ham
# Ingredient being searched: 'ham'
# {'cost': 2.0, 'calories': 150}
# Ingredient Type: salami
# Ingredient being searched: 'salami'
# {'cost': 2.0, 'calories': 120}
# Ingredient Type: pepperoni
# Ingredient being searched: 'pepperoni'
# {'cost': 1.5, 'calories': 80}
# Category: cheeses
# Category: vegetables
# Category: condiments
# Category: spices
# Total Cost: 5.5
# Total Calories: 350
# Rating: 3
# {'ingredients': {'breads': {}, 'meats': {'ham': ['ham'], 'salami': ['genoa salami'], 'pepperoni': ['pepperoni']}, 'cheeses': {}, 'vegetables': {}, 'condiments': {}, 'spices': {}}, 'cost': 5.5, 'calories': 350, 'rating': 3, 'dietary_tags': [], 'review_count': 1, 'reviews': []}
# Cost: 12.78
# Calories: 560
#
#
#
#
# Parsing sandwich...
# ID: 7
# Cuisine: None
# Restaurant: mr_pickles
# Name: Titan Turkey
# Ingredient: 'turkey breast'
# Category: breads
# Category: meats
# Ingredient Type: turkey
# Ingredient being searched: 'turkey'
# {'cost': 2.5, 'calories': 180}
# Category: cheeses
# Category: vegetables
# Category: condiments
# Category: spices
# Total Cost: 2.5
# Total Calories: 180
# Rating: 3
# {'ingredients': {'breads': {}, 'meats': {'turkey': ['turkey breast']}, 'cheeses': {}, 'vegetables': {}, 'condiments': {}, 'spices': {}}, 'cost': 2.5, 'calories': 180, 'rating': 3, 'dietary_tags': [], 'review_count': 1, 'reviews': []}
# Cost: 12.68
# Calories: 490
#
#
#
#
# Parsing sandwich...
# ID: 8
# Cuisine: None
# Restaurant: mr_pickles
# Name: Home Run Ham
# Ingredient: 'ham'
# Category: breads
# Category: meats
# Ingredient Type: ham
# Ingredient being searched: 'ham'
# {'cost': 2.0, 'calories': 150}
# Category: cheeses
# Category: vegetables
# Category: condiments
# Category: spices
# Total Cost: 2.0
# Total Calories: 150
# Rating: 5
# {'ingredients': {'breads': {}, 'meats': {'ham': ['ham']}, 'cheeses': {}, 'vegetables': {}, 'condiments': {}, 'spices': {}}, 'cost': 2.0, 'calories': 150, 'rating': 5, 'dietary_tags': [], 'review_count': 1, 'reviews': []}
# Cost: 12.18
# Calories: 510
#
#
#
#
# Parsing sandwich...
# ID: 9
# Cuisine: BBQ
# Restaurant: mr_pickles
# Name: Honey Mustard BBQ Chicken
# Ingredient: 'chicken breast'
# Ingredient: 'honey mustard'
# Category: breads
# Category: meats
# Ingredient Type: chicken
# Ingredient being searched: 'chicken'
# {'cost': 2.0, 'calories': 200}
# Category: cheeses
# Category: vegetables
# Category: condiments
# Ingredient Type: mustard
# Ingredient being searched: 'mustard'
# {'cost': 0.5, 'calories': 5}
# Category: spices
# Total Cost: 2.5
# Total Calories: 205
# Rating: 2
# {'ingredients': {'breads': {}, 'meats': {'chicken': ['chicken breast']}, 'cheeses': {}, 'vegetables': {}, 'condiments': {'mustard': ['honey mustard']}, 'spices': {}}, 'cost': 2.5, 'calories': 205, 'rating': 2, 'dietary_tags': [], 'review_count': 1, 'reviews': []}
# Cost: 13.78
# Calories: 510
#
#
#
#
# Parsing sandwich...
# ID: 10
# Cuisine: None
# Restaurant: mr_pickles
# Name: The Boss
# Category: breads
# Category: meats
# Category: cheeses
# Category: vegetables
# Category: condiments
# Category: spices
# Total Cost: 0
# Total Calories: 0
# Rating: 2
# {'ingredients': {'breads': {}, 'meats': {}, 'cheeses': {}, 'vegetables': {}, 'condiments': {}, 'spices': {}}, 'cost': 0, 'calories': 0, 'rating': 2, 'dietary_tags': ['vegan'], 'review_count': 1, 'reviews': []}
# Cost: 14.58
# Calories: 690
#
#
#
#
# Parsing sandwich...
# ID: 11
# Cuisine: None
# Restaurant: mr_pickles
# Name: Spicy Nacho Chicken
# Ingredient: 'chicken breast'
# Category: breads
# Category: meats
# Ingredient Type: chicken
# Ingredient being searched: 'chicken'
# {'cost': 2.0, 'calories': 200}
# Category: cheeses
# Category: vegetables
# Category: condiments
# Category: spices
# Total Cost: 2.0
# Total Calories: 200
# Rating: 1
# {'ingredients': {'breads': {}, 'meats': {'chicken': ['chicken breast']}, 'cheeses': {}, 'vegetables': {}, 'condiments': {}, 'spices': {}}, 'cost': 2.0, 'calories': 200, 'rating': 1, 'dietary_tags': [], 'review_count': 1, 'reviews': []}
# Cost: 13.78
# Calories: 440
#
#
#
#
# Parsing sandwich...
# ID: 12
# Cuisine: None
# Restaurant: mr_pickles
# Name: Cheesy Garlic Steak
# Ingredient: 'steak'
# Ingredient: 'cheese'
# Ingredient: 'herb garlic oil'
# Category: breads
# Category: meats
# Category: cheeses
# Category: vegetables
# Category: condiments
# Ingredient Type: oil
# Ingredient being searched: 'oil'
# {'cost': 0.8, 'calories': 120}
# Category: spices
# Total Cost: 0.8
# Total Calories: 120
# Rating: 3
# {'ingredients': {'breads': {}, 'meats': {}, 'cheeses': {}, 'vegetables': {}, 'condiments': {'oil': ['herb garlic oil']}, 'spices': {}}, 'cost': 0.8, 'calories': 120, 'rating': 3, 'dietary_tags': ['vegan'], 'review_count': 1, 'reviews': []}
# Cost: 13.78
# Calories: 510
#
#
#
#
# Parsing sandwich...
# ID: 13
# Cuisine: None
# Restaurant: mr_pickles
# Name: Garlic Roast Beef
# Ingredient: 'roast beef'
# Ingredient: 'herb garlic oil'
# Category: breads
# Category: meats
# Ingredient Type: beef
# Ingredient being searched: 'beef'
# {'cost': 3.0, 'calories': 250}
# Category: cheeses
# Category: vegetables
# Category: condiments
# Ingredient Type: oil
# Ingredient being searched: 'oil'
# {'cost': 0.8, 'calories': 120}
# Category: spices
# Total Cost: 3.8
# Total Calories: 370
# Rating: 3
# {'ingredients': {'breads': {}, 'meats': {'beef': ['roast beef']}, 'cheeses': {}, 'vegetables': {}, 'condiments': {'oil': ['herb garlic oil']}, 'spices': {}}, 'cost': 3.8, 'calories': 370, 'rating': 3, 'dietary_tags': [], 'review_count': 1, 'reviews': []}
# Cost: 10.69
# Calories: 490
#
#
#
#
# Parsing sandwich...
# ID: 14
# Cuisine: None
# Restaurant: mr_pickles
# Name: The Beast
# Category: breads
# Category: meats
# Category: cheeses
# Category: vegetables
# Category: condiments
# Category: spices
# Total Cost: 0
# Total Calories: 0
# Rating: 3
# {'ingredients': {'breads': {}, 'meats': {}, 'cheeses': {}, 'vegetables': {}, 'condiments': {}, 'spices': {}}, 'cost': 0, 'calories': 0, 'rating': 3, 'dietary_tags': ['vegan'], 'review_count': 1, 'reviews': []}
# Cost: 11.19
# Calories: 740
#
#
#
#
# Parsing sandwich...
# ID: 15
# Cuisine: Japanese
# Restaurant: mr_pickles
# Name: Teriyaki Blitz
# Ingredient: 'chicken teriyaki'
# Category: breads
# Category: meats
# Ingredient Type: chicken
# Ingredient being searched: 'chicken'
# {'cost': 2.0, 'calories': 200}
# Category: cheeses
# Category: vegetables
# Category: condiments
# Category: spices
# Total Cost: 2.0
# Total Calories: 200
# Rating: 2
# {'ingredients': {'breads': {}, 'meats': {'chicken': ['chicken teriyaki']}, 'cheeses': {}, 'vegetables': {}, 'condiments': {}, 'spices': {}}, 'cost': 2.0, 'calories': 200, 'rating': 2, 'dietary_tags': [], 'review_count': 1, 'reviews': []}
# Cost: 9.49
# Calories: 460
#
#
#
#
# Parsing sandwich...
# ID: 16
# Cuisine: None
# Restaurant: mr_pickles
# Name: The Outlaw
# Category: breads
# Category: meats
# Category: cheeses
# Category: vegetables
# Category: condiments
# Category: spices
# Total Cost: 0
# Total Calories: 0
# Rating: 3
# {'ingredients': {'breads': {}, 'meats': {}, 'cheeses': {}, 'vegetables': {}, 'condiments': {}, 'spices': {}}, 'cost': 0, 'calories': 0, 'rating': 3, 'dietary_tags': ['vegan'], 'review_count': 1, 'reviews': []}
# Cost: 9.49
# Calories: 590
#
#
#
#
# Parsing sandwich...
# ID: 17
# Cuisine: None
# Restaurant: mr_pickles
# Name: The Monster
# Category: breads
# Category: meats
# Category: cheeses
# Category: vegetables
# Category: condiments
# Category: spices
# Total Cost: 0
# Total Calories: 0
# Rating: 1
# {'ingredients': {'breads': {}, 'meats': {}, 'cheeses': {}, 'vegetables': {}, 'condiments': {}, 'spices': {}}, 'cost': 0, 'calories': 0, 'rating': 1, 'dietary_tags': ['vegan'], 'review_count': 1, 'reviews': []}
# Cost: 10.99
# Calories: 590
#
#
#
#
# Parsing sandwich...
# ID: 18
# Cuisine: Japanese
# Restaurant: mr_pickles
# Name: Sweet Onion Chicken Teriyaki
# Ingredient: 'chicken teriyaki'
# Ingredient: 'sweet onion sauce'
# Category: breads
# Category: meats
# Ingredient Type: chicken
# Ingredient being searched: 'chicken'
# {'cost': 2.0, 'calories': 200}
# Category: cheeses
# Category: vegetables
# Category: condiments
# Ingredient Type: sauce
# Ingredient being searched: 'sauce'
# {'cost': 0.5, 'calories': 50}
# Category: spices
# Total Cost: 2.5
# Total Calories: 250
# Rating: 5
# {'ingredients': {'breads': {}, 'meats': {'chicken': ['chicken teriyaki']}, 'cheeses': {}, 'vegetables': {}, 'condiments': {'sauce': ['sweet onion sauce']}, 'spices': {}}, 'cost': 2.5, 'calories': 250, 'rating': 5, 'dietary_tags': [], 'review_count': 1, 'reviews': []}
# Cost: 6.99
# Calories: 430
#
#
#
#
# Parsing sandwich...
# ID: 19
# Cuisine: None
# Restaurant: mr_pickles
# Name: Pickleball Club
# Category: breads
# Category: meats
# Category: cheeses
# Category: vegetables
# Category: condiments
# Category: spices
# Total Cost: 0
# Total Calories: 0
# Rating: 5
# {'ingredients': {'breads': {}, 'meats': {}, 'cheeses': {}, 'vegetables': {}, 'condiments': {}, 'spices': {}}, 'cost': 0, 'calories': 0, 'rating': 5, 'dietary_tags': ['vegan'], 'review_count': 1, 'reviews': []}
# Cost: 6.99
# Calories: 500
#
#
#
#
# Parsing sandwich...
# ID: 20
# Cuisine: None
# Restaurant: mr_pickles
# Name: Black Forest Ham
# Ingredient: 'black forest ham'
# Category: breads
# Category: meats
# Ingredient Type: ham
# Ingredient being searched: 'ham'
# {'cost': 2.0, 'calories': 150}
# Category: cheeses
# Category: vegetables
# Category: condiments
# Category: spices
# Total Cost: 2.0
# Total Calories: 150
# Rating: 4
# {'ingredients': {'breads': {}, 'meats': {'ham': ['black forest ham']}, 'cheeses': {}, 'vegetables': {}, 'condiments': {}, 'spices': {}}, 'cost': 2.0, 'calories': 150, 'rating': 4, 'dietary_tags': [], 'review_count': 1, 'reviews': []}
# Cost: 5.99
# Calories: 320
#
#
#
#
# Parsing sandwich...
# ID: 21
# Cuisine: None
# Restaurant: mr_pickles
# Name: B.L.T.
# Ingredient: 'bacon'
# Ingredient: 'lettuce'
# Ingredient: 'tomato'
# Category: breads
# Category: meats
# Ingredient Type: bacon
# Ingredient being searched: 'bacon'
# {'cost': 1.0, 'calories': 50}
# Category: cheeses
# Category: vegetables
# Ingredient Type: lettuce
# Ingredient being searched: 'lettuce'
# {'cost': 0.5, 'calories': 10}
# Ingredient Type: tomato
# Ingredient being searched: 'tomato'
# {'cost': 0.6, 'calories': 20}
# Category: condiments
# Category: spices
# Total Cost: 2.1
# Total Calories: 80
# Rating: 5
# {'ingredients': {'breads': {}, 'meats': {'bacon': ['bacon']}, 'cheeses': {}, 'vegetables': {'lettuce': ['lettuce'], 'tomato': ['tomato']}, 'condiments': {}, 'spices': {}}, 'cost': 2.1, 'calories': 80, 'rating': 5, 'dietary_tags': [], 'review_count': 1, 'reviews': []}
# Cost: 5.99
# Calories: 370
#
#
#
#
# Parsing sandwich...
# ID: 22
# Cuisine: None
# Restaurant: mr_pickles
# Name: Cold Cut Combo
# Ingredient: 'turkey ham'
# Ingredient: 'turkey salami'
# Ingredient: 'turkey bologna'
# Category: breads
# Category: meats
# Ingredient Type: turkey
# Ingredient being searched: 'turkey'
# {'cost': 2.5, 'calories': 180}
# Category: cheeses
# Category: vegetables
# Category: condiments
# Category: spices
# Total Cost: 2.5
# Total Calories: 180
# Rating: 3
# {'ingredients': {'breads': {}, 'meats': {'turkey': ['turkey ham', 'turkey salami', 'turkey bologna']}, 'cheeses': {}, 'vegetables': {}, 'condiments': {}, 'spices': {}}, 'cost': 2.5, 'calories': 180, 'rating': 3, 'dietary_tags': [], 'review_count': 1, 'reviews': []}
# Cost: 5.99
# Calories: 370
#
#
#
#
# Parsing sandwich...
# ID: 23
# Cuisine: None
# Restaurant: mr_pickles
# Name: Grilled Chicken
# Ingredient: 'chicken breast'
# Category: breads
# Category: meats
# Ingredient Type: chicken
# Ingredient being searched: 'chicken'
# {'cost': 2.0, 'calories': 200}
# Category: cheeses
# Category: vegetables
# Category: condiments
# Category: spices
# Total Cost: 2.0
# Total Calories: 200
# Rating: 2
# {'ingredients': {'breads': {}, 'meats': {'chicken': ['chicken breast']}, 'cheeses': {}, 'vegetables': {}, 'condiments': {}, 'spices': {}}, 'cost': 2.0, 'calories': 200, 'rating': 2, 'dietary_tags': [], 'review_count': 1, 'reviews': []}
# Cost: 6.99
# Calories: 330
#
#
#
#
# Parsing sandwich...
# ID: 24
# Cuisine: Italian
# Restaurant: mr_pickles
# Name: Meatball Marinara
# Ingredient: 'italian meatball'
# Ingredient: 'marinara sauce'
# Category: breads
# Category: meats
# Ingredient Type: meatball
# Ingredient being searched: 'meatball'
# {'cost': 2.0, 'calories': 150}
# Category: cheeses
# Category: vegetables
# Category: condiments
# Ingredient Type: sauce
# Ingredient being searched: 'sauce'
# {'cost': 0.5, 'calories': 50}
# Category: spices
# Total Cost: 2.5
# Total Calories: 200
# Rating: 5
# {'ingredients': {'breads': {}, 'meats': {'meatball': ['italian meatball']}, 'cheeses': {}, 'vegetables': {}, 'condiments': {'sauce': ['marinara sauce']}, 'spices': {}}, 'cost': 2.5, 'calories': 200, 'rating': 5, 'dietary_tags': [], 'review_count': 1, 'reviews': []}
# Cost: 6.99
# Calories: 520
#
#
#
#
# Parsing sandwich...
# ID: 25
# Cuisine: None
# Restaurant: mr_pickles
# Name: Oven-Roasted Turkey
# Ingredient: 'turkey breast'
# Category: breads
# Category: meats
# Ingredient Type: turkey
# Ingredient being searched: 'turkey'
# {'cost': 2.5, 'calories': 180}
# Category: cheeses
# Category: vegetables
# Category: condiments
# Category: spices
# Total Cost: 2.5
# Total Calories: 180
# Rating: 4
# {'ingredients': {'breads': {}, 'meats': {'turkey': ['turkey breast']}, 'cheeses': {}, 'vegetables': {}, 'condiments': {}, 'spices': {}}, 'cost': 2.5, 'calories': 180, 'rating': 4, 'dietary_tags': [], 'review_count': 1, 'reviews': []}
# Cost: 5.99
# Calories: 310
#
#
#
#
# Parsing sandwich...
# ID: 26
# Cuisine: Italian
# Restaurant: mr_pickles
# Name: Pizza Sub
# Ingredient: 'pepperoni'
# Ingredient: 'marinara sauce'
# Ingredient: 'cheese'
# Category: breads
# Category: meats
# Ingredient Type: pepperoni
# Ingredient being searched: 'pepperoni'
# {'cost': 1.5, 'calories': 80}
# Category: cheeses
# Category: vegetables
# Category: condiments
# Ingredient Type: sauce
# Ingredient being searched: 'sauce'
# {'cost': 0.5, 'calories': 50}
# Category: spices
# Total Cost: 2.0
# Total Calories: 130
# Rating: 2
# {'ingredients': {'breads': {}, 'meats': {'pepperoni': ['pepperoni']}, 'cheeses': {}, 'vegetables': {}, 'condiments': {'sauce': ['marinara sauce']}, 'spices': {}}, 'cost': 2.0, 'calories': 130, 'rating': 2, 'dietary_tags': [], 'review_count': 1, 'reviews': []}
# Cost: 4.99
# Calories: 490
#
#
#
#
# Parsing sandwich...
# ID: 27
# Cuisine: None
# Restaurant: mr_pickles
# Name: Oven-Roasted Turkey & Ham
# Ingredient: 'turkey breast'
# Ingredient: 'ham'
# Category: breads
# Category: meats
# Ingredient Type: turkey
# Ingredient being searched: 'turkey'
# {'cost': 2.5, 'calories': 180}
# Ingredient Type: ham
# Ingredient being searched: 'ham'
# {'cost': 2.0, 'calories': 150}
# Category: cheeses
# Category: vegetables
# Category: condiments
# Category: spices
# Total Cost: 4.5
# Total Calories: 330
# Rating: 1
# {'ingredients': {'breads': {}, 'meats': {'turkey': ['turkey breast'], 'ham': ['ham']}, 'cheeses': {}, 'vegetables': {}, 'condiments': {}, 'spices': {}}, 'cost': 4.5, 'calories': 330, 'rating': 1, 'dietary_tags': [], 'review_count': 1, 'reviews': []}
# Cost: 5.99
# Calories: 310
#
#
#
#
# Parsing sandwich...
# ID: 28
# Cuisine: None
# Restaurant: mr_pickles
# Name: Rotisserie-Style Chicken
# Ingredient: 'chicken breast'
# Category: breads
# Category: meats
# Ingredient Type: chicken
# Ingredient being searched: 'chicken'
# {'cost': 2.0, 'calories': 200}
# Category: cheeses
# Category: vegetables
# Category: condiments
# Category: spices
# Total Cost: 2.0
# Total Calories: 200
# Rating: 3
# {'ingredients': {'breads': {}, 'meats': {'chicken': ['chicken breast']}, 'cheeses': {}, 'vegetables': {}, 'condiments': {}, 'spices': {}}, 'cost': 2.0, 'calories': 200, 'rating': 3, 'dietary_tags': [], 'review_count': 1, 'reviews': []}
# Cost: 6.99
# Calories: 350
#
#
#
#
# Parsing sandwich...
# ID: 29
# Cuisine: None
# Restaurant: mr_pickles
# Name: Roast Beef
# Ingredient: 'roast beef'
# Category: breads
# Category: meats
# Ingredient Type: beef
# Ingredient being searched: 'beef'
# {'cost': 3.0, 'calories': 250}
# Category: cheeses
# Category: vegetables
# Category: condiments
# Category: spices
# Total Cost: 3.0
# Total Calories: 250
# Rating: 3
# {'ingredients': {'breads': {}, 'meats': {'beef': ['roast beef']}, 'cheeses': {}, 'vegetables': {}, 'condiments': {}, 'spices': {}}, 'cost': 3.0, 'calories': 250, 'rating': 3, 'dietary_tags': [], 'review_count': 1, 'reviews': []}
# Cost: 6.99
# Calories: 350
#
#
#
#
# Parsing sandwich...
# ID: 30
# Cuisine: None
# Restaurant: mr_pickles
# Name: Steak & Cheese
# Ingredient: 'steak'
# Ingredient: 'cheese'
# Category: breads
# Category: meats
# Category: cheeses
# Category: vegetables
# Category: condiments
# Category: spices
# Total Cost: 0
# Total Calories: 0
# Rating: 1
# {'ingredients': {'breads': {}, 'meats': {}, 'cheeses': {}, 'vegetables': {}, 'condiments': {}, 'spices': {}}, 'cost': 0, 'calories': 0, 'rating': 1, 'dietary_tags': ['vegan'], 'review_count': 1, 'reviews': []}
# Cost: 6.99
# Calories: 370
#
#
#
#
# Parsing sandwich...
# ID: 31
# Cuisine: None
# Restaurant: mr_pickles
# Name: Tuna
# Ingredient: 'tuna'
# Category: breads
# Category: meats
# Ingredient Type: tuna
# Ingredient being searched: 'tuna'
# {'cost': 2.0, 'calories': 150}
# Category: cheeses
# Category: vegetables
# Category: condiments
# Category: spices
# Total Cost: 2.0
# Total Calories: 150
# Rating: 5
# {'ingredients': {'breads': {}, 'meats': {'tuna': ['tuna']}, 'cheeses': {}, 'vegetables': {}, 'condiments': {}, 'spices': {}}, 'cost': 2.0, 'calories': 150, 'rating': 5, 'dietary_tags': [], 'review_count': 1, 'reviews': []}
# Cost: 5.99
# Calories: 510
#
#
#
#
# Parsing sandwich...
# ID: 32
# Cuisine: None
# Restaurant: mr_pickles
# Name: Veggie Delite
# Ingredient: 'lettuce'
# Ingredient: 'tomato'
# Ingredient: 'cucumber'
# Ingredient: 'green pepper'
# Ingredient: 'onion'
# Category: breads
# Category: meats
# Category: cheeses
# Category: vegetables
# Ingredient Type: lettuce
# Ingredient being searched: 'lettuce'
# {'cost': 0.5, 'calories': 10}
# Ingredient Type: tomato
# Ingredient being searched: 'tomato'
# {'cost': 0.6, 'calories': 20}
# Ingredient Type: cucumber
# Ingredient being searched: 'cucumber'
# {'cost': 0.4, 'calories': 10}
# Ingredient Type: pepper
# Ingredient being searched: 'pepper'
# {'cost': 0.7, 'calories': 20}
# Ingredient Type: onion
# Ingredient being searched: 'onion'
# {'cost': 0.4, 'calories': 40}
# Category: condiments
# Category: spices
# Total Cost: 2.6
# Total Calories: 100
# Rating: 1
# {'ingredients': {'breads': {}, 'meats': {}, 'cheeses': {}, 'vegetables': {'lettuce': ['lettuce'], 'tomato': ['tomato'], 'cucumber': ['cucumber'], 'pepper': ['green pepper'], 'onion': ['onion']}, 'condiments': {}, 'spices': {}}, 'cost': 2.6, 'calories': 100, 'rating': 1, 'dietary_tags': ['vegan'], 'review_count': 1, 'reviews': []}
# Cost: 5.99
# Calories: 220
