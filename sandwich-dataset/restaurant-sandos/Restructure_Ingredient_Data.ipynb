# %%
import random
import re
import io
import pandas as pd
import json
import requests
from google.colab import files
import ipywidgets as widgets
from IPython.display import display

# Create a FileUpload widget that accepts JSON files
uploader = widgets.FileUpload(
    accept='.csv',
    multiple=False
)

# Display the uploader widget
display(uploader)

def handle_upload(change):
    # Declare global vars because apparently I can't use ones in the broader scope
    global ingredients_data, uploaded_filename
    if uploader.value:
        # Get the uploaded file content
        uploaded_file = next(iter(uploader.value.values()))
        uploaded_filename = uploaded_file['metadata']['name']

        # Decode the file content from bytes to a string
        csv_str = uploaded_file['content'].decode('utf-8')
        print(f"Successfully uploaded {uploaded_filename}")

        ingredients_data = pd.read_csv(io.StringIO(csv_str))


# Observe changes in the uploader widget
uploader.observe(handle_upload, names='value')
# Out:
# FileUpload(value={}, accept='.csv', description='Upload')
# Successfully uploaded Mr Pickles Ingredients - ingredients.csv

# %%
ingredients_data.head()
# Out:
#   category    ingredient  cost
# 0    Bread  Dutch Crunch   0.0
# 1    Bread     Sourdough   0.0
# 2    Bread         Wheat   0.0
# 3    Bread        French   0.0
# 4    Bread    Marble Rye   0.0

# %%
def convert_to_json(df):
  result = {
    "Bread": dict(),
    "Meat": dict(),
    "Vegetable": dict(),
    "Cheese": dict(),
    "Condiment": dict()
  }

  for _, row in df.iterrows():
      category = row['category']
      ingredient = row['ingredient']

      print(f"Category: {category}\
            \nIngredient: {ingredient}")

      # if the ingredient doesn't exist
      if ingredient not in result[category].keys():
          result[category][ingredient] = dict()

      if 'cost' not in result[category][ingredient].keys():
          result[category][ingredient]['cost'] = row['cost']

      # defaults to null if no calorie count provided
      if 'calories' not in result[category][ingredient].keys():
          result[category][ingredient]['calories'] = row.get('calories')

  return result

# %%
# print(convert_to_json(ingredients_data))
# Out:
# Category: Bread
# Ingredient: Dutch Crunch
# Category: Bread
# Ingredient: Sourdough
# Category: Bread
# Ingredient: Wheat
# Category: Bread
# Ingredient: French
# Category: Bread
# Ingredient: Marble Rye
# Category: Bread
# Ingredient: Sourdough
# Category: Bread
# Ingredient: Gluten Free Wrap
# Category: Bread
# Ingredient: Multi-Grain Wheat
# Category: Bread
# Ingredient: Spinach Wrap
# Category: Meat
# Ingredient: Turkey Breast
# Category: Meat
# Ingredient: Ham
# Category: Meat
# Ingredient: Chicken Salad
# Category: Meat
# Ingredient: Marinated Chicken
# Category: Meat
# Ingredient: Salami
# Category: Meat
# Ingredient: Roast Beef
# Category: Meat
# Ingredient: Tuna Salad
# Category: Meat
# Ingredient: Pastrami
# Category: Meat
# Ingredient: Bacon
# Category: Meat
# Ingredient: Veggie Patty
# Category: Vegetable
# Ingredient: Red Peppers
# Category: Vegetable
# Ingredient: Cucumber
# Category: Vegetable
# Ingredient: Jalapenos
# Category: Vegetable
# Ingredient: Sauerkraut
# Category: Cheese
# Ingredient: Swiss
# Category: Cheese
# Ingredient: Cheddar Cheese
# Category: Cheese
# Ingredient: Monterey Jack
# Category: Cheese
# Ingredient: Provolone
# Category: Cheese
# Ingredient: Pepper Jack
# Category: Cheese
# Ingredient: American
# Category: Cheese
# Ingredient: Cream Cheese
# Category: Condiment
# Ingredient: Mayonnaise
# Category: Condiment
# Ingredient: Mustard
# Category: Condiment
# Ingredient: Garlic Sauce
# Category: Vegetable
# Ingredient: Tomato
# Category: Vegetable
# Ingredient: Onions
# Category: Vegetable
# Ingredient: Pickles
# Category: Vegetable
# Ingredient: Pepperoncinis
# Category: Vegetable
# Ingredient: Lettuce
# Category: Vegetable
# Ingredient: Avocado
# Category: Condiment
# Ingredient: Cranberry Sauce
# Category: Condiment
# Ingredient: Hummus Roasted Red Pepper
# Category: Condiment
# Ingredient: Salt
# Category: Condiment
# Ingredient: Pepper
# Category: Condiment
# Ingredient: Sauces
# {'Bread': {'Dutch Crunch': {'cost': 0.0, 'calories': None}, 'Sourdough': {'cost': 0.0, 'calories': None}, 'Wheat': {'cost': 0.0, 'calories': None}, 'French': {'cost': 0.0, 'calories': None}, 'Marble Rye': {'cost': 0.0, 'calories': None}, 'Gluten Free Wrap': {'cost': 0.99, 'calories': None}, 'Multi-Grain Wheat': {'cost': 0.0, 'calories': None}, 'Spinach Wrap': {'cost': 0.0, 'calories': None}}, 'Meat': {'Turkey Breast': {'cost': 13.99, 'calories': None}, 'Ham': {'cost': 13.99, 'calories': None}, 'Chicken Salad': {'cost': 13.99, 'calories': None}, 'Marinated Chicken': {'cost': 14.39, 'calories': None}, 'Salami': {'cost': 13.99, 'calories': None}, 'Roast Beef': {'cost': 14.99, 'calories': None}, 'Tuna Salad': {'cost': 14.99, 'calories': None}, 'Pastrami': {'cost': 14.69, 'calories': None}, 'Bacon': {'cost': 13.99, 'calories': None}, 'Veggie Patty': {'cost': 11.99, 'calories': None}}, 'Vegetable': {'Red Peppers': {'cost': 0.0, 'calories': None}, 'Cucumber': {'cost': 0.0, 'calories': None}, 'Jalapenos': {'cost': 0.69, 'calories': None}, 'Sauerkraut': {'cost': 0.99, 'calories': None}, 'Tomato': {'cost': 0.0, 'calories': None}, 'Onions': {'cost': 0.0, 'calories': None}, 'Pickles': {'cost': 0.0, 'calories': None}, 'Pepperoncinis': {'cost': 0.0, 'calories': None}, 'Lettuce': {'cost': 0.0, 'calories': None}, 'Avocado': {'cost': 1.79, 'calories': None}}, 'Cheese': {'Swiss': {'cost': 0.0, 'calories': None}, 'Cheddar Cheese': {'cost': 0.0, 'calories': None}, 'Monterey Jack': {'cost': 0.0, 'calories': None}, 'Provolone': {'cost': 0.0, 'calories': None}, 'Pepper Jack': {'cost': 0.0, 'calories': None}, 'American': {'cost': 0.0, 'calories': None}, 'Cream Cheese': {'cost': 0.0, 'calories': None}}, 'Condiment': {'Mayonnaise': {'cost': 0.0, 'calories': None}, 'Mustard': {'cost': 0.0, 'calories': None}, 'Garlic Sauce': {'cost': 0.0, 'calories': None}, 'Cranberry Sauce': {'cost': 1.29, 'calories': None}, 'Hummus Roasted Red Pepper': {'cost': 1.49, 'calories': None}, 'Salt': {'cost': 0.0, 'calories': None}, 'Pepper': {'cost': 0.0, 'calories': None}, 'Sauces': {'cost': 0.0, 'calories': None}}}

# %%
json_data = convert_to_json(ingredients_data)

output_file = "ingredients_data.json"
with open(output_file, 'w') as outfile:
    json.dump(json_data, outfile, indent=4)

# Download the reformatted JSON file
files.download(output_file)
# Out:
# Category: Bread
# Ingredient: Dutch Crunch
# Category: Bread
# Ingredient: Sourdough
# Category: Bread
# Ingredient: Wheat
# Category: Bread
# Ingredient: French
# Category: Bread
# Ingredient: Marble Rye
# Category: Bread
# Ingredient: Sourdough
# Category: Bread
# Ingredient: Gluten Free Wrap
# Category: Bread
# Ingredient: Multi-Grain Wheat
# Category: Bread
# Ingredient: Spinach Wrap
# Category: Meat
# Ingredient: Turkey Breast
# Category: Meat
# Ingredient: Ham
# Category: Meat
# Ingredient: Chicken Salad
# Category: Meat
# Ingredient: Marinated Chicken
# Category: Meat
# Ingredient: Salami
# Category: Meat
# Ingredient: Roast Beef
# Category: Meat
# Ingredient: Tuna Salad
# Category: Meat
# Ingredient: Pastrami
# Category: Meat
# Ingredient: Bacon
# Category: Meat
# Ingredient: Veggie Patty
# Category: Vegetable
# Ingredient: Red Peppers
# Category: Vegetable
# Ingredient: Cucumber
# Category: Vegetable
# Ingredient: Jalapenos
# Category: Vegetable
# Ingredient: Sauerkraut
# Category: Cheese
# Ingredient: Swiss
# Category: Cheese
# Ingredient: Cheddar Cheese
# Category: Cheese
# Ingredient: Monterey Jack
# Category: Cheese
# Ingredient: Provolone
# Category: Cheese
# Ingredient: Pepper Jack
# Category: Cheese
# Ingredient: American
# Category: Cheese
# Ingredient: Cream Cheese
# Category: Condiment
# Ingredient: Mayonnaise
# Category: Condiment
# Ingredient: Mustard
# Category: Condiment
# Ingredient: Garlic Sauce
# Category: Vegetable
# Ingredient: Tomato
# Category: Vegetable
# Ingredient: Onions
# Category: Vegetable
# Ingredient: Pickles
# Category: Vegetable
# Ingredient: Pepperoncinis
# Category: Vegetable
# Ingredient: Lettuce
# Category: Vegetable
# Ingredient: Avocado
# Category: Condiment
# Ingredient: Cranberry Sauce
# Category: Condiment
# Ingredient: Hummus Roasted Red Pepper
# Category: Condiment
# Ingredient: Salt
# Category: Condiment
# Ingredient: Pepper
# Category: Condiment
# Ingredient: Sauces
